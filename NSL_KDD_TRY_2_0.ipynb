# %% [markdown]
# <a href="https://colab.research.google.com/github/plant310/5UJob/blob/master/NSL_KDD_TRY_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###连接谷歌网盘，读取数据集

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# 进入指定KDD99数据集文件夹
import os
os.chdir("/content/gdrive/My Drive/Self_ANN/NSL_KDD")
# 查看文件目录
# !ls
# Out:
# Mounted at /content/gdrive
# KDDTest+.txt  KDDTrain+.txt  training_attack_types.txt

# %% [markdown]
# ### 数据集读取并预处理

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# %%
# 创建攻击类型的映射字典
from collections import defaultdict
category = defaultdict(list)
category['benign'].append('normal')

with open('training_attack_types.txt', 'r') as f:
  for line in f.readlines():
    attack, cat = line.strip().split(' ')
    category[cat].append(attack)
attack_mapping = dict((v,k) for k in category for v in category[k])
print(attack_mapping)

# 读取训练集数据并将攻击类型合为五种
header_names = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'attack_type', 'success_pred']
train_df = pd.read_csv("KDDTrain+.txt", names=header_names)
train_df['label'] = train_df['attack_type'].map(lambda x:attack_mapping[x]) #把攻击类型归到五大类中
train_df.drop(['attack_type'], axis=1, inplace=True) # 去掉细分攻击类型那一列
train_df.drop(['success_pred'], axis=1, inplace=True) # 去掉最后一列score-the severity of the traffic input itself

# 读取测试集
test_df = pd.read_csv("KDDTest+.txt", names=header_names)
test_df['label'] = test_df['attack_type'].map(lambda x:attack_mapping[x])
test_df.drop(['attack_type'], axis=1, inplace=True)
test_df.drop(['success_pred'], axis=1, inplace=True)
# Out:
# {'normal': 'benign', 'apache2': 'dos', 'back': 'dos', 'mailbomb': 'dos', 'processtable': 'dos', 'snmpgetattack': 'dos', 'teardrop': 'dos', 'smurf': 'dos', 'land': 'dos', 'neptune': 'dos', 'pod': 'dos', 'udpstorm': 'dos', 'ps': 'u2r', 'buffer_overflow': 'u2r', 'perl': 'u2r', 'rootkit': 'u2r', 'loadmodule': 'u2r', 'xterm': 'u2r', 'sqlattack': 'u2r', 'httptunnel': 'u2r', 'ftp_write': 'r2l', 'guess_passwd': 'r2l', 'snmpguess': 'r2l', 'imap': 'r2l', 'spy': 'r2l', 'warezclient': 'r2l', 'warezmaster': 'r2l', 'multihop': 'r2l', 'phf': 'r2l', 'named': 'r2l', 'sendmail': 'r2l', 'xlock': 'r2l', 'xsnoop': 'r2l', 'worm': 'probe', 'nmap': 'probe', 'ipsweep': 'probe', 'portsweep': 'probe', 'satan': 'probe', 'mscan': 'probe', 'saint': 'probe'}

# %%
## 区分训练/测试集、特征集/标签集
Y_train = train_df['label']  # 训练数据标签列
Y_test = test_df['label']  # 测试集标签列
X_train = train_df.drop('label', axis=1)
X_test = test_df.drop('label', axis=1)

# %%
## 查看数据类型使用，与预处理无关

train_num = X_train.shape[0]
total_data = pd.concat([X_train, X_test], axis=0)  #行拼接

# 共有三种协议类型
protocol_type = total_data['protocol_type']
protocol_type_unique = list(set(protocol_type))
print(protocol_type_unique)

# 网络服务类型的种类66
service = total_data['service']
service_unique = list(set(service))
print(service_unique)
print('网络服务类型的种类为',len(service_unique))

# 网络连接状态11种
flag = total_data['flag']
flag_unique = list(set(flag))
print(flag_unique)
print('网络连接状态的种类为',len(flag_unique))
# Out:
# ['udp', 'tcp', 'icmp']
# ['echo', 'http', 'gopher', 'sunrpc', 'courier', 'pop_3', 'nnsp', 'tim_i', 'finger', 'login', 'name', 'uucp_path', 'Z39_50', 'printer', 'ecr_i', 'eco_i', 'domain_u', 'nntp', 'netbios_ssn', 'klogin', 'ldap', 'netstat', 'urh_i', 'X11', 'private', 'urp_i', 'http_2784', 'remote_job', 'smtp', 'link', 'ftp', 'uucp', 'sql_net', 'pm_dump', 'red_i', 'domain', 'mtp', 'supdup', 'shell', 'imap4', 'auth', 'pop_2', 'whois', 'ftp_data', 'time', 'IRC', 'kshell', 'tftp_u', 'systat', 'ntp_u', 'discard', 'ctf', 'http_443', 'netbios_dgm', 'efs', 'exec', 'ssh', 'rje', 'http_8001', 'other', 'telnet', 'hostnames', 'aol', 'csnet_ns', 'harvest', 'iso_tsap', 'daytime', 'vmnet', 'netbios_ns', 'bgp']
# 网络服务类型的种类为 70
# ['SH', 'RSTO', 'S0', 'SF', 'RSTR', 'S2', 'RSTOS0', 'S3', 'S1', 'REJ', 'OTH']
# 网络连接状态的种类为 11

# %%
print(total_data.shape)
# Out:
# (148517, 41)

# %%
# 特征集进行onehot编码

train_num = X_train.shape[0]
total_data = pd.concat([X_train, X_test], axis=0)  #行拼接

x = total_data.values[:,:]
#Transform to numeric features
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# Encode Protocol type feature (3 different values)
labelencoder_x_1 = LabelEncoder()
x[:, 1] = labelencoder_x_1.fit_transform(x[:, 1])
# Encode Service feature (67 different values)
labelencoder_x_2 = LabelEncoder()
x[:, 2] = labelencoder_x_2.fit_transform(x[:, 2])
# Encode Flag feature (11 different values)
labelencoder_x_3 = LabelEncoder()
x[:, 3] = labelencoder_x_3.fit_transform(x[:, 3])

print(x.shape)


# Encoded by one-hot vector
from sklearn.compose import ColumnTransformer
# transform the second feature to 3-dim one-hot vector
ct = ColumnTransformer([("ProtocolType", OneHotEncoder(), [1])], remainder = 'passthrough')
x = ct.fit_transform(x)
print(x.shape)


# transform the third feature to 70-dim one-hot vector
ct = ColumnTransformer([("Service", OneHotEncoder(), [4])], remainder = 'passthrough')
x = ct.fit_transform(x)
print(x.shape)

# transform the fourth feature to 11-dim one-hot vector
ct = ColumnTransformer([("Flag", OneHotEncoder(), [74])], remainder = 'passthrough')  # 这里因为数据集比原作者少，导致Service有66种类型，原71改为70
x = ct.fit_transform(x)
print(x.shape)
# Out:
# (148517, 41)
# (148517, 43)
# (148517, 112)
# (148517, 122)

# %%
print(Y_train.shape)
y = pd.concat([Y_train, Y_test], axis=0)  #行拼接
print(y.shape)
# Out:
# (125973,)
# (148517,)

# %%
# 标签 Encode label (5 labels)
y = pd.concat([Y_train, Y_test], axis=0)  #行拼接
y = y.values
print("编码前", y)
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
print("编码后", y)
# Out:
# 编码前 ['benign' 'benign' 'dos' ... 'dos' 'benign' 'probe']
# 编码后 [0 0 1 ... 1 0 2]

# %%
# 归一化/标准化
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x_train = x[:train_num,:]
x_test = x[train_num:,:]

y_train = y[:train_num]
y_test = y[train_num:]

# %% [markdown]
# ### 复现一篇文章自编码器降维算法----[NDAE降维](https://github.com/ngoctn-lqdtu/A-Deep-Learning-Approach-to-Network-Intrusion-Detection/blob/master/KDD99_5_class_NDAE_classifier.ipynb)

# %%
# 降维前随机森林预测值
from sklearn.ensemble import RandomForestClassifier
rfc1 = RandomForestClassifier(n_jobs=-1, n_estimators=10)
rfc1.fit(x_train, y_train)
rfc1.score(x_test, y_test)
# Out:
# 0.7457416607523066

# %%
import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras import backend as K
import tensorflow as tf
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 2.8.2

# %%
class DenseTranspose(keras.layers.Layer):
  def __init__(self, dense, activation=None, **kwargs):
    self.dense = dense
    self.activation = keras.activations.get(activation)
    super().__init__(**kwargs)
  def build(self, batch_input_shape):
    self.biases = self.add_weight(name="bias", initializer="zeros",shape=[self.dense.input_shape[-1]])
    self.W = tf.transpose(self.dense.weights[0]) 
    super().build(batch_input_shape)
  def compute_output_shape(self, input_shape):
    return (input_shape[0], self.dense.input_shape[-1])
  def call(self, inputs):
    z = tf.matmul(inputs, self.W)
    return self.activation(z + self.biases)

# %%
K.clear_session()
num_hidden = (122, 10, 20, 20)

Dense_11 = Dense(units=num_hidden[1], activation='sigmoid')
Dense_12 = Dense(units=num_hidden[2], activation='sigmoid')
Dense_13 = Dense(units=num_hidden[3], activation='sigmoid')

inputs_1 = Input(shape=(num_hidden[0],))

#Encoder
encoded_11 = Dense_11(inputs_1)
encoded_12 = Dense_12(encoded_11)
encoded_13 = Dense_13(encoded_12)

#Decoder
decoded_11 = DenseTranspose(Dense_13, activation='sigmoid')(encoded_13)
decoded_12 = DenseTranspose(Dense_12, activation='sigmoid')(decoded_11)
outputs_1 = DenseTranspose(Dense_11, activation='sigmoid')(decoded_12)

AE_1=Model(inputs_1, outputs_1)
Encoder_1=Model(inputs_1, decoded_12)

# %%
AE_1.compile(optimizer='rmsprop', loss= 'mse')
AE_1.fit(x_train,x_train,epochs=50,batch_size=256,shuffle=True)
# Out:
# Epoch 1/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.1979
# Epoch 2/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.1201
# Epoch 3/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0750
# Epoch 4/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0522
# Epoch 5/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0418
# Epoch 6/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0374
# Epoch 7/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0357
# Epoch 8/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0350
# Epoch 9/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0347
# Epoch 10/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0346
# Epoch 11/50
# 493/493 [==============================] - 1s 3ms/step - loss: 0.0346
# Epoch 12/50
# 493/493 [==============================] - 1s 3ms/step - loss: 0.0346
# Epoch 13/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0346
# Epoch 14/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 15/50
# 493/493 [==============================] - 1s 3ms/step - loss: 0.0345
# Epoch 16/50
# 493/493 [==============================] - 1s 3ms/step - loss: 0.0345
# Epoch 17/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 18/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 19/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 20/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 21/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 22/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 23/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 24/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 25/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 26/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 27/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 28/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 29/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 30/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 31/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 32/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 33/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 34/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 35/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 36/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 37/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 38/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 39/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 40/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 41/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 42/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 43/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 44/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 45/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 46/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 47/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 48/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 49/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 50/50
# 493/493 [==============================] - 1s 2ms/step - loss: 0.0345

# %%
AE_1_encoded_train = Encoder_1.predict(x_train)
AE_1_encoded_test = Encoder_1.predict(x_test)

# %%
K.clear_session()
num_hidden = (10, 20, 20)

Dense_21 = Dense(units=num_hidden[1], activation='sigmoid')
Dense_22 = Dense(units=num_hidden[2], activation='sigmoid')


inputs_2 = Input(shape=(num_hidden[0],))

#Encoder
encoded_21 = Dense_21(inputs_2)
encoded_22 = Dense_22(encoded_21)


#Decoder
decoded_21 = DenseTranspose(Dense_22, activation='sigmoid')(encoded_22)
outputs_2 = DenseTranspose(Dense_21, activation='sigmoid')(decoded_21)

AE_2=Model(inputs_2, outputs_2)
Encoder_2=Model(inputs_2, decoded_21)

# %%
AE_2.compile(optimizer='rmsprop', loss= 'mse')
AE_2.fit(AE_1_encoded_train,AE_1_encoded_train,epochs=100,batch_size=256,shuffle=True)
# Out:
# Epoch 1/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0446
# Epoch 2/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0134
# Epoch 3/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0054
# Epoch 4/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0035
# Epoch 5/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0029
# Epoch 6/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0025
# Epoch 7/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0022
# Epoch 8/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 9/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 10/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0016
# Epoch 11/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0014
# Epoch 12/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0013
# Epoch 13/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0012
# Epoch 14/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0011
# Epoch 15/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0010
# Epoch 16/100
# 493/493 [==============================] - 1s 1ms/step - loss: 0.0010
# Epoch 17/100
# 493/493 [==============================] - 1s 1ms/step - loss: 9.9017e-04
# Epoch 18/100
# 493/493 [==============================] - 1s 1ms/step - loss: 9.7063e-04
# Epoch 19/100
# 493/493 [==============================] - 1s 1ms/step - loss: 9.4951e-04
# Epoch 20/100
# 493/493 [==============================] - 1s 1ms/step - loss: 9.2865e-04
# Epoch 21/100
# 493/493 [==============================] - 1s 1ms/step - loss: 9.1206e-04
# Epoch 22/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.9756e-04
# Epoch 23/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.8778e-04
# Epoch 24/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.8305e-04
# Epoch 25/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.8098e-04
# Epoch 26/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7997e-04
# Epoch 27/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7932e-04
# Epoch 28/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7878e-04
# Epoch 29/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7852e-04
# Epoch 30/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7819e-04
# Epoch 31/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7795e-04
# Epoch 32/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7768e-04
# Epoch 33/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7743e-04
# Epoch 34/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7730e-04
# Epoch 35/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7722e-04
# Epoch 36/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7704e-04
# Epoch 37/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7691e-04
# Epoch 38/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7678e-04
# Epoch 39/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7671e-04
# Epoch 40/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7656e-04
# Epoch 41/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7652e-04
# Epoch 42/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7640e-04
# Epoch 43/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7638e-04
# Epoch 44/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7631e-04
# Epoch 45/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7626e-04
# Epoch 46/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7616e-04
# Epoch 47/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7610e-04
# Epoch 48/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7605e-04
# Epoch 49/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7605e-04
# Epoch 50/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7592e-04
# Epoch 51/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7594e-04
# Epoch 52/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7586e-04
# Epoch 53/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7583e-04
# Epoch 54/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7581e-04
# Epoch 55/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7570e-04
# Epoch 56/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7563e-04
# Epoch 57/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7568e-04
# Epoch 58/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7559e-04
# Epoch 59/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7551e-04
# Epoch 60/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7547e-04
# Epoch 61/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7550e-04
# Epoch 62/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7539e-04
# Epoch 63/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7533e-04
# Epoch 64/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7535e-04
# Epoch 65/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7529e-04
# Epoch 66/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7519e-04
# Epoch 67/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7516e-04
# Epoch 68/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7518e-04
# Epoch 69/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7506e-04
# Epoch 70/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7498e-04
# Epoch 71/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7494e-04
# Epoch 72/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7495e-04
# Epoch 73/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7479e-04
# Epoch 74/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7474e-04
# Epoch 75/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7466e-04
# Epoch 76/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7460e-04
# Epoch 77/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7451e-04
# Epoch 78/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7443e-04
# Epoch 79/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7435e-04
# Epoch 80/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7431e-04
# Epoch 81/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7423e-04
# Epoch 82/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7417e-04
# Epoch 83/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7409e-04
# Epoch 84/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7405e-04
# Epoch 85/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7393e-04
# Epoch 86/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7397e-04
# Epoch 87/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7384e-04
# Epoch 88/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7381e-04
# Epoch 89/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7374e-04
# Epoch 90/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7374e-04
# Epoch 91/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7369e-04
# Epoch 92/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7358e-04
# Epoch 93/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7355e-04
# Epoch 94/100
# 493/493 [==============================] - 1s 1ms/step - loss: 8.7342e-04
# Epoch 95/100
# 493/493 [==============================] - 1s 2ms/step - loss: 8.7344e-04
# Epoch 96/100
# 493/493 [==============================] - 1s 2ms/step - loss: 8.7339e-04
# Epoch 97/100
# 493/493 [==============================] - 2s 3ms/step - loss: 8.7338e-04
# Epoch 98/100
# 493/493 [==============================] - 1s 3ms/step - loss: 8.7330e-04
# Epoch 99/100
# 493/493 [==============================] - 1s 3ms/step - loss: 8.7319e-04
# Epoch 100/100
# 493/493 [==============================] - 1s 2ms/step - loss: 8.7321e-04

# %%
AE_2_encoded_train = Encoder_2.predict(AE_1_encoded_train)
AE_2_encoded_test = Encoder_2.predict(AE_1_encoded_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc1 = RandomForestClassifier(n_jobs=-1, n_estimators=10)
rfc1.fit(AE_2_encoded_train, y_train)
rfc1.score(AE_2_encoded_test, y_test)
# Out:
# 0.6958392476933996

# %% [markdown]
# ### 免疫

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# %%
# 区分训练集中的自体与非自体，测试集中的已知攻击和未知攻击
train_num = AE_2_encoded_train.shape
Abnormaldata, Normaldata, test_NonSelf2= np.empty(shape=train_num), np.empty(shape=train_num), np.empty(shape=train_num)

flag, flag2, flag3 = 0, 0, 0
for i in range(0, train_num[0]):
  if y_train[i] in [1,3,4]:  # 已知攻击
    Abnormaldata[flag,:] = AE_2_encoded_train[i,:]
    flag = flag + 1
  if y_train[i] == 0:  # 正常样本被labelencode为0
    Normaldata[flag2,:] = AE_2_encoded_train[i,:]
    flag2 = flag2 + 1
  if y_train[i] in [2]:  # 作为未知攻击测试用
    test_NonSelf2[flag3,:] = AE_2_encoded_train[i,:]
    flag3 = flag3 + 1

test_NonSelf = Abnormaldata[int(flag*0.8):flag,:]  # 已知攻击用于测试
test_Self = Normaldata[int(flag2*0.8):flag2,:]  # 自体用于测试

Abnormaldata = Abnormaldata[:flag,:][0:int(flag*0.8),:]  # 非自体用于训练
print("攻击数据量", Abnormaldata.shape)
Normaldata = Normaldata[:flag2, :][0:int(flag2*0.8),:]  # 自体用于训练
print("正常样本数量", Normaldata.shape)
test_NonSelf2 = test_NonSelf2[:flag3,:][0:int(flag3*0.1),:]  # 未知攻击用于测试
print("测试的攻击样本数据量",test_NonSelf2.shape)
# Out:
# 攻击数据量 (37579, 20)
# 正常样本数量 (53874, 20)
# 测试的攻击样本数据量 (1165, 20)

# %%
#  矩阵计算欧式距离
def EuclideanDistance(A, B):
    m, n = A.shape[0], B.shape[0]
    # AA经过pow函数对矩阵每个元素求二次方，axis=1横向求和，此时AA.shape=(m,1),扩展n-1次，AA.shape=(m,n)
    AA = torch.pow(A, 2).sum(1, keepdim=True).expand(m, n)
    # sum操作后BB.shape=(n,1)
    BB = torch.pow(B, 2).sum(1, keepdim=True).expand(n, m).T
    dist = AA + BB
    # 表示dist - 2* A * B.T
    dist.addmm_(1, -2, A, B.t())
    # clamp()函数可以限定dist内元素的最大最小范围，dist最后开方，得到样本之间的距离矩阵
    dist = dist.clamp(min=1e-12).sqrt()
    return dist


# 生成自体检测器[计算与非自体的最小距离-非自体半径=自体检测器半径]
def Gen_Self_Detector(Normaldata, Abnormaldata, Nonself_Radius):
    Normaldata_num = len(Normaldata)
    Radius = np.empty(shape=(Normaldata_num))
    temp = 2 * Nonself_Radius

    # 自体与非自体欧式距离
    process_Nor = torch.tensor(Normaldata)
    process_Abnor = torch.tensor(Abnormaldata)
    Self_Nonself_distance = EuclideanDistance(process_Nor, process_Abnor)

    for i in range(0, Normaldata_num):
        min_distance = min(Self_Nonself_distance[i])  # 与非自体最小距离
        #index = Self_Nonself_distance[i].tolist().index(min_distance)  # 最小距离索引

        # 最小距离应减去非自体半径，依情况判断微调
        if min_distance < temp:
            Radius[i] = min_distance * 0.4
        else:
            Radius[i] = min(Self_Nonself_distance[i]) - Nonself_Radius
        #print("第{}个自体与第{}个非自体最近，半径为 {}".format(i, index, Radius[i]))

        print("第{}个自体半径为 {}".format(i, Radius[i]))
    return Radius


step = 200  # 由于上万数据的矩阵运算，内存不足，因此分步计算
nonself_radius = 0
Normaldata_num = len(Normaldata)
Radius = np.empty(shape=Normaldata_num)  # 用于存储自体检测器的半径
for i in range(0, Normaldata_num, step):
  print("实验进行{}/{}.".format(i, Normaldata_num))
  local_Normaldata = Normaldata[i:i+step,:]
  curr_radius = Gen_Self_Detector(local_Normaldata, Abnormaldata, nonself_radius) # 调用函数计算自体检测器
  Radius[i:i+step] = curr_radius
if i < Normaldata_num:
  print("实验进行{}/{}.".format(Normaldata_num, Normaldata_num))
  local_Normaldata = Normaldata[i:Normaldata_num,:]
  curr_radius = Gen_Self_Detector(local_Normaldata, Abnormaldata, nonself_radius)
  Radius[i:Normaldata_num] = curr_radius

Radius = Radius.T  # 得到最终的检测器半径
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 第174个自体半径为 0.00012434151790227487
# 第175个自体半径为 9.878246068763309e-05
# 第176个自体半径为 4.50388613911515e-05
# 第177个自体半径为 0.0005009454381943175
# 第178个自体半径为 5.946208438136866e-05
# 第179个自体半径为 0.0002577854466416567
# 第180个自体半径为 0.0002844522658728871
# 第181个自体半径为 0.00037311493961754807
# 第182个自体半径为 8.174983596564826e-05
# 第183个自体半径为 0.000807066805321463
# 第184个自体半径为 0.0008975372792352921
# 第185个自体半径为 0.0004328767053748291
# 第186个自体半径为 0.03482896922770052
# 第187个自体半径为 0.0002844522658728871
# 第188个自体半径为 0.001243988672376603
# 第189个自体半径为 0.002502444581715462
# 第190个自体半径为 0.0011964086905180906
# 第191个自体半径为 1e-06
# 第192个自体半径为 0.00046114034288027633
# 第193个自体半径为 6.53129666699619e-05
# 第194个自体半径为 4.526131743229988e-05
# 第195个自体半径为 1e-06
# 第196个自体半径为 0.00015619346909918915
# 第197个自体半径为 0.0005916121006505406
# 第198个自体半径为 0.0009460185033841882
# 第199个自体半径为 0.0004567501128971317
# 实验进行49000/53874.
# 第0个自体半径为 8.545465169074817e-05
# 第1个自体半径为 0.0006152591888566627
# 第2个自体半径为 0.0022550961930785356
# 第3个自体半径为 0.0007360009799298431
# 第4个自体半径为 0.00028170021261175667
# 第5个自体半径为 0.000854405450499798
# 第6个自体半径为 0.00012281324890673153
# 第7个自体半径为 0.0006163864272343579
# 第8个自体半径为 0.00016655417189145885
# 第9个自体半径为 0.0001873289376146433
# 第10个自体半径为 4.3749415925496414e-05
# 第11个自体半径为 6.556629456185589e-06
# 第12个自体半径为 0.00026646302570233874
# 第13个自体半径为 0.0010781400414317573
# 第14个自体半径为 0.00042660571141587574
# 第15个自体半径为 0.0010815511898472424
# 第16个自体半径为 0.0002849924686020302
# 第17个自体半径为 0.0005027416475223837
# 第18个自体半径为 0.03584610655969966
# 第19个自体半径为 0.0005835725292583965
# 第20个自体半径为 0.00020339944914537822
# 第21个自体半径为 1e-06
# 第22个自体半径为 0.00424240526603582
# 第23个自体半径为 9.628605626289877e-05
# 第24个自体半径为 0.0012241610628692496
# 第25个自体半径为 0.0002781370355972202
# 第26个自体半径为 0.0006834746231737676
# 第27个自体半径为 2.2964514501864336e-05
# 第28个自体半径为 0.0008060078733124744
# 第29个自体半径为 0.0004358186549055559
# 第30个自体半径为 0.0007354563634202234
# 第31个自体半径为 3.728530339057083e-05
# 第32个自体半径为 2.6141897062163206e-05
# 第33个自体半径为 0.0002845420403025501
# 第34个自体半径为 0.00027030326727300375
# 第35个自体半径为 0.0005036547521931528
# 第36个自体半径为 0.002993070756912817
# 第37个自体半径为 0.0001868141124571462
# 第38个自体半径为 5.825032971025169e-05
# 第39个自体半径为 0.0001698308911397002
# 第40个自体半径为 0.000878895098165018
# 第41个自体半径为 1e-06
# 第42个自体半径为 0.00031742866778524916
# 第43个自体半径为 0.0008627031387436757
# 第44个自体半径为 4.6165456774349135e-05
# 第45个自体半径为 0.004382985965397494
# 第46个自体半径为 5.2573640784890176e-05
# 第47个自体半径为 4.2433992803176595e-05
# 第48个自体半径为 4.1465912966703305e-05
# 第49个自体半径为 0.00036832897753224126
# 第50个自体半径为 0.00028455064283706586
# 第51个自体半径为 0.0012434672523281523
# 第52个自体半径为 0.00030644944841129966
# 第53个自体半径为 0.000416345373751705
# 第54个自体半径为 0.0061487900222144875
# 第55个自体半径为 6.31905873910611e-06
# 第56个自体半径为 0.023047555578025375
# 第57个自体半径为 0.000278356776015223
# 第58个自体半径为 0.00047959418310786076
# 第59个自体半径为 0.0012625614055301697
# 第60个自体半径为 0.0005367179831667292
# 第61个自体半径为 9.352844131896093e-06
# 第62个自体半径为 1e-06
# 第63个自体半径为 0.00029056339810867453
# 第64个自体半径为 0.001986257700794859
# 第65个自体半径为 6.6120167327864e-05
# 第66个自体半径为 2.9780480457350913e-05
# 第67个自体半径为 0.030134939075141667
# 第68个自体半径为 0.0003152093769750628
# 第69个自体半径为 1.7794663231497662e-05
# 第70个自体半径为 0.00040009424492277524
# 第71个自体半径为 0.0013407742043465923
# 第72个自体半径为 0.0001899096253147196
# 第73个自体半径为 0.02773291092294481
# 第74个自体半径为 8.751261801572064e-05
# 第75个自体半径为 5.037242273308726e-05
# 第76个自体半径为 7.220340627219277e-05
# 第77个自体半径为 0.0002706610666953473
# 第78个自体半径为 0.0007876642628285447
# 第79个自体半径为 0.003063738334630676
# 第80个自体半径为 1.0298944862559138e-05
# 第81个自体半径为 0.00015525919116339532
# 第82个自体半径为 0.0003853607989730583
# 第83个自体半径为 0.0001231354459599926
# 第84个自体半径为 0.0002601793406620434
# 第85个自体半径为 4.609567579379653e-05
# 第86个自体半径为 0.00025351557892669716
# 第87个自体半径为 0.000501793529925709
# 第88个自体半径为 0.00012411010550125395
# 第89个自体半径为 2.230773010053968e-05
# 第90个自体半径为 0.00038478927902345567
# 第91个自体半径为 0.0003907798480534694
# 第92个自体半径为 0.008201149600979856
# 第93个自体半径为 1.9570810367012142e-05
# 第94个自体半径为 0.00026115132431525325
# 第95个自体半径为 9.731180927654856e-05
# 第96个自体半径为 0.0025666766851180313
# 第97个自体半径为 0.00019949063964354392
# 第98个自体半径为 3.8930121354621474e-06
# 第99个自体半径为 5.5876699026908973e-05
# 第100个自体半径为 0.0002821625786560762
# 第101个自体半径为 4.5435111512153584e-05
# 第102个自体半径为 0.0005855462876140409
# 第103个自体半径为 0.00013570057286223935
# 第104个自体半径为 0.0007081828227394878
# 第105个自体半径为 0.0005082017484942667
# 第106个自体半径为 0.0007570696399922506
# 第107个自体半径为 8.854526397013758e-05
# 第108个自体半径为 0.002134186401522064
# 第109个自体半径为 0.00040090611226516925
# 第110个自体半径为 0.0002846305908930773
# 第111个自体半径为 0.017494527501230876
# 第112个自体半径为 0.00045047174208335763
# 第113个自体半径为 1.839938942849429e-05
# 第114个自体半径为 0.04602111277207011
# 第115个自体半径为 0.0002737447879042673
# 第116个自体半径为 0.0002848695053890694
# 第117个自体半径为 0.0010762744852064264
# 第118个自体半径为 0.0007891632736069305
# 第119个自体半径为 0.00038114527252157995
# 第120个自体半径为 0.00030512051862249644
# 第121个自体半径为 0.0012681259746558972
# 第122个自体半径为 0.0012603283334438303
# 第123个自体半径为 0.0006799757524280783
# 第124个自体半径为 0.0007444915255189384
# 第125个自体半径为 0.0003001798444253339
# 第126个自体半径为 0.0003580534209564609
# 第127个自体半径为 0.0003946852772250311
# 第128个自体半径为 4.9891259603040644e-05
# 第129个自体半径为 0.0007246683260677283
# 第130个自体半径为 0.00022029024013244935
# 第131个自体半径为 1e-06
# 第132个自体半径为 0.030429268722187083
# 第133个自体半径为 0.0005254392224970546
# 第134个自体半径为 2.786659377976254e-05
# 第135个自体半径为 0.0033039745169290767
# 第136个自体半径为 0.0004173173341896318
# 第137个自体半径为 0.000715069388211405
# 第138个自体半径为 0.0015512007493177025
# 第139个自体半径为 6.907051811400358e-05
# 第140个自体半径为 0.0019304882576708811
# 第141个自体半径为 4.211324143964273e-05
# 第142个自体半径为 0.0004921990577643066
# 第143个自体半径为 0.00019359946639861678
# 第144个自体半径为 0.0005744499718073606
# 第145个自体半径为 1e-06
# 第146个自体半径为 1e-06
# 第147个自体半径为 0.00013536331540627743
# 第148个自体半径为 0.00019361802308738417
# 第149个自体半径为 0.00043324597272756567
# 第150个自体半径为 4.4487836625079534e-05
# 第151个自体半径为 0.00011671100854627639
# 第152个自体半径为 0.0007020541157091398
# 第153个自体半径为 0.0013461376159141268
# 第154个自体半径为 0.0006092553416280547
# 第155个自体半径为 0.03380895832857778
# 第156个自体半径为 0.0005520777221356254
# 第157个自体半径为 0.00026194710680513093
# 第158个自体半径为 0.00040021080844843197
# 第159个自体半径为 0.0002549460713007569
# 第160个自体半径为 8.74747027383933e-05
# 第161个自体半径为 0.00034126276041868006
# 第162个自体半径为 0.00012956623452686517
# 第163个自体半径为 0.0005827928842883644
# 第164个自体半径为 0.0003899174776941295
# 第165个自体半径为 0.0007867668521193274
# 第166个自体半径为 0.000576251342354283
# 第167个自体半径为 0.0029955981086486946
# 第168个自体半径为 0.00018846669103797444
# 第169个自体半径为 0.000737313963022392
# 第170个自体半径为 7.575648278482726e-05
# 第171个自体半径为 4.288215433084395e-05
# 第172个自体半径为 0.00019843080906768533
# 第173个自体半径为 0.0005379496126975065
# 第174个自体半径为 0.0005525392450900624
# 第175个自体半径为 0.00047306757699911974
# 第176个自体半径为 0.011696972591356639
# 第177个自体半径为 0.00037488973106251727
# 第178个自体半径为 0.000176745255572475
# 第179个自体半径为 0.000830585534384434
# 第180个自体半径为 0.0005172509761198508
# 第181个自体半径为 0.00018473351643019724
# 第182个自体半径为 0.0006412918308611213
# 第183个自体半径为 9.335426572331838e-05
# 第184个自体半径为 5.0238239021898495e-05
# 第185个自体半径为 0.00018094730648623135
# 第186个自体半径为 0.0004073155469069121
# 第187个自体半径为 0.0008131341929569864
# 第188个自体半径为 0.0005591146717622563
# 第189个自体半径为 0.0008323797736027854
# 第190个自体半径为 5.249441692457914e-05
# 第191个自体半径为 0.0010592660569806308
# 第192个自体半径为 0.0003774091865388974
# 第193个自体半径为 0.00040035260910132426
# 第194个自体半径为 0.00016307923738302163
# 第195个自体半径为 0.001004160857492141
# 第196个自体半径为 0.003866805678175771
# 第197个自体半径为 0.032027457395181626
# 第198个自体半径为 0.00011671100854627639
# 第199个自体半径为 7.632217517089055e-05
# 实验进行49200/53874.
# 第0个自体半径为 0.0003278328298035956
# 第1个自体半径为 0.00012153587263582728
# 第2个自体半径为 5.207339289192646e-05
# 第3个自体半径为 3.1670489250520767e-06
# 第4个自体半径为 0.0005143394492677282
# 第5个自体半径为 0.028910693105497657
# 第6个自体半径为 0.00018860018625272193
# 第7个自体半径为 1e-06
# 第8个自体半径为 0.00302327566656451
# 第9个自体半径为 2.730126974725434e-06
# 第10个自体半径为 0.018950738164652436
# 第11个自体半径为 0.0023371978254717717
# 第12个自体半径为 0.00025479482845557235
# 第13个自体半径为 0.00021088575658319072
# 第14个自体半径为 0.0006106287045602173
# 第15个自体半径为 5.2386278870723195e-05
# 第16个自体半径为 0.00043447407288669344
# 第17个自体半径为 0.0001456532593877164
# 第18个自体半径为 1.7032255388552468e-05
# 第19个自体半径为 0.0016251944895609193
# 第20个自体半径为 0.02525933724021543
# 第21个自体半径为 0.00012153707615834363
# 第22个自体半径为 0.0014402979397136935
# 第23个自体半径为 0.00018839426246998367
# 第24个自体半径为 0.0005548740355600016
# 第25个自体半径为 0.001078727255471943
# 第26个自体半径为 0.0007167345218688372
# 第27个自体半径为 0.0026873253558460774
# 第28个自体半径为 0.008119970492462119
# 第29个自体半径为 0.00032165765925712484
# 第30个自体半径为 0.00043879579493781194
# 第31个自体半径为 0.00042042549016999676
# 第32个自体半径为 0.0004396317685390563
# 第33个自体半径为 1e-06
# 第34个自体半径为 0.0003559089031607667
# 第35个自体半径为 4.677691080379837e-05
# 第36个自体半径为 0.00021610628376351196
# 第37个自体半径为 7.566585018390747e-05
# 第38个自体半径为 0.0008064267091856087
# 第39个自体半径为 0.003748088182162095
# 第40个自体半径为 5.3152331274450426e-05
# 第41个自体半径为 0.00026194710680513093
# 第42个自体半径为 0.0005685983744010282
# 第43个自体半径为 0.0006476840480018607
# 第44个自体半径为 0.0007792198703791304
# 第45个自体半径为 0.0007515995855545407
# 第46个自体半径为 6.619129851473519e-05
# 第47个自体半径为 0.0013252472862837162
# 第48个自体半径为 0.0007239975447350789
# 第49个自体半径为 0.0005673403194444707
# 第50个自体半径为 0.0013905163021443112
# 第51个自体半径为 0.00024347942375443256
# 第52个自体半径为 6.420378646106382e-05
# 第53个自体半径为 1e-06
# 第54个自体半径为 8.276918964240628e-05
# 第55个自体半径为 0.0004924752682050318
# 第56个自体半径为 7.466105290650025e-05
# 第57个自体半径为 0.0004734390932440435
# 第58个自体半径为 2.1428525209848657e-05
# 第59个自体半径为 0.00014995522200693644
# 第60个自体半径为 6.8170166029400134e-06
# 第61个自体半径为 1e-06
# 第62个自体半径为 0.00015488976325127223
# 第63个自体半径为 0.000606335961259147
# 第64个自体半径为 0.0011173579802216287
# 第65个自体半径为 0.000311554505776538
# 第66个自体半径为 0.00012230871292466406
# 第67个自体半径为 0.027480616685958296
# 第68个自体半径为 7.995894852563667e-05
# 第69个自体半径为 0.0004458951996906783
# 第70个自体半径为 8.386323081380335e-05
# 第71个自体半径为 0.0002972166843269822
# 第72个自体半径为 0.00024251419803797503
# 第73个自体半径为 0.0018551427310189452
# 第74个自体半径为 0.0006872578660240584
# 第75个自体半径为 0.000531069692962954
# 第76个自体半径为 1e-06
# 第77个自体半径为 0.000766703801065562
# 第78个自体半径为 0.00034817363854346904
# 第79个自体半径为 1e-06
# 第80个自体半径为 0.0008305463376669706
# 第81个自体半径为 0.029291785074924238
# 第82个自体半径为 0.00012528967133369846
# 第83个自体半径为 0.000520056295883786
# 第84个自体半径为 8.04169297162472e-06
# 第85个自体半径为 0.00014581906399170107
# 第86个自体半径为 0.0009642324523509565
# 第87个自体半径为 0.0003007839310161169
# 第88个自体半径为 0.00015388694698200133
# 第89个自体半径为 0.00028472550570665526
# 第90个自体半径为 0.000872047493454514
# 第91个自体半径为 0.0002848455531114586
# 第92个自体半径为 0.00039809475368326737
# 第93个自体半径为 8.387433717630546e-05
# 第94个自体半径为 1e-06
# 第95个自体半径为 0.0018868861290694892
# 第96个自体半径为 0.00069401984685196
# 第97个自体半径为 0.00020871762038732265
# 第98个自体半径为 4.335860753371357e-05
# 第99个自体半径为 0.00016170312873826134
# 第100个自体半径为 0.0003220544617414227
# 第101个自体半径为 0.023102124932267466
# 第102个自体半径为 0.0024001460484179673
# 第103个自体半径为 0.001999234102582937
# 第104个自体半径为 0.011075228774695661
# 第105个自体半径为 0.029453096668060227
# 第106个自体半径为 0.04752926057316501
# 第107个自体半径为 0.00017667855400921225
# 第108个自体半径为 0.00021109828445893346
# 第109个自体半径为 0.0005664929683123073
# 第110个自体半径为 0.01190089810194313
# 第111个自体半径为 0.0017523405740626171
# 第112个自体半径为 0.0009310248860595063
# 第113个自体半径为 0.0015756237968450144
# 第114个自体半径为 0.00034454737694355407
# 第115个自体半径为 5.37251153324658e-05
# 第116个自体半径为 0.000838490940860765
# 第117个自体半径为 4.5619379934695336e-05
# 第118个自体半径为 0.0001811939226835069
# 第119个自体半径为 0.0010812066181101162
# 第120个自体半径为 0.00010507784494442488
# 第121个自体半径为 0.0005810702398487557
# 第122个自体半径为 0.02944204653385923
# 第123个自体半径为 0.030978082190275147
# 第124个自体半径为 0.0012152447824509425
# 第125个自体半径为 1.090333350296421e-06
# 第126个自体半径为 0.0005645958962122844
# 第127个自体半径为 3.552888085119359e-06
# 第128个自体半径为 9.800530477249397e-05
# 第129个自体半径为 3.676769353630204e-05
# 第130个自体半径为 0.00028133210409791553
# 第131个自体半径为 0.0017597904013047032
# 第132个自体半径为 0.0004716481654136313
# 第133个自体半径为 1.6841750273954333e-05
# 第134个自体半径为 0.00013506682776005344
# 第135个自体半径为 0.00018196970726602106
# 第136个自体半径为 0.00017276707611829553
# 第137个自体半径为 0.0012525851104453487
# 第138个自体半径为 1e-06
# 第139个自体半径为 0.00024251419803797503
# 第140个自体半径为 0.0005956259395258918
# 第141个自体半径为 0.0007196021143701369
# 第142个自体半径为 0.00019335499319987726
# 第143个自体半径为 0.0001118498639052874
# 第144个自体半径为 6.464650638055201e-05
# 第145个自体半径为 0.0004418514187459056
# 第146个自体半径为 0.0014906063203363599
# 第147个自体半径为 0.0004895817026217167
# 第148个自体半径为 8.57008518655838e-06
# 第149个自体半径为 0.0006443853456025297
# 第150个自体半径为 5.7146467042736304e-05
# 第151个自体半径为 8.820480093537482e-05
# 第152个自体半径为 0.0005395509215529968
# 第153个自体半径为 0.0012042722030221927
# 第154个自体半径为 0.00013480625517676908
# 第155个自体半径为 0.00011628306959066121
# 第156个自体半径为 0.00012515264401971623
# 第157个自体半径为 0.00036851353844662973
# 第158个自体半径为 3.967740224508747e-06
# 第159个自体半径为 6.158806033709065e-05
# 第160个自体半径为 1e-06
# 第161个自体半径为 7.362880278493214e-05
# 第162个自体半径为 0.00016384832682601484
# 第163个自体半径为 0.0005430472525464194
# 第164个自体半径为 7.912165945845024e-05
# 第165个自体半径为 0.0005097298415342554
# 第166个自体半径为 0.00044051187227144343
# 第167个自体半径为 0.00026844273192333274
# 第168个自体半径为 0.0012053186407162378
# 第169个自体半径为 0.0023206782393108178
# 第170个自体半径为 0.000611597790345002
# 第171个自体半径为 0.0012702548701814477
# 第172个自体半径为 0.025521035292591247
# 第173个自体半径为 0.001402373318580831
# 第174个自体半径为 1e-06
# 第175个自体半径为 0.001374847341875354
# 第176个自体半径为 0.00028212134576968294
# 第177个自体半径为 0.02953124478201749
# 第178个自体半径为 0.005848096852377723
# 第179个自体半径为 0.014078510388174578
# 第180个自体半径为 0.000302324704302373
# 第181个自体半径为 2.1988176885857616e-06
# 第182个自体半径为 0.0018806840465958757
# 第183个自体半径为 0.0009685804280397561
# 第184个自体半径为 0.0015664942697648288
# 第185个自体半径为 3.846404068034671e-05
# 第186个自体半径为 0.0002205687670732757
# 第187个自体半径为 2.6549587536052455e-06
# 第188个自体半径为 4.3286313875839184e-05
# 第189个自体半径为 9.979182324780255e-05
# 第190个自体半径为 0.0008361036873817455
# 第191个自体半径为 1.2922503148559259e-05
# 第192个自体半径为 0.00011632719399712438
# 第193个自体半径为 0.0019147705074407761
# 第194个自体半径为 0.0009247739415110975
# 第195个自体半径为 0.0006037253107010346
# 第196个自体半径为 5.2371406682947935e-05
# 第197个自体半径为 0.0001245981646516137
# 第198个自体半径为 0.0006370899385872094
# 第199个自体半径为 3.6010745610899554e-06
# 实验进行49400/53874.
# 第0个自体半径为 0.0013186722187151934
# 第1个自体半径为 0.0003322424850365988
# 第2个自体半径为 0.0013656250702583502
# 第3个自体半径为 0.02136164756698268
# 第4个自体半径为 1e-06
# 第5个自体半径为 0.0009606955181591834
# 第6个自体半径为 0.0008561236748961723
# 第7个自体半径为 5.037242273308726e-05
# 第8个自体半径为 0.00011749675871314079
# 第9个自体半径为 0.00012281324890673153
# 第10个自体半径为 0.0004770108467519059
# 第11个自体半径为 0.000804710376768325
# 第12个自体半径为 0.00023812080275380451
# 第13个自体半径为 0.0022291514338731765
# 第14个自体半径为 0.00026194710680513093
# 第15个自体半径为 0.0002671491594886761
# 第16个自体半径为 0.0001517185317407294
# 第17个自体半径为 0.0004169591312458455
# 第18个自体半径为 3.2467946209221875e-05
# 第19个自体半径为 0.0002878215459453898
# 第20个自体半径为 0.00026183429837595704
# 第21个自体半径为 0.034072864103201185
# 第22个自体半径为 0.0003975737763072024
# 第23个自体半径为 0.0003429548795557921
# 第24个自体半径为 1.973714910721594e-06
# 第25个自体半径为 0.00015274853778341624
# 第26个自体半径为 0.00027619538752850616
# 第27个自体半径为 1.8199912520497312e-05
# 第28个自体半径为 0.0006957761622512679
# 第29个自体半径为 0.00018019566087089847
# 第30个自体半径为 0.0008116927389565058
# 第31个自体半径为 0.00028472550570665526
# 第32个自体半径为 0.0008253338242471666
# 第33个自体半径为 0.00019666146872899338
# 第34个自体半径为 0.0010270880471407017
# 第35个自体半径为 0.0008077230251024063
# 第36个自体半径为 0.0007858495811243555
# 第37个自体半径为 0.0053642317114844865
# 第38个自体半径为 0.0003131051903589996
# 第39个自体半径为 0.00020642256061730946
# 第40个自体半径为 5.908226417567394e-05
# 第41个自体半径为 0.0006367657654613481
# 第42个自体半径为 0.0025506872271404742
# 第43个自体半径为 0.0005451190258650209
# 第44个自体半径为 4.5619379934695336e-05
# 第45个自体半径为 0.0004543186891051981
# 第46个自体半径为 5.185582578651413e-05
# 第47个自体半径为 0.02359894624646993
# 第48个自体半径为 0.0007173893471565019
# 第49个自体半径为 3.233214453581511e-05
# 第50个自体半径为 0.0039075088575954335
# 第51个自体半径为 8.06772667531899e-05
# 第52个自体半径为 0.000749592476306137
# 第53个自体半径为 0.0005891216714904511
# 第54个自体半径为 0.0008137998798369032
# 第55个自体半径为 0.00045209483655857805
# 第56个自体半径为 0.00011632719399712438
# 第57个自体半径为 0.001159817031287097
# 第58个自体半径为 0.0023251951515546386
# 第59个自体半径为 1.5873758775694102e-06
# 第60个自体半径为 5.856381189359225e-05
# 第61个自体半径为 1e-06
# 第62个自体半径为 0.0003605577066610777
# 第63个自体半径为 5.9445362052391466e-06
# 第64个自体半径为 0.00016964862436081782
# 第65个自体半径为 0.00012530883675028953
# 第66个自体半径为 0.014824251216219506
# 第67个自体半径为 0.018988163036702994
# 第68个自体半径为 4.1180781783870126e-05
# 第69个自体半径为 0.0005183206144367893
# 第70个自体半径为 0.00024380943501206817
# 第71个自体半径为 0.00010435787838835308
# 第72个自体半径为 0.00017837777439227165
# 第73个自体半径为 2.213688241112336e-05
# 第74个自体半径为 0.0008404133741444985
# 第75个自体半径为 0.02867377607883754
# 第76个自体半径为 0.00032833685424436316
# 第77个自体半径为 0.021570468463891674
# 第78个自体半径为 0.0014848135662432643
# 第79个自体半径为 0.001088113068115137
# 第80个自体半径为 0.0011229356062103452
# 第81个自体半径为 0.00028670938323498136
# 第82个自体半径为 0.00021088575658319072
# 第83个自体半径为 0.0006772127982592303
# 第84个自体半径为 5.0238239021898495e-05
# 第85个自体半径为 9.48835396856696e-05
# 第86个自体半径为 1e-06
# 第87个自体半径为 8.683016972776002e-05
# 第88个自体半径为 0.00014865017172255708
# 第89个自体半径为 3.2257648142667086e-05
# 第90个自体半径为 0.0005567651627837171
# 第91个自体半径为 0.000645934289569841
# 第92个自体半径为 0.0009345030643071962
# 第93个自体半径为 0.0006353774143296578
# 第94个自体半径为 0.0005494769645847152
# 第95个自体半径为 0.00010380761783007081
# 第96个自体半径为 0.0006822740378327165
# 第97个自体半径为 0.00024251075537916485
# 第98个自体半径为 0.0072776942680413265
# 第99个自体半径为 0.00015090993949356155
# 第100个自体半径为 1e-06
# 第101个自体半径为 0.00032052905374849215
# 第102个自体半径为 0.00041951932555385545
# 第103个自体半径为 0.00760096930365379
# 第104个自体半径为 0.00023543094261400854
# 第105个自体半径为 0.0005526272098301409
# 第106个自体半径为 0.0026358513101824204
# 第107个自体半径为 0.000226897943797121
# 第108个自体半径为 7.690653936520133e-05
# 第109个自体半径为 0.001232675845976116
# 第110个自体半径为 0.002152150342202139
# 第111个自体半径为 0.0006744910436961568
# 第112个自体半径为 4.913816120049373e-05
# 第113个自体半径为 0.001102373982679429
# 第114个自体半径为 0.00026194710680513093
# 第115个自体半径为 0.0005518242730289189
# 第116个自体半径为 0.00010768864242598137
# 第117个自体半径为 0.00024438603453151597
# 第118个自体半径为 0.0005866871734366054
# 第119个自体半径为 0.01517870149350155
# 第120个自体半径为 0.00010920417824184914
# 第121个自体半径为 0.0004382410375125594
# 第122个自体半径为 1.2827156365612291e-05
# 第123个自体半径为 0.0014559200194526074
# 第124个自体半径为 3.9533259469855563e-05
# 第125个自体半径为 0.0009266770140249971
# 第126个自体半径为 7.3593333778056345e-06
# 第127个自体半径为 0.00038723959699325593
# 第128个自体半径为 5.742747162331684e-05
# 第129个自体半径为 5.0238239021898495e-05
# 第130个自体半径为 5.0238239021898495e-05
# 第131个自体半径为 0.0015421429725027175
# 第132个自体半径为 0.00018715010907078988
# 第133个自体半径为 1e-06
# 第134个自体半径为 1e-06
# 第135个自体半径为 8.013922902248872e-06
# 第136个自体半径为 0.00014358145222344618
# 第137个自体半径为 0.0006926075992974451
# 第138个自体半径为 0.0005088307405929725
# 第139个自体半径为 0.023937772291456584
# 第140个自体半径为 0.0013367659262030292
# 第141个自体半径为 0.0006560470043728851
# 第142个自体半径为 0.0043281875488912
# 第143个自体半径为 0.0007732430954122787
# 第144个自体半径为 0.0002848613988816853
# 第145个自体半径为 0.030538887581781336
# 第146个自体半径为 1e-06
# 第147个自体半径为 0.00015121603741869363
# 第148个自体半径为 0.00015367324578867774
# 第149个自体半径为 0.00018094730648623135
# 第150个自体半径为 9.38470358541532e-05
# 第151个自体半径为 1.461225828186424e-06
# 第152个自体半径为 0.0007131291113794366
# 第153个自体半径为 0.0005175879466030749
# 第154个自体半径为 0.010654768925908949
# 第155个自体半径为 0.000444280551703916
# 第156个自体半径为 0.0008514867904047779
# 第157个自体半径为 0.002953638802786781
# 第158个自体半径为 5.67595499024165e-05
# 第159个自体半径为 0.0009329460032190287
# 第160个自体半径为 0.00021268196618316623
# 第161个自体半径为 0.028594014495448315
# 第162个自体半径为 1.2897038945019161e-05
# 第163个自体半径为 0.00013559833330892976
# 第164个自体半径为 0.00010050367843148266
# 第165个自体半径为 0.009335912827941164
# 第166个自体半径为 0.00024251419803797503
# 第167个自体半径为 0.001627690608708635
# 第168个自体半径为 0.001962588567331563
# 第169个自体半径为 8.314204006806961e-05
# 第170个自体半径为 0.00027142737653540987
# 第171个自体半径为 0.0005019777969292673
# 第172个自体半径为 5.7019042618499635e-05
# 第173个自体半径为 1.0792803145785224e-06
# 第174个自体半径为 0.000385583551277372
# 第175个自体半径为 0.0011613062638427447
# 第176个自体半径为 0.00019727726149179956
# 第177个自体半径为 0.00011626392318775674
# 第178个自体半径为 0.0006708405902948364
# 第179个自体半径为 0.0001868141124571462
# 第180个自体半径为 1e-06
# 第181个自体半径为 0.028542227841908
# 第182个自体半径为 0.0008647533365908326
# 第183个自体半径为 0.00015056258883991918
# 第184个自体半径为 0.0003673435280556643
# 第185个自体半径为 0.002244177748561565
# 第186个自体半径为 0.0009223164864453074
# 第187个自体半径为 0.0011011439291522865
# 第188个自体半径为 3.9879107192511204e-05
# 第189个自体半径为 0.021172367530049533
# 第190个自体半径为 0.0010621498960170675
# 第191个自体半径为 0.00010656803611371435
# 第192个自体半径为 0.0005073805234171817
# 第193个自体半径为 7.780896407995138e-06
# 第194个自体半径为 0.0001995395046859824
# 第195个自体半径为 6.23009405679356e-05
# 第196个自体半径为 9.166260574155963e-05
# 第197个自体半径为 3.0192479309255305e-05
# 第198个自体半径为 0.0002983781026011619
# 第199个自体半径为 2.3356380662411e-05
# 实验进行49600/53874.
# 第0个自体半径为 0.016061678833671128
# 第1个自体半径为 0.001869626397480959
# 第2个自体半径为 0.0008267750798394663
# 第3个自体半径为 1e-06
# 第4个自体半径为 1e-06
# 第5个自体半径为 8.87712049908007e-05
# 第6个自体半径为 0.00029316263970152734
# 第7个自体半径为 5.67595499024165e-05
# 第8个自体半径为 0.0014212617216663242
# 第9个自体半径为 0.00039430504256233854
# 第10个自体半径为 0.0003156365270798835
# 第11个自体半径为 1.1327480109230086e-05
# 第12个自体半径为 0.01120928241647078
# 第13个自体半径为 1e-06
# 第14个自体半径为 0.0004427572451823692
# 第15个自体半径为 0.00017113611422418006
# 第16个自体半径为 0.00042971827624876675
# 第17个自体半径为 0.0004709713629335104
# 第18个自体半径为 0.0001868141124571462
# 第19个自体半径为 0.0010739950197718405
# 第20个自体半径为 0.003836042248039904
# 第21个自体半径为 0.000357931575457805
# 第22个自体半径为 1.793327045811096e-05
# 第23个自体半径为 0.00018998938389806218
# 第24个自体半径为 0.00011484208537333923
# 第25个自体半径为 0.01261972748600817
# 第26个自体半径为 0.0012831744540614668
# 第27个自体半径为 5.698121721148675e-05
# 第28个自体半径为 0.0005980796747032319
# 第29个自体半径为 0.0004451114112271104
# 第30个自体半径为 8.25892554153842e-05
# 第31个自体半径为 0.00019717003282993342
# 第32个自体半径为 0.005273140234576195
# 第33个自体半径为 1.5849961072891644e-06
# 第34个自体半径为 0.00121173194181387
# 第35个自体半径为 0.001916152306367051
# 第36个自体半径为 3.0565187596450015e-05
# 第37个自体半径为 0.0006411970715321274
# 第38个自体半径为 1.1246349706619547e-05
# 第39个自体半径为 0.00032786565418111574
# 第40个自体半径为 0.02696726013073287
# 第41个自体半径为 4.1638928006516105e-05
# 第42个自体半径为 5.2327021484473484e-05
# 第43个自体半径为 1e-06
# 第44个自体半径为 0.0025099966911839118
# 第45个自体半径为 0.00021253444433414344
# 第46个自体半径为 4.5179531934584605e-05
# 第47个自体半径为 4.9894659723604895e-05
# 第48个自体半径为 0.0006384447072498308
# 第49个自体半径为 0.0006390441919596448
# 第50个自体半径为 1e-06
# 第51个自体半径为 1e-06
# 第52个自体半径为 0.0004137765038750309
# 第53个自体半径为 0.0007174053229599467
# 第54个自体半径为 0.00028725693906000814
# 第55个自体半径为 0.009194971119486917
# 第56个自体半径为 0.00047794627478434646
# 第57个自体半径为 0.0010348365264515758
# 第58个自体半径为 0.0009222362446239632
# 第59个自体半径为 0.0005132764563459942
# 第60个自体半径为 0.00010387443155562879
# 第61个自体半径为 0.0001606338759370337
# 第62个自体半径为 1e-06
# 第63个自体半径为 0.0009789020982176972
# 第64个自体半径为 0.0005802152449098503
# 第65个自体半径为 0.0004119832818717389
# 第66个自体半径为 0.0005172025266855915
# 第67个自体半径为 8.726498368517263e-05
# 第68个自体半径为 4.4425772295322775e-05
# 第69个自体半径为 5.9069138986473534e-05
# 第70个自体半径为 0.0002405846984044332
# 第71个自体半径为 2.7435836135777248e-05
# 第72个自体半径为 4.859723995318658e-05
# 第73个自体半径为 0.03255768096355973
# 第74个自体半径为 0.00048504802075495697
# 第75个自体半径为 0.0007142991813535413
# 第76个自体半径为 0.00027986793388195944
# 第77个自体半径为 0.0006491806183914937
# 第78个自体半径为 0.0022757119280490735
# 第79个自体半径为 0.0003015743756853071
# 第80个自体半径为 0.00025307099843330645
# 第81个自体半径为 6.666041246946139e-05
# 第82个自体半径为 0.002104650310676246
# 第83个自体半径为 0.0001436438542475915
# 第84个自体半径为 0.0008489969743415549
# 第85个自体半径为 1.482611624058538e-05
# 第86个自体半径为 0.00026194710680513093
# 第87个自体半径为 0.029659101769320836
# 第88个自体半径为 2.1192757089414645e-05
# 第89个自体半径为 0.00011671100854627639
# 第90个自体半径为 0.0010380716446780544
# 第91个自体半径为 0.00024438603453151597
# 第92个自体半径为 0.0008686781190289736
# 第93个自体半径为 5.9865605649098876e-05
# 第94个自体半径为 0.0006998414323729289
# 第95个自体半径为 0.00035700157735015604
# 第96个自体半径为 0.0007368269596375691
# 第97个自体半径为 8.331485618039585e-05
# 第98个自体半径为 5.6551475355509154e-05
# 第99个自体半径为 0.0001991797964734456
# 第100个自体半径为 0.0003253212408482654
# 第101个自体半径为 0.00025478283747780954
# 第102个自体半径为 0.00023339143380298995
# 第103个自体半径为 2.832834981890834e-05
# 第104个自体半径为 0.0003464739509582268
# 第105个自体半径为 4.124729704738892e-05
# 第106个自体半径为 0.00032461664802271693
# 第107个自体半径为 0.02136425839207957
# 第108个自体半径为 0.001265960618709916
# 第109个自体半径为 0.001879829170697449
# 第110个自体半径为 0.001999819624590508
# 第111个自体半径为 0.0004406194786773093
# 第112个自体半径为 0.00044377592066782967
# 第113个自体半径为 7.898908564913976e-05
# 第114个自体半径为 0.0001675379951148889
# 第115个自体半径为 0.00042774193369752396
# 第116个自体半径为 0.000311559441000299
# 第117个自体半径为 0.00013670264449747253
# 第118个自体半径为 0.00018588179100964222
# 第119个自体半径为 0.000180921284698668
# 第120个自体半径为 0.004597256502100933
# 第121个自体半径为 0.0011915053813233395
# 第122个自体半径为 0.00015129578905267215
# 第123个自体半径为 0.00014650079943226053
# 第124个自体半径为 8.040781734753989e-06
# 第125个自体半径为 0.0002612957546299933
# 第126个自体半径为 0.0001390669332081395
# 第127个自体半径为 0.0004494922502034968
# 第128个自体半径为 0.027457907594392917
# 第129个自体半径为 0.0004774541290688956
# 第130个自体半径为 0.00011125795962700875
# 第131个自体半径为 3.896646529258651e-06
# 第132个自体半径为 0.00013207117562229786
# 第133个自体半径为 0.0012197625472004593
# 第134个自体半径为 4.115047327869489e-05
# 第135个自体半径为 3.615383006948846e-05
# 第136个自体半径为 4.135817222242161e-06
# 第137个自体半径为 0.008464657824003494
# 第138个自体半径为 0.0011881789173786453
# 第139个自体半径为 0.015630619743134917
# 第140个自体半径为 6.580262687250321e-05
# 第141个自体半径为 0.000680552680230811
# 第142个自体半径为 0.0022596817051245607
# 第143个自体半径为 3.955578846696328e-05
# 第144个自体半径为 1e-06
# 第145个自体半径为 0.00809995733829627
# 第146个自体半径为 4.2274210877372214e-05
# 第147个自体半径为 0.0017660426163358584
# 第148个自体半径为 0.002134186401522064
# 第149个自体半径为 1e-06
# 第150个自体半径为 0.00018730570658289774
# 第151个自体半径为 0.0006476840480018607
# 第152个自体半径为 1e-06
# 第153个自体半径为 0.00011472740430778902
# 第154个自体半径为 0.0005049903001916314
# 第155个自体半径为 0.00038051154003149076
# 第156个自体半径为 6.402989085106327e-05
# 第157个自体半径为 0.020083673105950387
# 第158个自体半径为 0.00031159598138869976
# 第159个自体半径为 1.1246349706619547e-05
# 第160个自体半径为 3.9210839230517544e-05
# 第161个自体半径为 0.0005754873598157876
# 第162个自体半径为 1e-06
# 第163个自体半径为 1.7608983445142618e-05
# 第164个自体半径为 0.0014406498761897833
# 第165个自体半径为 2.7190662938888784e-05
# 第166个自体半径为 0.01523232318486853
# 第167个自体半径为 0.00027813259027137865
# 第168个自体半径为 1.748145016814524e-05
# 第169个自体半径为 0.0001811933197597125
# 第170个自体半径为 0.00037214411802879196
# 第171个自体半径为 0.0004225445118218952
# 第172个自体半径为 0.00018200452467781117
# 第173个自体半径为 0.0012300589493315103
# 第174个自体半径为 2.289933007198304e-05
# 第175个自体半径为 1e-06
# 第176个自体半径为 0.00024256408180699072
# 第177个自体半径为 0.0006640135729548721
# 第178个自体半径为 0.0006295393629677286
# 第179个自体半径为 0.00012654507217071704
# 第180个自体半径为 0.0013204743207551474
# 第181个自体半径为 0.00024438603453151597
# 第182个自体半径为 4.368920467594946e-05
# 第183个自体半径为 0.0006211391178172118
# 第184个自体半径为 0.0008682055808173788
# 第185个自体半径为 0.0011768857116411053
# 第186个自体半径为 0.0005831402797506508
# 第187个自体半径为 6.9584418172398e-05
# 第188个自体半径为 2.4020366793960192e-05
# 第189个自体半径为 0.00019206258459998518
# 第190个自体半径为 0.0733845904983352
# 第191个自体半径为 0.00044802663957650105
# 第192个自体半径为 0.00010492923126865148
# 第193个自体半径为 0.0006731699934119121
# 第194个自体半径为 0.00022493677593806894
# 第195个自体半径为 0.0006798900705129457
# 第196个自体半径为 0.00013821636385751552
# 第197个自体半径为 7.027987858035854e-05
# 第198个自体半径为 0.004014386147191547
# 第199个自体半径为 0.0006493003709291264
# 实验进行49800/53874.
# 第0个自体半径为 0.0005984386153157536
# 第1个自体半径为 0.00032616058451960897
# 第2个自体半径为 1e-06
# 第3个自体半径为 0.0002785183301563824
# 第4个自体半径为 4.669433112025273e-05
# 第5个自体半径为 4.420533508832184e-05
# 第6个自体半径为 0.0003999451087837525
# 第7个自体半径为 8.747378320304893e-05
# 第8个自体半径为 1e-06
# 第9个自体半径为 0.0008207415108911791
# 第10个自体半径为 0.006178716383837466
# 第11个自体半径为 0.001177863313737865
# 第12个自体半径为 0.0002573537602993739
# 第13个自体半径为 0.02962216337215887
# 第14个自体半径为 0.00010261285828923951
# 第15个自体半径为 0.0013670051001884588
# 第16个自体半径为 0.00018174849854106474
# 第17个自体半径为 0.00021088575658319072
# 第18个自体半径为 0.0001448911081262232
# 第19个自体半径为 1e-06
# 第20个自体半径为 0.002830873014221445
# 第21个自体半径为 0.0002553183198330936
# 第22个自体半径为 0.00591243598189834
# 第23个自体半径为 0.00015231412213971267
# 第24个自体半径为 0.00017115602734052047
# 第25个自体半径为 0.00026194710680513093
# 第26个自体半径为 0.0004533086956506915
# 第27个自体半径为 0.0009845932263268403
# 第28个自体半径为 0.0012800369278283977
# 第29个自体半径为 0.0001190126751580844
# 第30个自体半径为 0.006342366338178796
# 第31个自体半径为 6.933609579811512e-05
# 第32个自体半径为 1e-06
# 第33个自体半径为 0.0002826655004089856
# 第34个自体半径为 3.787874442728108e-05
# 第35个自体半径为 0.00023255823364277747
# 第36个自体半径为 0.0005839488028794349
# 第37个自体半径为 0.0018562669620119138
# 第38个自体半径为 0.00012780836797744843
# 第39个自体半径为 0.00198152383261463
# 第40个自体半径为 0.0014906063203363599
# 第41个自体半径为 0.00021088575658319072
# 第42个自体半径为 5.261376136658424e-06
# 第43个自体半径为 0.0006643524151953664
# 第44个自体半径为 0.00023571933415656078
# 第45个自体半径为 0.0001675485226128687
# 第46个自体半径为 1e-06
# 第47个自体半径为 0.09244657292816934
# 第48个自体半径为 0.0006991002057673243
# 第49个自体半径为 0.0004744779042919659
# 第50个自体半径为 0.0007396838561067765
# 第51个自体半径为 0.0005757165939476993
# 第52个自体半径为 8.067622914547535e-05
# 第53个自体半径为 4.314358267250815e-05
# 第54个自体半径为 3.9967185267682874e-05
# 第55个自体半径为 5.821324333601444e-05
# 第56个自体半径为 4.152241922351858e-05
# 第57个自体半径为 0.000499164806014026
# 第58个自体半径为 5.1112064629554476e-05
# 第59个自体半径为 0.0004440253755871996
# 第60个自体半径为 0.02349552468946994
# 第61个自体半径为 0.0006021273516362624
# 第62个自体半径为 1e-06
# 第63个自体半径为 0.0002877041246974956
# 第64个自体半径为 7.566110561459901e-05
# 第65个自体半径为 0.0006587321960507683
# 第66个自体半径为 0.02640059220308971
# 第67个自体半径为 0.0002545914850131449
# 第68个自体半径为 0.0019587024359260428
# 第69个自体半径为 0.031682010787194965
# 第70个自体半径为 0.0013081409476212984
# 第71个自体半径为 0.02881502028230476
# 第72个自体半径为 6.53101695054771e-05
# 第73个自体半径为 1.8829638181047635e-05
# 第74个自体半径为 0.0001971723687492762
# 第75个自体半径为 0.0026079812213741296
# 第76个自体半径为 0.00782729471072949
# 第77个自体半径为 0.00014352927949202876
# 第78个自体半径为 0.030620436120935863
# 第79个自体半径为 0.00039262058914821187
# 第80个自体半径为 0.0004555268715800423
# 第81个自体半径为 0.0010695454646985254
# 第82个自体半径为 0.00036077911227963116
# 第83个自体半径为 0.00016045185419946822
# 第84个自体半径为 0.00046865085719862765
# 第85个自体半径为 8.283876697986269e-05
# 第86个自体半径为 0.0001590944012067837
# 第87个自体半径为 0.00025615849200922994
# 第88个自体半径为 0.001972299544679184
# 第89个自体半径为 4.291138076029988e-05
# 第90个自体半径为 0.00011034906749580174
# 第91个自体半径为 0.00026194710680513093
# 第92个自体半径为 1e-06
# 第93个自体半径为 0.00026194710680513093
# 第94个自体半径为 0.00036201695869829984
# 第95个自体半径为 0.0004906914755897151
# 第96个自体半径为 0.0003527573360169418
# 第97个自体半径为 5.0134291938005743e-05
# 第98个自体半径为 1e-06
# 第99个自体半径为 0.00017935422858763735
# 第100个自体半径为 0.00013635566858784303
# 第101个自体半径为 0.00017166817870692538
# 第102个自体半径为 0.00012499685121004531
# 第103个自体半径为 0.0004984150359767321
# 第104个自体半径为 9.941100599623045e-05
# 第105个自体半径为 0.00021944602213588312
# 第106个自体半径为 1e-06
# 第107个自体半径为 0.00013588198293810777
# 第108个自体半径为 0.0013460684146415804
# 第109个自体半径为 4.55309375501941e-05
# 第110个自体半径为 0.01944095186891206
# 第111个自体半径为 0.00024438603453151597
# 第112个自体半径为 1e-06
# 第113个自体半径为 0.0002227859900066066
# 第114个自体半径为 0.0031591971047400576
# 第115个自体半径为 0.0007168509894372605
# 第116个自体半径为 1.6432542227218849e-06
# 第117个自体半径为 0.0003744620358185611
# 第118个自体半径为 6.903083184746894e-05
# 第119个自体半径为 0.08926586780632755
# 第120个自体半径为 4.160144147380977e-05
# 第121个自体半径为 0.00029315836048756
# 第122个自体半径为 0.002212842048406999
# 第123个自体半径为 0.00021560611398003108
# 第124个自体半径为 0.00019694722553060428
# 第125个自体半径为 0.00016157469600528915
# 第126个自体半径为 0.002750799360469264
# 第127个自体半径为 1.7373268245290256e-05
# 第128个自体半径为 5.6968662275966267e-05
# 第129个自体半径为 0.0001875527531009898
# 第130个自体半径为 0.006796083189363386
# 第131个自体半径为 0.0001125780908693892
# 第132个自体半径为 0.00010285973835997929
# 第133个自体半径为 0.00032836446555552717
# 第134个自体半径为 1.2897038945019161e-05
# 第135个自体半径为 0.0003980367058584013
# 第136个自体半径为 9.205904401786927e-05
# 第137个自体半径为 0.00024221946861232392
# 第138个自体半径为 0.0006303206889322346
# 第139个自体半径为 0.001720475493330155
# 第140个自体半径为 9.583079379164889e-05
# 第141个自体半径为 0.027914146856804756
# 第142个自体半径为 0.029805199464783546
# 第143个自体半径为 3.1793557654744924e-05
# 第144个自体半径为 6.440183347865737e-05
# 第145个自体半径为 0.0008816727399424187
# 第146个自体半径为 0.00035582986807318115
# 第147个自体半径为 3.5663307432297686e-06
# 第148个自体半径为 0.00026194710680513093
# 第149个自体半径为 0.0008818956522450983
# 第150个自体半径为 0.00016044868545045534
# 第151个自体半径为 0.00018839426246998367
# 第152个自体半径为 1e-06
# 第153个自体半径为 0.00034512152126187534
# 第154个自体半径为 0.0004302272099572378
# 第155个自体半径为 5.037242273308726e-05
# 第156个自体半径为 0.00012406464032878512
# 第157个自体半径为 0.011203630023641697
# 第158个自体半径为 0.004049280678327442
# 第159个自体半径为 4.919085808426438e-05
# 第160个自体半径为 2.832086722386238e-05
# 第161个自体半径为 0.0003072591314088225
# 第162个自体半径为 0.0004552055321470958
# 第163个自体半径为 0.014062453861356301
# 第164个自体半径为 0.0004616044249924552
# 第165个自体半径为 2.186867124242149e-05
# 第166个自体半径为 0.00014939935461364431
# 第167个自体半径为 0.0017932732043008663
# 第168个自体半径为 8.189035052723495e-05
# 第169个自体半径为 0.00028258347063847187
# 第170个自体半径为 1.1790764485119789e-06
# 第171个自体半径为 0.00036883048781776964
# 第172个自体半径为 0.0004896306233621659
# 第173个自体半径为 0.0013359827269043066
# 第174个自体半径为 0.0009111327601616803
# 第175个自体半径为 0.028362472838934588
# 第176个自体半径为 1.1278712433675683e-06
# 第177个自体半径为 0.0001690621522200722
# 第178个自体半径为 0.00042950485389324175
# 第179个自体半径为 8.834627851642491e-05
# 第180个自体半径为 0.00025158232908232154
# 第181个自体半径为 0.03455524790281164
# 第182个自体半径为 0.000122801164187358
# 第183个自体半径为 0.00014686279937600204
# 第184个自体半径为 0.0011541225996431798
# 第185个自体半径为 0.00011653287936331687
# 第186个自体半径为 0.00016108558204061172
# 第187个自体半径为 0.0008620889131352593
# 第188个自体半径为 1e-06
# 第189个自体半径为 0.0001358424242233997
# 第190个自体半径为 0.002449637092498951
# 第191个自体半径为 0.0009774891968796484
# 第192个自体半径为 0.0016192482585926408
# 第193个自体半径为 0.15858390174407883
# 第194个自体半径为 0.02953094546715496
# 第195个自体半径为 5.318941674935902e-05
# 第196个自体半径为 0.0012017338262376796
# 第197个自体半径为 0.0003218559967796438
# 第198个自体半径为 0.00014342635364325175
# 第199个自体半径为 0.00016209672320996655
# 实验进行50000/53874.
# 第0个自体半径为 0.0010993254360679636
# 第1个自体半径为 0.0006053276337801233
# 第2个自体半径为 0.0002968151174115855
# 第3个自体半径为 0.001067642041597686
# 第4个自体半径为 0.056596282274061424
# 第5个自体半径为 0.00026096808478734526
# 第6个自体半径为 0.0017036779717873448
# 第7个自体半径为 0.00030512427185420857
# 第8个自体半径为 7.2064191667896e-05
# 第9个自体半径为 0.0056169784938165145
# 第10个自体半径为 0.0001379463253198527
# 第11个自体半径为 0.014167843569643564
# 第12个自体半径为 4.503066440882237e-05
# 第13个自体半径为 0.00011699057857261147
# 第14个自体半径为 5.026370848064218e-05
# 第15个自体半径为 0.00012465463461514188
# 第16个自体半径为 0.0018272321333376916
# 第17个自体半径为 0.0002915466054795406
# 第18个自体半径为 4.782466689604239e-05
# 第19个自体半径为 0.0001842324837798142
# 第20个自体半径为 5.037242273308726e-05
# 第21个自体半径为 0.0009937849870906084
# 第22个自体半径为 6.79524549316289e-05
# 第23个自体半径为 0.00021905866680617755
# 第24个自体半径为 0.00020871762038732265
# 第25个自体半径为 5.471968534159381e-05
# 第26个自体半径为 1.646868218494437e-05
# 第27个自体半径为 0.002065326560285667
# 第28个自体半径为 0.00012528093826805675
# 第29个自体半径为 0.00014093701290674687
# 第30个自体半径为 0.00011323409304274885
# 第31个自体半径为 0.00012549560544713664
# 第32个自体半径为 0.00015434817839378773
# 第33个自体半径为 7.898908564913976e-05
# 第34个自体半径为 0.00022531916474405897
# 第35个自体半径为 8.023559268069053e-06
# 第36个自体半径为 1e-06
# 第37个自体半径为 0.00012995846914396026
# 第38个自体半径为 0.00020343135636196678
# 第39个自体半径为 0.0013228063081552745
# 第40个自体半径为 0.013073580530222095
# 第41个自体半径为 0.0007321775420740935
# 第42个自体半径为 0.00014482116358944034
# 第43个自体半径为 0.0008882049882651827
# 第44个自体半径为 0.0017413415063324866
# 第45个自体半径为 5.220309256299495e-05
# 第46个自体半径为 0.0004062365907778623
# 第47个自体半径为 0.0006218840026072943
# 第48个自体半径为 0.02901879887307883
# 第49个自体半径为 8.193486646402475e-05
# 第50个自体半径为 0.0014771875791734874
# 第51个自体半径为 0.0005266242935517378
# 第52个自体半径为 0.00020504738136668986
# 第53个自体半径为 0.0008501991906033528
# 第54个自体半径为 0.028159711857815548
# 第55个自体半径为 0.00010475498355199596
# 第56个自体半径为 0.00039859394153657444
# 第57个自体半径为 0.0004314374188360639
# 第58个自体半径为 0.0007467080301625846
# 第59个自体半径为 5.3971889621516274e-05
# 第60个自体半径为 8.09596735760115e-05
# 第61个自体半径为 1e-06
# 第62个自体半径为 0.0006723899030926816
# 第63个自体半径为 0.00021573906271130024
# 第64个自体半径为 0.013530170793329554
# 第65个自体半径为 0.000180921284698668
# 第66个自体半径为 0.0022445089099524533
# 第67个自体半径为 2.7140165215374177e-06
# 第68个自体半径为 0.000481052301843248
# 第69个自体半径为 0.0030476278448533793
# 第70个自体半径为 0.0002846988084591837
# 第71个自体半径为 0.0004194855735153946
# 第72个自体半径为 0.0006760960235601078
# 第73个自体半径为 7.194123987653279e-05
# 第74个自体半径为 0.0020027828038016162
# 第75个自体半径为 1e-06
# 第76个自体半径为 0.0002088822011842978
# 第77个自体半径为 0.000840156814928729
# 第78个自体半径为 0.0037441552136935705
# 第79个自体半径为 0.007224895491837859
# 第80个自体半径为 6.060734493043848e-05
# 第81个自体半径为 0.0004969600063799992
# 第82个自体半径为 0.0014338829063423105
# 第83个自体半径为 0.0002029499790860808
# 第84个自体半径为 3.558601959770773e-06
# 第85个自体半径为 0.00013282917989893396
# 第86个自体半径为 0.002325300835328503
# 第87个自体半径为 0.00013387254965810378
# 第88个自体半径为 7.574141725260892e-05
# 第89个自体半径为 0.0006230724997120407
# 第90个自体半径为 0.0007992039303218374
# 第91个自体半径为 0.002375540477290578
# 第92个自体半径为 0.00012201401543868585
# 第93个自体半径为 0.0006032613747471846
# 第94个自体半径为 5.1448933284477105e-05
# 第95个自体半径为 0.0015758835631321303
# 第96个自体半径为 0.00048631687574514224
# 第97个自体半径为 0.0008795903472326052
# 第98个自体半径为 2.556426120931268e-05
# 第99个自体半径为 0.02978409486834695
# 第100个自体半径为 0.00017959514879370875
# 第101个自体半径为 0.0007745805150977096
# 第102个自体半径为 0.0006046010837859318
# 第103个自体半径为 0.00043526988551285814
# 第104个自体半径为 0.000886455195606958
# 第105个自体半径为 0.0007630965320828673
# 第106个自体半径为 0.00028470959622048153
# 第107个自体半径为 7.437534607903935e-05
# 第108个自体半径为 0.0011401968125780782
# 第109个自体半径为 0.0003021832576912873
# 第110个自体半径为 4.1848658377117745e-06
# 第111个自体半径为 0.0004372602376134658
# 第112个自体半径为 0.00022201843041979696
# 第113个自体半径为 0.0004813241809255577
# 第114个自体半径为 0.000318872413103077
# 第115个自体半径为 0.0006075093247092094
# 第116个自体半径为 0.025272956795981787
# 第117个自体半径为 0.002134028576753615
# 第118个自体半径为 0.001909089157920724
# 第119个自体半径为 0.13607859115963594
# 第120个自体半径为 0.0008350773786678765
# 第121个自体半径为 0.00037471396834031715
# 第122个自体半径为 0.0003089540189663044
# 第123个自体半径为 0.039146904930164796
# 第124个自体半径为 1e-06
# 第125个自体半径为 0.000331224284732512
# 第126个自体半径为 0.00021031201654385351
# 第127个自体半径为 0.0008304793227396186
# 第128个自体半径为 1.610015129709909e-06
# 第129个自体半径为 0.0007112888264059297
# 第130个自体半径为 0.00010913623276132133
# 第131个自体半径为 8.700619204273862e-05
# 第132个自体半径为 0.0005155737529716841
# 第133个自体半径为 0.00014923775247333937
# 第134个自体半径为 0.00020228825242693635
# 第135个自体半径为 0.0001202313342603577
# 第136个自体半径为 0.0001935124506514457
# 第137个自体半径为 6.236281764981871e-05
# 第138个自体半径为 5.418376022892283e-05
# 第139个自体半径为 4.206464257250384e-05
# 第140个自体半径为 4.9891259603040644e-05
# 第141个自体半径为 0.0011018147239794992
# 第142个自体半径为 9.694703947090528e-05
# 第143个自体半径为 0.0007117517403213505
# 第144个自体半径为 0.00016919493375331507
# 第145个自体半径为 1.7794663231497662e-05
# 第146个自体半径为 1e-06
# 第147个自体半径为 0.0003312658385280023
# 第148个自体半径为 1e-06
# 第149个自体半径为 0.00048242327616599616
# 第150个自体半径为 0.0004218419057928121
# 第151个自体半径为 0.0005221013310110011
# 第152个自体半径为 7.579968632032827e-05
# 第153个自体半径为 0.0005815803094774799
# 第154个自体半径为 0.00046869265202242243
# 第155个自体半径为 0.00018444975438354892
# 第156个自体半径为 1.5618080426388323e-05
# 第157个自体半径为 0.00020296908802875497
# 第158个自体半径为 9.516780384104662e-05
# 第159个自体半径为 0.0002102492227089079
# 第160个自体半径为 0.0006300341180618625
# 第161个自体半径为 0.14778733951238093
# 第162个自体半径为 0.0001617702493886218
# 第163个自体半径为 7.541902753219308e-05
# 第164个自体半径为 0.03446792599734094
# 第165个自体半径为 4.206464257250384e-05
# 第166个自体半径为 0.0020739048601762055
# 第167个自体半径为 0.0005725322090650137
# 第168个自体半径为 4.395829545220028e-05
# 第169个自体半径为 0.00872477570460189
# 第170个自体半径为 4.5151409773400265e-05
# 第171个自体半径为 0.0020547956999005927
# 第172个自体半径为 0.0005355196036204362
# 第173个自体半径为 1e-06
# 第174个自体半径为 0.00053623575692371
# 第175个自体半径为 0.0008104408616362476
# 第176个自体半径为 0.0052513249916733735
# 第177个自体半径为 0.00022099679344144763
# 第178个自体半径为 0.0001114935675234046
# 第179个自体半径为 0.0001509223444858347
# 第180个自体半径为 0.0005994733624861161
# 第181个自体半径为 0.00030515659722097694
# 第182个自体半径为 3.4141506578277716e-05
# 第183个自体半径为 0.00046212571064064726
# 第184个自体半径为 6.153809468320223e-05
# 第185个自体半径为 0.0006709856230655506
# 第186个自体半径为 1e-06
# 第187个自体半径为 5.037242273308726e-05
# 第188个自体半径为 0.00010998211488057092
# 第189个自体半径为 8.969199424683003e-06
# 第190个自体半径为 0.00012172075567402862
# 第191个自体半径为 0.00011600157144697754
# 第192个自体半径为 3.771042607220682e-05
# 第193个自体半径为 0.0003762075627068391
# 第194个自体半径为 0.0004885105963948491
# 第195个自体半径为 8.129391072300867e-05
# 第196个自体半径为 0.0012471996376022254
# 第197个自体半径为 0.00661724633862824
# 第198个自体半径为 0.0005023369591367438
# 第199个自体半径为 3.1129889919985765e-05
# 实验进行50200/53874.
# 第0个自体半径为 0.00032537935628675963
# 第1个自体半径为 0.0010533395780491484
# 第2个自体半径为 7.898908564913976e-05
# 第3个自体半径为 7.120766340882178e-05
# 第4个自体半径为 0.00013877206611737102
# 第5个自体半径为 1.2951158039355734e-06
# 第6个自体半径为 0.027819025669447432
# 第7个自体半径为 0.0006705073481497573
# 第8个自体半径为 0.000523825506435682
# 第9个自体半径为 0.0001449609963209915
# 第10个自体半径为 0.000387892469641675
# 第11个自体半径为 0.0006245703234559011
# 第12个自体半径为 0.0012875439854391035
# 第13个自体半径为 0.0005764899825322387
# 第14个自体半径为 0.0006095172172354235
# 第15个自体半径为 0.0008519888575742215
# 第16个自体半径为 0.0007927089705017622
# 第17个自体半径为 1e-06
# 第18个自体半径为 0.0002848695053890694
# 第19个自体半径为 1e-06
# 第20个自体半径为 4.600098516391439e-05
# 第21个自体半径为 0.0026320057208044103
# 第22个自体半径为 0.00019953183967439818
# 第23个自体半径为 5.7219342356517934e-05
# 第24个自体半径为 0.0007269654003123836
# 第25个自体半径为 0.0007685455858315472
# 第26个自体半径为 0.000917978103083919
# 第27个自体半径为 0.00034998538873086713
# 第28个自体半径为 0.0026977223000646746
# 第29个自体半径为 0.0012252511666674137
# 第30个自体半径为 4.9499859849363634e-05
# 第31个自体半径为 0.00030339196182214913
# 第32个自体半径为 0.0006759366705827696
# 第33个自体半径为 1e-06
# 第34个自体半径为 0.00036525742580026036
# 第35个自体半径为 0.0003987997862178505
# 第36个自体半径为 0.0004513494698180513
# 第37个自体半径为 0.015699036633555836
# 第38个自体半径为 0.0285630642976975
# 第39个自体半径为 0.0002422699886402083
# 第40个自体半径为 0.000492435883632901
# 第41个自体半径为 0.0003310608603615312
# 第42个自体半径为 0.001345169615212465
# 第43个自体半径为 3.032340537365563e-06
# 第44个自体半径为 0.006069239638854635
# 第45个自体半径为 0.00020474786583743218
# 第46个自体半径为 0.01068404469852315
# 第47个自体半径为 0.002033689174064988
# 第48个自体半径为 1e-06
# 第49个自体半径为 0.0008716044341891176
# 第50个自体半径为 2.8517667337137662e-05
# 第51个自体半径为 0.18307330754736142
# 第52个自体半径为 0.0002220800591320015
# 第53个自体半径为 0.0036500124387154995
# 第54个自体半径为 0.0006389994246561865
# 第55个自体半径为 0.0002845420403025501
# 第56个自体半径为 0.021054146695841176
# 第57个自体半径为 0.00032161495622185524
# 第58个自体半径为 5.051343861647805e-05
# 第59个自体半径为 0.0009034010151024558
# 第60个自体半径为 0.00027519256522860096
# 第61个自体半径为 0.00027043706986250906
# 第62个自体半径为 0.0008040736987602426
# 第63个自体半径为 1.2827156365612291e-05
# 第64个自体半径为 0.00022079724260847788
# 第65个自体半径为 0.00011484207377247277
# 第66个自体半径为 0.0003579691372165221
# 第67个自体半径为 0.0002956958769093739
# 第68个自体半径为 6.496154343549116e-06
# 第69个自体半径为 0.0001699191851391807
# 第70个自体半径为 0.00023875058934307104
# 第71个自体半径为 0.00031069599942211033
# 第72个自体半径为 0.00012864807593530295
# 第73个自体半径为 0.0033422313706244072
# 第74个自体半径为 1.7676376457513893e-05
# 第75个自体半径为 0.00016317817889044696
# 第76个自体半径为 5.244425524139784e-06
# 第77个自体半径为 0.0003498702695994944
# 第78个自体半径为 0.000948474288143019
# 第79个自体半径为 1e-06
# 第80个自体半径为 9.58127098382248e-05
# 第81个自体半径为 3.419105449632224e-05
# 第82个自体半径为 0.000231208964461436
# 第83个自体半径为 7.835508069827503e-05
# 第84个自体半径为 7.625339435525565e-05
# 第85个自体半径为 8.533974308675815e-05
# 第86个自体半径为 1e-06
# 第87个自体半径为 0.0001221934550876348
# 第88个自体半径为 7.75468275776771e-05
# 第89个自体半径为 0.0002162092023481203
# 第90个自体半径为 0.0013155384927764648
# 第91个自体半径为 8.792910260670027e-05
# 第92个自体半径为 0.0008046685890251907
# 第93个自体半径为 0.035631095251941615
# 第94个自体半径为 0.0005857774887377556
# 第95个自体半径为 0.0007299376057004602
# 第96个自体半径为 0.0002481901108072808
# 第97个自体半径为 0.021999209485327693
# 第98个自体半径为 0.004372007005247313
# 第99个自体半径为 0.0003134847270752521
# 第100个自体半径为 0.00026194710680513093
# 第101个自体半径为 0.0014130502042560501
# 第102个自体半径为 7.164890489487456e-05
# 第103个自体半径为 0.0010096058237102398
# 第104个自体半径为 1e-06
# 第105个自体半径为 1e-06
# 第106个自体半径为 0.00011612575065286076
# 第107个自体半径为 0.0028448947757624765
# 第108个自体半径为 0.00031503689159905537
# 第109个自体半径为 9.92018352789534e-05
# 第110个自体半径为 5.4575713929461513e-05
# 第111个自体半径为 0.0004439699899221755
# 第112个自体半径为 1e-06
# 第113个自体半径为 0.00044185924046612245
# 第114个自体半径为 0.0007247711352520055
# 第115个自体半径为 0.00040568031854623513
# 第116个自体半径为 0.00020740157052205827
# 第117个自体半径为 0.0004306508700635303
# 第118个自体半径为 0.00024672616062228713
# 第119个自体半径为 0.0005495627131353009
# 第120个自体半径为 5.588504047075164e-05
# 第121个自体半径为 0.0027400424366520377
# 第122个自体半径为 7.898908564913976e-05
# 第123个自体半径为 0.0007996484729241199
# 第124个自体半径为 0.000405201848176529
# 第125个自体半径为 0.00029369997836214387
# 第126个自体半径为 0.00022051752029356143
# 第127个自体半径为 3.228569642055235e-06
# 第128个自体半径为 0.0008536218859603116
# 第129个自体半径为 0.00026194710680513093
# 第130个自体半径为 0.00011549675682572932
# 第131个自体半径为 0.0007972800326028742
# 第132个自体半径为 0.000482329628862545
# 第133个自体半径为 5.5116255005694646e-05
# 第134个自体半径为 0.000301505056451927
# 第135个自体半径为 9.529488253858743e-05
# 第136个自体半径为 0.0006199133995533685
# 第137个自体半径为 0.0002320255316460845
# 第138个自体半径为 0.00020339944914537822
# 第139个自体半径为 0.00012132073386135222
# 第140个自体半径为 0.0011314393241181804
# 第141个自体半径为 0.03272781926321104
# 第142个自体半径为 0.00011867291931601516
# 第143个自体半径为 0.000849925416611218
# 第144个自体半径为 2.11276186372433e-06
# 第145个自体半径为 0.00021858900864293233
# 第146个自体半径为 0.0036039165144639276
# 第147个自体半径为 0.00018939491035689456
# 第148个自体半径为 4.604663755583982e-06
# 第149个自体半径为 0.006356303653925712
# 第150个自体半径为 7.395675534039729e-05
# 第151个自体半径为 0.0001386413474792169
# 第152个自体半径为 0.0007627094835075722
# 第153个自体半径为 1e-06
# 第154个自体半径为 0.0030093259469703435
# 第155个自体半径为 4.337830272648521e-05
# 第156个自体半径为 0.0002196973597869233
# 第157个自体半径为 0.001071201096914397
# 第158个自体半径为 0.0009757050987943851
# 第159个自体半径为 4.4685905447674774e-05
# 第160个自体半径为 0.0011022675652303945
# 第161个自体半径为 0.0003013977111396065
# 第162个自体半径为 4.600623417610252e-05
# 第163个自体半径为 0.00028470959622048153
# 第164个自体半径为 0.00014366377242604948
# 第165个自体半径为 0.00010357642259216269
# 第166个自体半径为 0.0006433428526297325
# 第167个自体半径为 0.0007565111878031661
# 第168个自体半径为 1e-06
# 第169个自体半径为 0.00010925436933638425
# 第170个自体半径为 0.002327567512392738
# 第171个自体半径为 0.000858196652879376
# 第172个自体半径为 5.598627431297018e-05
# 第173个自体半径为 0.001978194451140969
# 第174个自体半径为 0.00021717756464595736
# 第175个自体半径为 0.0003686234340184862
# 第176个自体半径为 0.00014651373459397994
# 第177个自体半径为 0.002473164078247176
# 第178个自体半径为 0.00020981078876076924
# 第179个自体半径为 0.0010028763702056784
# 第180个自体半径为 4.547189138119056e-05
# 第181个自体半径为 4.2488885013093e-05
# 第182个自体半径为 3.4599001009779424e-05
# 第183个自体半径为 0.0005676149632490267
# 第184个自体半径为 0.00019023397564829874
# 第185个自体半径为 1.3645233410807455e-05
# 第186个自体半径为 0.0004442344124367928
# 第187个自体半径为 0.0004849468596748898
# 第188个自体半径为 0.09784967611205508
# 第189个自体半径为 0.0016001188237941917
# 第190个自体半径为 6.336529617566424e-05
# 第191个自体半径为 6.546592203242414e-05
# 第192个自体半径为 0.0007694032235492991
# 第193个自体半径为 0.001629484074611403
# 第194个自体半径为 0.00032282366408114817
# 第195个自体半径为 0.0005687469646005549
# 第196个自体半径为 0.00043881548722760094
# 第197个自体半径为 0.000605613157772003
# 第198个自体半径为 0.000707040361870966
# 第199个自体半径为 7.265244632454554e-05
# 实验进行50400/53874.
# 第0个自体半径为 5.9921545389124e-05
# 第1个自体半径为 5.1813482388122096e-05
# 第2个自体半径为 8.013922902248872e-06
# 第3个自体半径为 0.012376799864910243
# 第4个自体半径为 0.02241684027694609
# 第5个自体半径为 8.740511311395656e-05
# 第6个自体半径为 0.0003044007257405508
# 第7个自体半径为 0.00019923580062951847
# 第8个自体半径为 0.00011414774335524429
# 第9个自体半径为 0.0007008897703412142
# 第10个自体半径为 0.00019808964771373687
# 第11个自体半径为 0.0001417133596373866
# 第12个自体半径为 0.002238855443672751
# 第13个自体半径为 1e-06
# 第14个自体半径为 1e-06
# 第15个自体半径为 5.2327021484473484e-05
# 第16个自体半径为 9.739702970808096e-05
# 第17个自体半径为 0.0002859647664468696
# 第18个自体半径为 0.00026752982439136514
# 第19个自体半径为 0.0003086472498386943
# 第20个自体半径为 0.00022538747484654258
# 第21个自体半径为 0.0004439699899221755
# 第22个自体半径为 0.009980495365588034
# 第23个自体半径为 0.0020776783007273934
# 第24个自体半径为 0.0006856351574550063
# 第25个自体半径为 0.00020005894132921372
# 第26个自体半径为 0.0003758069768865804
# 第27个自体半径为 4.056076369283252e-05
# 第28个自体半径为 0.00017073692883538973
# 第29个自体半径为 7.850082622254658e-05
# 第30个自体半径为 0.0001539114163842892
# 第31个自体半径为 0.0009571679339777245
# 第32个自体半径为 1e-06
# 第33个自体半径为 0.027819324322870237
# 第34个自体半径为 1e-06
# 第35个自体半径为 9.393380112911431e-05
# 第36个自体半径为 0.0006360907862198862
# 第37个自体半径为 1.037863470284902e-05
# 第38个自体半径为 0.000757501564909714
# 第39个自体半径为 0.0007607888633629966
# 第40个自体半径为 0.00034063410167522296
# 第41个自体半径为 0.00017930649243665667
# 第42个自体半径为 1.7603371218971765e-05
# 第43个自体半径为 5.684062733060921e-05
# 第44个自体半径为 0.00014085124756000418
# 第45个自体半径为 0.0005118795625849908
# 第46个自体半径为 0.0012543684286659804
# 第47个自体半径为 0.0007787556371477676
# 第48个自体半径为 1.921828125754614e-05
# 第49个自体半径为 0.0005946855962664486
# 第50个自体半径为 0.001952826379971177
# 第51个自体半径为 0.02462988785972221
# 第52个自体半径为 0.0005195963818543373
# 第53个自体半径为 0.0003769436019179991
# 第54个自体半径为 0.0017369316092276169
# 第55个自体半径为 1.6921470887341387e-05
# 第56个自体半径为 5.949919096696119e-05
# 第57个自体半径为 0.00023368342533946248
# 第58个自体半径为 0.0006187628647784108
# 第59个自体半径为 0.00040755456806573266
# 第60个自体半径为 0.00041669638388613434
# 第61个自体半径为 4.9891259603040644e-05
# 第62个自体半径为 0.0003579691372165221
# 第63个自体半径为 0.00012244737281712556
# 第64个自体半径为 1e-06
# 第65个自体半径为 0.0003360770262651013
# 第66个自体半径为 0.0007949287035886763
# 第67个自体半径为 4.3626060177999266e-06
# 第68个自体半径为 0.0015255905004523827
# 第69个自体半径为 0.0006108199574442654
# 第70个自体半径为 0.00040899575337049684
# 第71个自体半径为 8.751261801572064e-05
# 第72个自体半径为 3.743201055134421e-05
# 第73个自体半径为 4.3019694948736906e-05
# 第74个自体半径为 0.00018132612838525703
# 第75个自体半径为 0.00011583043106188377
# 第76个自体半径为 0.0008129027377433584
# 第77个自体半径为 0.0002972166843269822
# 第78个自体半径为 0.007190867331135044
# 第79个自体半径为 5.037242273308726e-05
# 第80个自体半径为 0.0005896837917178168
# 第81个自体半径为 0.00038236314162195883
# ...
# 第46个自体半径为 1.2903588241016097e-05
# 第47个自体半径为 0.0010158196093018083
# 第48个自体半径为 7.898908564913976e-05
# 第49个自体半径为 0.0001311718754511823
# 第50个自体半径为 9.694596986214676e-05
# 第51个自体半径为 0.0006788438827655087
# 第52个自体半径为 1e-06
# 第53个自体半径为 0.0017160349053328716
# 第54个自体半径为 0.02764880992464522
# 第55个自体半径为 4.2488885013093e-05
# 第56个自体半径为 0.0005907295866286525
# 第57个自体半径为 0.0005808667282730438
# 第58个自体半径为 1e-06
# 第59个自体半径为 5.0552144877225166e-05
# 第60个自体半径为 6.902138243689123e-05
# 第61个自体半径为 5.68118578952262e-05
# 第62个自体半径为 0.0001491508392253188
# 第63个自体半径为 0.0005607554273249438
# 第64个自体半径为 0.0010824438906586633
# 第65个自体半径为 0.0006903033724512853
# 第66个自体半径为 0.00012528967133369846
# 第67个自体半径为 0.004877767832200899
# 第68个自体半径为 0.00017189626234741131
# 第69个自体半径为 0.025049555429947648
# 第70个自体半径为 0.0002029499790860808
# 第71个自体半径为 0.00043213728916572107
# 第72个自体半径为 0.0020726365345892627
# 第73个自体半径为 0.001428814581993859
# 第74个自体半径为 0.0004584888788046754
# 第75个自体半径为 0.029867356419646152
# 第76个自体半径为 4.493089292521794e-06
# 第77个自体半径为 0.0007173697792664587
# 第78个自体半径为 7.066452096181724e-05
# 第79个自体半径为 8.980783546007497e-05
# 第80个自体半径为 0.00021103386223675382
# 第81个自体半径为 0.0001379890579935618
# 第82个自体半径为 0.00023241600356689512
# 第83个自体半径为 0.00010915559601977655
# 第84个自体半径为 1.6921470887341387e-05
# 第85个自体半径为 0.0012569417204079708
# 第86个自体半径为 0.000990380259348858
# 第87个自体半径为 0.0003575585622239532
# 第88个自体半径为 0.0005347240703085344
# 第89个自体半径为 0.00016113845393238735
# 第90个自体半径为 0.0007105817691516579
# 第91个自体半径为 5.923150844982404e-05
# 第92个自体半径为 3.267115697557902e-05
# 第93个自体半径为 0.0023689573886177028
# 第94个自体半径为 7.567846326083842e-06
# 第95个自体半径为 0.00040593718422452776
# 第96个自体半径为 0.00011677123428580214
# 第97个自体半径为 0.002078337062427305
# 第98个自体半径为 0.0005792817718723186
# 第99个自体半径为 0.0001818330016218271
# 第100个自体半径为 0.000136052180098414
# 第101个自体半径为 0.0005930080414115633
# 第102个自体半径为 0.018801059510080757
# 第103个自体半径为 9.086887906990988e-05
# 第104个自体半径为 0.0002296590508398746
# 第105个自体半径为 1e-06
# 第106个自体半径为 9.493187901064296e-05
# 第107个自体半径为 0.0009513202175772536
# 第108个自体半径为 9.671758203858087e-05
# 第109个自体半径为 0.0002855283860672908
# 第110个自体半径为 5.1470842222306694e-05
# 第111个自体半径为 0.000420300452436581
# 第112个自体半径为 0.0019186005017125824
# 第113个自体半径为 0.0018551145134702983
# 第114个自体半径为 0.0005460585063277921
# 第115个自体半径为 0.003389978348446434
# 第116个自体半径为 0.0001627410479761258
# 第117个自体半径为 0.00020058291489860475
# 第118个自体半径为 0.002069786832944105
# 第119个自体半径为 4.526131743229988e-05
# 第120个自体半径为 0.00038167166301012427
# 第121个自体半径为 0.00020770025878334976
# 第122个自体半径为 6.814475097560808e-05
# 第123个自体半径为 0.00044787119384995374
# 第124个自体半径为 5.67595499024165e-05
# 第125个自体半径为 0.00016684419293853473
# 第126个自体半径为 0.00026194710680513093
# 第127个自体半径为 0.0017179136876802673
# 第128个自体半径为 4.193827715070633e-05
# 第129个自体半径为 0.002216917525851894
# 第130个自体半径为 1e-06
# 第131个自体半径为 0.0648120571587146
# 第132个自体半径为 4.217229489152376e-05
# 第133个自体半径为 1e-06
# 第134个自体半径为 0.00031702107656655926
# 第135个自体半径为 0.0001108121042474111
# 第136个自体半径为 0.00024438603453151597
# 第137个自体半径为 0.0026901658475302994
# 第138个自体半径为 6.81582378939759e-05
# 第139个自体半径为 9.370355263160375e-05
# 第140个自体半径为 0.02734580803752319
# 第141个自体半径为 0.00048496213617454643
# 第142个自体半径为 0.0005070565770240652
# 第143个自体半径为 4.925778814276366e-05
# 第144个自体半径为 7.764378195274569e-05
# 第145个自体半径为 7.207215075324585e-05
# 第146个自体半径为 0.0005977606772073381
# 第147个自体半径为 0.004138320415349504
# 第148个自体半径为 3.6995695715420204e-05
# 第149个自体半径为 0.0004935262771997861
# 第150个自体半径为 0.003162572094983852
# 第151个自体半径为 0.0006678066629761736
# 第152个自体半径为 4.064551555704214e-05
# 第153个自体半径为 5.375003862862114e-05
# 第154个自体半径为 0.00030094097798860793
# 第155个自体半径为 7.177176116143451e-05
# 第156个自体半径为 5.206223475667718e-06
# 第157个自体半径为 0.0009419431840090849
# 第158个自体半径为 0.0007913989520810691
# 第159个自体半径为 3.2070946073323445e-05
# 第160个自体半径为 0.026118150978081112
# 第161个自体半径为 3.5722095963754177e-06
# 第162个自体半径为 3.1192832469067945e-05
# 第163个自体半径为 0.0005531513319136375
# 第164个自体半径为 0.0009032948936532665
# 第165个自体半径为 1.556796988292538e-06
# 第166个自体半径为 0.0003012421944106551
# 第167个自体半径为 4.8884680461800034e-05
# 第168个自体半径为 3.763842476399939e-05
# 第169个自体半径为 0.00047892645468655296
# 第170个自体半径为 0.0019483652236447974
# 第171个自体半径为 0.007331698229425324
# 第172个自体半径为 7.469933008114956e-05
# 第173个自体半径为 2.9775409915028233e-05
# 第174个自体半径为 8.751261801572064e-05
# 第175个自体半径为 0.0012568503431290812
# 第176个自体半径为 0.0007222202095778858
# 第177个自体半径为 0.00013626970639234342
# 第178个自体半径为 0.0002595581410189077
# 第179个自体半径为 0.001256595594050399
# 第180个自体半径为 0.00026911324836331594
# 第181个自体半径为 3.676210390355414e-06
# 第182个自体半径为 1.2673067469997726e-05
# 第183个自体半径为 0.00038093057005602227
# 第184个自体半径为 0.0007795454964545987
# 第185个自体半径为 0.020709847687296223
# 第186个自体半径为 9.805144497025056e-05
# 第187个自体半径为 0.0031575861031191946
# 第188个自体半径为 3.428689192553973e-05
# 第189个自体半径为 0.0037398151525807185
# 第190个自体半径为 0.00043345989487244825
# 第191个自体半径为 0.0001474476993036775
# 第192个自体半径为 0.0013881818331415079
# 第193个自体半径为 0.00040051544119141624
# 第194个自体半径为 0.004716327373795248
# 第195个自体半径为 0.0002059596247301556
# 第196个自体半径为 0.00020640744084435945
# 第197个自体半径为 0.00031657758095407116
# 第198个自体半径为 0.00028433293428742595
# 第199个自体半径为 0.0009886157226057075
# 实验进行53600/53874.
# 第0个自体半径为 0.0014871032838915178
# 第1个自体半径为 8.387433717630546e-05
# 第2个自体半径为 4.3286313875839184e-05
# 第3个自体半径为 0.00034204277521933597
# 第4个自体半径为 0.0002846988084591837
# 第5个自体半径为 0.0006200075041201166
# 第6个自体半径为 0.0010526912676958999
# 第7个自体半径为 0.000593924809849549
# 第8个自体半径为 0.00015670913377730514
# 第9个自体半径为 7.191761986039071e-05
# 第10个自体半径为 4.190084645884915e-05
# 第11个自体半径为 4.065942322572143e-06
# 第12个自体半径为 4.1169517813470384e-05
# 第13个自体半径为 9.274155561306414e-05
# 第14个自体半径为 0.00011304490486334523
# 第15个自体半径为 0.00021229161283981774
# 第16个自体半径为 0.00010051451179168944
# 第17个自体半径为 0.0013261554230428881
# 第18个自体半径为 0.00014377893380590796
# 第19个自体半径为 0.0015772197577221111
# 第20个自体半径为 6.998123681908781e-05
# 第21个自体半径为 0.0005353095501249305
# 第22个自体半径为 4.993196794732537e-05
# 第23个自体半径为 8.013922902248872e-06
# 第24个自体半径为 0.00014702145191028925
# 第25个自体半径为 0.0006112582192911931
# 第26个自体半径为 0.0004991233358055228
# 第27个自体半径为 0.000961736135923649
# 第28个自体半径为 0.0003609906473912891
# 第29个自体半径为 0.00028455064283706586
# 第30个自体半径为 0.0007075807420344667
# 第31个自体半径为 8.836998999344326e-05
# 第32个自体半径为 3.6484220461189145e-05
# 第33个自体半径为 0.0011897690492574864
# 第34个自体半径为 6.147716995510389e-05
# 第35个自体半径为 0.00011573964565691182
# 第36个自体半径为 0.0005782116894265392
# 第37个自体半径为 0.00039325209998879586
# 第38个自体半径为 0.0015524900888506394
# 第39个自体半径为 0.0001031500688776635
# 第40个自体半径为 0.00012537793373373527
# 第41个自体半径为 0.00087866768826801
# 第42个自体半径为 0.00020328901690375465
# 第43个自体半径为 0.0007381757485222238
# 第44个自体半径为 0.00030703785508506956
# 第45个自体半径为 3.4365676807608638e-06
# 第46个自体半径为 0.0008658263383676509
# 第47个自体半径为 0.0015162474434868628
# 第48个自体半径为 0.0001043254910221432
# 第49个自体半径为 0.0006871409080761205
# 第50个自体半径为 0.0005278468995972677
# 第51个自体半径为 0.024588125681064017
# 第52个自体半径为 0.0013302199277780106
# 第53个自体半径为 0.00014210233281513506
# 第54个自体半径为 0.00040050697670542657
# 第55个自体半径为 0.00014608636907615337
# 第56个自体半径为 5.5371760608036646e-05
# 第57个自体半径为 0.0006656389593291987
# 第58个自体半径为 1e-06
# 第59个自体半径为 7.481493670917807e-05
# 第60个自体半径为 0.0008274833083375975
# 第61个自体半径为 7.365270233767397e-05
# 第62个自体半径为 0.00018206124987422842
# 第63个自体半径为 5.453233396904847e-05
# 第64个自体半径为 0.00020620998878223106
# 第65个自体半径为 2.989009879947775e-05
# 第66个自体半径为 0.00033163295087965155
# 第67个自体半径为 0.0004298105699503641
# 第68个自体半径为 0.0005792497174375985
# 第69个自体半径为 6.165803317876349e-05
# 第70个自体半径为 0.00014591872376081385
# 第71个自体半径为 0.00010597053633291285
# 第72个自体半径为 0.0002241940075512875
# 第73个自体半径为 0.0014793190474387528
# 第74个自体半径为 0.0006186343016626478
# 第75个自体半径为 0.0005761081848383215
# 第76个自体半径为 0.00021124781357415072
# 第77个自体半径为 0.00031100537184128524
# 第78个自体半径为 0.00040746400971465845
# 第79个自体半径为 7.838181611201246e-05
# 第80个自体半径为 0.00010390494648319848
# 第81个自体半径为 4.332520753163204e-05
# 第82个自体半径为 0.00048785228222585373
# 第83个自体半径为 0.00017488479668700924
# 第84个自体半径为 0.00044625974792040406
# 第85个自体半径为 2.0368857216408115e-06
# 第86个自体半径为 8.815538107918643e-05
# 第87个自体半径为 0.0014169653862628018
# 第88个自体半径为 7.8434594329424e-05
# 第89个自体半径为 0.0007043363926015725
# 第90个自体半径为 2.737720884101305e-06
# 第91个自体半径为 0.029504146473136067
# 第92个自体半径为 0.0003130923115787012
# 第93个自体半径为 0.00021863477872817677
# 第94个自体半径为 0.0016919509096408605
# 第95个自体半径为 1e-06
# 第96个自体半径为 2.143760308055102e-05
# 第97个自体半径为 0.0009093836820011344
# 第98个自体半径为 0.0015474689106706407
# 第99个自体半径为 3.913558860977853e-05
# 第100个自体半径为 0.001068097860754083
# 第101个自体半径为 0.00015365027644359183
# 第102个自体半径为 0.0003152861595217136
# 第103个自体半径为 0.00045919223269371855
# 第104个自体半径为 0.0004232160422017712
# 第105个自体半径为 8.013922902248872e-06
# 第106个自体半径为 0.00011367082593637387
# 第107个自体半径为 0.00061406802883221
# 第108个自体半径为 0.00019233612667902177
# 第109个自体半径为 0.0004721853705188803
# 第110个自体半径为 0.021773958565096223
# 第111个自体半径为 0.0009401090747084604
# 第112个自体半径为 0.0003516331505143626
# 第113个自体半径为 2.9947017170582847e-05
# 第114个自体半径为 2.7010589745545642e-06
# 第115个自体半径为 0.0006734209854699126
# 第116个自体半径为 0.0006817583827498033
# 第117个自体半径为 0.00020545955166758673
# 第118个自体半径为 0.00012402375303232857
# 第119个自体半径为 0.0005963950894927014
# 第120个自体半径为 1.513916910545679e-06
# 第121个自体半径为 0.0003834441723315556
# 第122个自体半径为 0.0005863831488061049
# 第123个自体半径为 0.0007026867522863237
# 第124个自体半径为 1e-06
# 第125个自体半径为 0.0004761030013023999
# 第126个自体半径为 0.000236309607073733
# 第127个自体半径为 0.00010657286160999872
# 第128个自体半径为 0.0004733763420414403
# 第129个自体半径为 0.00011017813286569619
# 第130个自体半径为 0.0019101232011021273
# 第131个自体半径为 0.00022694513138073107
# 第132个自体半径为 0.00022849400464696335
# 第133个自体半径为 0.0004608340272043762
# 第134个自体半径为 1.7324501684348085e-05
# 第135个自体半径为 0.0009349490744358581
# 第136个自体半径为 0.00020781683408529458
# 第137个自体半径为 0.0004769951726895575
# 第138个自体半径为 0.00010492923126865148
# 第139个自体半径为 0.0002481901108072808
# 第140个自体半径为 0.0005050748682273561
# 第141个自体半径为 0.013985160756114874
# 第142个自体半径为 2.474407250816557e-05
# 第143个自体半径为 0.0004489135922314684
# 第144个自体半径为 0.0019996527680078828
# 第145个自体半径为 0.0004572446343397865
# 第146个自体半径为 0.009358724247990256
# 第147个自体半径为 0.0002674292282032814
# 第148个自体半径为 0.0005584013598771675
# 第149个自体半径为 0.0005959474923834219
# 第150个自体半径为 0.00024251419803797503
# 第151个自体半径为 0.0005380804701808162
# 第152个自体半径为 0.00020063577809025825
# 第153个自体半径为 4.3560380018035875e-05
# 第154个自体半径为 0.0018250865670603582
# 第155个自体半径为 0.0003025819687160484
# 第156个自体半径为 0.0003942326058342331
# 第157个自体半径为 0.004272991586623076
# 第158个自体半径为 0.0005722189502696001
# 第159个自体半径为 8.871298408767096e-06
# 第160个自体半径为 0.00023402887697120448
# 第161个自体半径为 0.0011955062481730197
# 第162个自体半径为 0.0014426153312735942
# 第163个自体半径为 0.0004002077677507433
# 第164个自体半径为 0.0005167613757620567
# 第165个自体半径为 0.0006487017266405877
# 第166个自体半径为 0.00047669330688801325
# 第167个自体半径为 0.0010055652101930365
# 第168个自体半径为 7.615290292610933e-05
# 第169个自体半径为 0.0001137069571195845
# 第170个自体半径为 0.0004968785320390333
# 第171个自体半径为 1e-06
# 第172个自体半径为 0.0010062381278450809
# 第173个自体半径为 0.0002293822071455362
# 第174个自体半径为 0.0005336102314606399
# 第175个自体半径为 0.00042901885137439647
# 第176个自体半径为 1e-06
# 第177个自体半径为 0.00024600060337841653
# 第178个自体半径为 0.00012651090899610805
# 第179个自体半径为 9.543827024806444e-05
# 第180个自体半径为 8.751261801572064e-05
# 第181个自体半径为 0.0006796477688565297
# 第182个自体半径为 0.0002556678974293428
# 第183个自体半径为 0.00012820897609028137
# 第184个自体半径为 0.025273111754176167
# 第185个自体半径为 0.0005827135760343158
# 第186个自体半径为 0.02498790932532685
# 第187个自体半径为 0.0005051671719243138
# 第188个自体半径为 0.00013194348645967864
# 第189个自体半径为 0.00011599337858839217
# 第190个自体半径为 5.679776531593091e-05
# 第191个自体半径为 0.001227743634136536
# 第192个自体半径为 0.0012849852113809201
# 第193个自体半径为 4.365085917185273e-05
# 第194个自体半径为 0.00018836138857417404
# 第195个自体半径为 0.00030853935655625976
# 第196个自体半径为 0.0007259800860271866
# 第197个自体半径为 0.004726516486656776
# 第198个自体半径为 0.012012141689493468
# 第199个自体半径为 0.002600723833338708
# 实验进行53800/53874.
# 第0个自体半径为 1e-06
# 第1个自体半径为 0.0003186534199929228
# 第2个自体半径为 0.000816147416548874
# 第3个自体半径为 0.00951507357689766
# 第4个自体半径为 5.1041098415020994e-05
# 第5个自体半径为 1.9623047181853824e-05
# 第6个自体半径为 0.0002452314149716817
# 第7个自体半径为 0.00031388293561709045
# 第8个自体半径为 0.00022266029187182251
# 第9个自体半径为 0.000530594701203524
# 第10个自体半径为 0.0002751323804727943
# 第11个自体半径为 0.0024145092881028693
# 第12个自体半径为 0.00015934206589929547
# 第13个自体半径为 0.0007185890271498852
# 第14个自体半径为 1e-06
# 第15个自体半径为 1e-06
# 第16个自体半径为 1.7573473305004225e-05
# 第17个自体半径为 2.2763688069237496e-06
# 第18个自体半径为 0.035097140461991694
# 第19个自体半径为 0.0002859824239227932
# 第20个自体半径为 1e-06
# 第21个自体半径为 0.0022291514338731765
# 第22个自体半径为 0.00010548942893432775
# 第23个自体半径为 0.0016403381451469165
# 第24个自体半径为 0.0007941377885791885
# 第25个自体半径为 0.0003370548777496463
# 第26个自体半径为 0.00042559646381029625
# 第27个自体半径为 0.0013301011205399604
# 第28个自体半径为 0.00037882658228033915
# 第29个自体半径为 0.0007438663011923493
# 第30个自体半径为 0.00017707024077139337
# 第31个自体半径为 4.99497236564154e-05
# 第32个自体半径为 0.0006352353153322825
# 第33个自体半径为 0.0003298850561130518
# 第34个自体半径为 6.573059201743754e-05
# 第35个自体半径为 0.000187311426370513
# 第36个自体半径为 8.034227451405422e-06
# 第37个自体半径为 6.305217663754333e-05
# 第38个自体半径为 0.0014375217704787097
# 第39个自体半径为 0.00135917749322751
# 第40个自体半径为 8.489401171124481e-05
# 第41个自体半径为 0.030851487746143342
# 第42个自体半径为 0.00035612082497268297
# 第43个自体半径为 2.9860343184412775e-05
# 第44个自体半径为 0.0010951513876875255
# 第45个自体半径为 0.00012589081540496003
# 第46个自体半径为 0.00018701094792153146
# 第47个自体半径为 0.0003187512916821341
# 第48个自体半径为 1e-06
# 第49个自体半径为 0.0003845451176510112
# 第50个自体半径为 1.326244784227486e-05
# 第51个自体半径为 0.000698415823525367
# 第52个自体半径为 0.0034228858119710655
# 第53个自体半径为 0.0020753751002050174
# 第54个自体半径为 0.0003732935716322925
# 第55个自体半径为 0.0003553629707243783
# 第56个自体半径为 5.5156078015068864e-05
# 第57个自体半径为 0.0006179930333860143
# 第58个自体半径为 0.00018106397808838887
# 第59个自体半径为 1e-06
# 第60个自体半径为 4.9891259603040644e-05
# 第61个自体半径为 5.04985502044518e-05
# 第62个自体半径为 0.17250392435447084
# 第63个自体半径为 0.0007109573089678747
# 第64个自体半径为 0.0023839961846169526
# 第65个自体半径为 4.9670149260236926e-05
# 第66个自体半径为 1.7676376457513893e-05
# 第67个自体半径为 1.577885218287106e-05
# 第68个自体半径为 0.00023720775184251654
# 第69个自体半径为 0.00047195079388332047
# 第70个自体半径为 0.0009914414431290213
# 第71个自体半径为 0.00016281360174525097
# 第72个自体半径为 0.000405957070881347
# 第73个自体半径为 0.00039773419990117207
# 实验进行53874/53874.
# 第0个自体半径为 1e-06
# 第1个自体半径为 0.0003186534199929228
# 第2个自体半径为 0.000816147416548874
# 第3个自体半径为 0.00951507357689766
# 第4个自体半径为 5.1041098415020994e-05
# 第5个自体半径为 1.9623047181853824e-05
# 第6个自体半径为 0.0002452314149716817
# 第7个自体半径为 0.00031388293561709045
# 第8个自体半径为 0.00022266029187182251
# 第9个自体半径为 0.000530594701203524
# 第10个自体半径为 0.0002751323804727943
# 第11个自体半径为 0.0024145092881028693
# 第12个自体半径为 0.00015934206589929547
# 第13个自体半径为 0.0007185890271498852
# 第14个自体半径为 1e-06
# 第15个自体半径为 1e-06
# 第16个自体半径为 1.7573473305004225e-05
# 第17个自体半径为 2.2763688069237496e-06
# 第18个自体半径为 0.035097140461991694
# 第19个自体半径为 0.0002859824239227932
# 第20个自体半径为 1e-06
# 第21个自体半径为 0.0022291514338731765
# 第22个自体半径为 0.00010548942893432775
# 第23个自体半径为 0.0016403381451469165
# 第24个自体半径为 0.0007941377885791885
# 第25个自体半径为 0.0003370548777496463
# 第26个自体半径为 0.00042559646381029625
# 第27个自体半径为 0.0013301011205399604
# 第28个自体半径为 0.00037882658228033915
# 第29个自体半径为 0.0007438663011923493
# 第30个自体半径为 0.00017707024077139337
# 第31个自体半径为 4.99497236564154e-05
# 第32个自体半径为 0.0006352353153322825
# 第33个自体半径为 0.0003298850561130518
# 第34个自体半径为 6.573059201743754e-05
# 第35个自体半径为 0.000187311426370513
# 第36个自体半径为 8.034227451405422e-06
# 第37个自体半径为 6.305217663754333e-05
# 第38个自体半径为 0.0014375217704787097
# 第39个自体半径为 0.00135917749322751
# 第40个自体半径为 8.489401171124481e-05
# 第41个自体半径为 0.030851487746143342
# 第42个自体半径为 0.00035612082497268297
# 第43个自体半径为 2.9860343184412775e-05
# 第44个自体半径为 0.0010951513876875255
# 第45个自体半径为 0.00012589081540496003
# 第46个自体半径为 0.00018701094792153146
# 第47个自体半径为 0.0003187512916821341
# 第48个自体半径为 1e-06
# 第49个自体半径为 0.0003845451176510112
# 第50个自体半径为 1.326244784227486e-05
# 第51个自体半径为 0.000698415823525367
# 第52个自体半径为 0.0034228858119710655
# 第53个自体半径为 0.0020753751002050174
# 第54个自体半径为 0.0003732935716322925
# 第55个自体半径为 0.0003553629707243783
# 第56个自体半径为 5.5156078015068864e-05
# 第57个自体半径为 0.0006179930333860143
# 第58个自体半径为 0.00018106397808838887
# 第59个自体半径为 1e-06
# 第60个自体半径为 4.9891259603040644e-05
# 第61个自体半径为 5.04985502044518e-05
# 第62个自体半径为 0.17250392435447084
# 第63个自体半径为 0.0007109573089678747
# 第64个自体半径为 0.0023839961846169526
# 第65个自体半径为 4.9670149260236926e-05
# 第66个自体半径为 1.7676376457513893e-05
# 第67个自体半径为 1.577885218287106e-05
# 第68个自体半径为 0.00023720775184251654
# 第69个自体半径为 0.00047195079388332047
# 第70个自体半径为 0.0009914414431290213
# 第71个自体半径为 0.00016281360174525097
# 第72个自体半径为 0.000405957070881347
# 第73个自体半径为 0.00039773419990117207

# %% [markdown]
# ### 未知攻击测试

# %%
def test(normal_sample, attack_sample, self_detector, detector_radius):
    true_self, false_self, true_nonself, false_nonself = 0, 0, 0, 0
    detector_num = self_detector.shape[0]
    error_nonself = pd.DataFrame(columns=["attack_sample", "self_detector", "detector_radius"])
    error_self = pd.DataFrame(columns=['normal_sample'])  # 未落入任何自体检测器的正常样本

    # 对每一个正常的样本,遍历所有自体检测器，计算正常自体被检测出的个数
    t=0
    for i in range(0, len(normal_sample)):
        flag = 0
        for k in range(0, detector_num):
            distance = np.linalg.norm(normal_sample[i] - self_detector[k])
            if distance < detector_radius[k]:
                true_self = true_self + 1
                flag = 1
                break
        if flag == 0:
          error_self.loc[t] = [i]
          t = t + 1
          


    # 对每一个异常样本，遍历所有自体检测器，计算异常点被检测器覆盖个数
    for i in range(0, len(attack_sample)):
        for k in range(0, detector_num):
            distance = np.linalg.norm(attack_sample[i] - self_detector[k])
            if distance < detector_radius[k]:
                false_nonself = false_nonself + 1
                error_nonself.loc[false_nonself] = [i, k, detector_radius[k]]
                print("第{}个异常样本，被第{}个自体检测器错误覆盖，距离{}，该检测器半径为{}".format(i, k, distance, detector_radius[k]))
                break

    false_self = len(normal_sample) - true_self
    true_nonself = len(attack_sample) - false_nonself
    print('true_self:{}, false_self:{}, true_nonself:{}, false_nonself:{}'.format(true_self, false_self, true_nonself, false_nonself))
    print('自体准确率：{}， 非自体识别准确率：{}'.format(true_self / len(normal_sample), true_nonself / len(attack_sample)))
    return error_nonself, error_self




#  矩阵计算欧式距离
def EuclideanDistance(A, B):
    m, n = A.shape[0], B.shape[0]
    # AA经过pow函数对矩阵每个元素求二次方，axis=1横向求和，此时AA.shape=(m,1),扩展n-1次，AA.shape=(m,n)
    AA = torch.pow(A, 2).sum(1, keepdim=True).expand(m, n)
    # sum操作后BB.shape=(n,1)
    BB = torch.pow(B, 2).sum(1, keepdim=True).expand(n, m).T
    dist = AA + BB
    # 表示dist - 2* A * B.T
    dist.addmm_(1, -2, A, B.t())
    # clamp()函数可以限定dist内元素的最大最小范围，dist最后开方，得到样本之间的距离矩阵
    dist = dist.clamp(min=1e-12).sqrt()
    return dist



test_Self = AE_2_encoded_test[y_test==0,:]
'''test_NonSelf1 = AE_2_encoded_test[y_test==1,:]
test_NonSelf = np.r_[test_NonSelf1, test_NonSelf2]'''
error_nonself, error_self = test(test_Self, test_NonSelf2, Normaldata, Radius)
# Out:
# 第0个异常样本，被第3092个自体检测器错误覆盖，距离6.502202920131574e-05，该检测器半径为0.0001537197552241818
# 第1个异常样本，被第23262个自体检测器错误覆盖，距离0.00011859021146393898，该检测器半径为0.00017410687188262108
# 第2个异常样本，被第793个自体检测器错误覆盖，距离7.638934657640018e-07，该检测器半径为1e-06
# 第3个异常样本，被第6559个自体检测器错误覆盖，距离0.0007402637738442873，该检测器半径为0.0007474388805345792
# 第4个异常样本，被第66个自体检测器错误覆盖，距离7.760057923318025e-07，该检测器半径为1e-06
# 第6个异常样本，被第25103个自体检测器错误覆盖，距离9.958337103959735e-05，该检测器半径为0.00010613917468223686
# 第9个异常样本，被第1886个自体检测器错误覆盖，距离0.00016199306123011547，该检测器半径为0.000299043979499568
# 第11个异常样本，被第1503个自体检测器错误覆盖，距离5.990192700378956e-07，该检测器半径为1e-06
# 第12个异常样本，被第4262个自体检测器错误覆盖，距离1.566950468963324e-05，该检测器半径为1.6306378209415943e-05
# 第14个异常样本，被第87个自体检测器错误覆盖，距离2.2891598193950898e-07，该检测器半径为1e-06
# 第15个异常样本，被第23262个自体检测器错误覆盖，距离0.00016306907632314472，该检测器半径为0.00017410687188262108
# 第16个异常样本，被第295个自体检测器错误覆盖，距离0.00028328861183709263，该检测器半径为0.00040246646445255186
# 第17个异常样本，被第23262个自体检测器错误覆盖，距离0.00012611306189751374，该检测器半径为0.00017410687188262108
# 第21个异常样本，被第154个自体检测器错误覆盖，距离9.185692787812583e-07，该检测器半径为1e-06
# 第22个异常样本，被第9872个自体检测器错误覆盖，距离0.0006025473487409688，该检测器半径为0.0006162112713459649
# 第24个异常样本，被第1886个自体检测器错误覆盖，距离0.00011828601075178149，该检测器半径为0.000299043979499568
# 第26个异常样本，被第1526个自体检测器错误覆盖，距离8.052144101921496e-07，该检测器半径为1e-06
# 第27个异常样本，被第1886个自体检测器错误覆盖，距离0.0002332977706513808，该检测器半径为0.000299043979499568
# 第28个异常样本，被第958个自体检测器错误覆盖，距离8.481889772674173e-07，该检测器半径为1e-06
# 第29个异常样本，被第35125个自体检测器错误覆盖，距离1.3705828602466792e-06，该检测器半径为3.3886957355748124e-06
# 第31个异常样本，被第10332个自体检测器错误覆盖，距离0.0011391740043345292，该检测器半径为0.0038451970774084692
# 第32个异常样本，被第24642个自体检测器错误覆盖，距离1.961300796989613e-06，该检测器半径为2.377470812222854e-06
# 第33个异常样本，被第1503个自体检测器错误覆盖，距离2.2302017127866021e-07，该检测器半径为1e-06
# 第34个异常样本，被第4426个自体检测器错误覆盖，距离0.00021342207354403315，该检测器半径为0.00036991876326851236
# 第36个异常样本，被第9131个自体检测器错误覆盖，距离0.00013129003429408393，该检测器半径为0.0002834043975349729
# 第37个异常样本，被第1886个自体检测器错误覆盖，距离0.0002879510506352866，该检测器半径为0.000299043979499568
# 第38个异常样本，被第6116个自体检测器错误覆盖，距离3.41103170581448e-07，该检测器半径为1e-06
# 第39个异常样本，被第2735个自体检测器错误覆盖，距离0.0009645812002898893，该检测器半径为0.0036766143594249624
# 第40个异常样本，被第1886个自体检测器错误覆盖，距离0.00021078301557937078，该检测器半径为0.000299043979499568
# 第41个异常样本，被第1173个自体检测器错误覆盖，距离4.749708663673886e-07，该检测器半径为1e-06
# 第42个异常样本，被第14714个自体检测器错误覆盖，距离9.915712359316485e-07，该检测器半径为1e-06
# 第45个异常样本，被第26295个自体检测器错误覆盖，距离1.8923301485487008e-05，该检测器半径为9.6554131912865e-05
# 第46个异常样本，被第899个自体检测器错误覆盖，距离6.01239238666196e-07，该检测器半径为1e-06
# 第47个异常样本，被第23262个自体检测器错误覆盖，距离7.236998650279541e-05，该检测器半径为0.00017410687188262108
# 第48个异常样本，被第4830个自体检测器错误覆盖，距离0.0031300483561050637，该检测器半径为0.015047244166147153
# 第49个异常样本，被第7982个自体检测器错误覆盖，距离6.10381611496682e-05，该检测器半径为7.583227577320075e-05
# 第50个异常样本，被第4426个自体检测器错误覆盖，距离0.00016900997138218952，该检测器半径为0.00036991876326851236
# 第51个异常样本，被第10744个自体检测器错误覆盖，距离8.37652046832752e-07，该检测器半径为2.597037711431589e-06
# 第52个异常样本，被第752个自体检测器错误覆盖，距离7.7773818350896e-05，该检测器半径为0.00010384867318439909
# 第54个异常样本，被第4830个自体检测器错误覆盖，距离0.0018673826341989563，该检测器半径为0.015047244166147153
# 第55个异常样本，被第47171个自体检测器错误覆盖，距离1.498437540944933e-06，该检测器半径为3.5159478508634436e-06
# 第57个异常样本，被第28225个自体检测器错误覆盖，距离0.0007951124540639365，该检测器半径为0.0013875601335665783
# 第60个异常样本，被第4426个自体检测器错误覆盖，距离0.00018125894243262958，该检测器半径为0.00036991876326851236
# 第61个异常样本，被第839个自体检测器错误覆盖，距离4.92415183423743e-07，该检测器半径为1e-06
# 第63个异常样本，被第24642个自体检测器错误覆盖，距离1.8349617079693078e-06，该检测器半径为2.377470812222854e-06
# 第64个异常样本，被第447个自体检测器错误覆盖，距离7.985687975878427e-07，该检测器半径为1e-06
# 第65个异常样本，被第37995个自体检测器错误覆盖，距离0.0012391914471268806，该检测器半径为0.0029171727565203216
# 第66个异常样本，被第9790个自体检测器错误覆盖，距离0.00014968274200123982，该检测器半径为0.00021986984994190782
# 第67个异常样本，被第28225个自体检测器错误覆盖，距离0.0008890385239085266，该检测器半径为0.0013875601335665783
# 第68个异常样本，被第66个自体检测器错误覆盖，距离3.25104955274931e-07，该检测器半径为1e-06
# 第69个异常样本，被第8309个自体检测器错误覆盖，距离0.0004892660418489567，该检测器半径为0.0005982697249168783
# 第72个异常样本，被第36117个自体检测器错误覆盖，距离6.72820019203196e-06，该检测器半径为7.332734091797959e-06
# 第73个异常样本，被第8309个自体检测器错误覆盖，距离0.00048406232117987024，该检测器半径为0.0005982697249168783
# 第74个异常样本，被第315个自体检测器错误覆盖，距离6.041865074550303e-07，该检测器半径为1e-06
# 第75个异常样本，被第13625个自体检测器错误覆盖，距离0.0001056324144225082，该检测器半径为0.0007372809067057293
# 第76个异常样本，被第1272个自体检测器错误覆盖，距离0.0010524330328883496，该检测器半径为0.0011765897774442973
# 第77个异常样本，被第1886个自体检测器错误覆盖，距离0.00014613589372146135，该检测器半径为0.000299043979499568
# 第79个异常样本，被第37831个自体检测器错误覆盖，距离5.99128983808609e-05，该检测器半径为0.00017865604207256472
# 第80个异常样本，被第8309个自体检测器错误覆盖，距离0.0005312330709016128，该检测器半径为0.0005982697249168783
# 第81个异常样本，被第295个自体检测器错误覆盖，距离0.00014888688768701768，该检测器半径为0.00040246646445255186
# 第82个异常样本，被第605个自体检测器错误覆盖，距离4.80174517719205e-05，该检测器半径为0.00010555879412769592
# 第83个异常样本，被第87个自体检测器错误覆盖，距离8.749913239099637e-07，该检测器半径为1e-06
# 第84个异常样本，被第1464个自体检测器错误覆盖，距离4.0535541561481274e-07，该检测器半径为1e-06
# 第85个异常样本，被第14714个自体检测器错误覆盖，距离8.985289026104792e-07，该检测器半径为1e-06
# 第86个异常样本，被第791个自体检测器错误覆盖，距离0.00043514991211104876，该检测器半径为0.0004933714091057292
# 第87个异常样本，被第8309个自体检测器错误覆盖，距离0.0004571896250315085，该检测器半径为0.0005982697249168783
# 第88个异常样本，被第21168个自体检测器错误覆盖，距离0.00036077119459685845，该检测器半径为0.0011530490086106102
# 第89个异常样本，被第8309个自体检测器错误覆盖，距离0.0003743520832777324，该检测器半径为0.0005982697249168783
# 第92个异常样本，被第284个自体检测器错误覆盖，距离9.780430354631031e-07，该检测器半径为1e-06
# 第94个异常样本，被第441个自体检测器错误覆盖，距离0.00010121334236750236，该检测器半径为0.0003791414060520321
# 第95个异常样本，被第13842个自体检测器错误覆盖，距离0.0022761965357080746，该检测器半径为0.0026865035057763074
# 第96个异常样本，被第374个自体检测器错误覆盖，距离0.0009896734473268368，该检测器半径为0.0013296876412343408
# 第97个异常样本，被第12786个自体检测器错误覆盖，距离7.515859858096628e-07，该检测器半径为1e-06
# 第100个异常样本，被第6575个自体检测器错误覆盖，距离0.0016916137832800368，该检测器半径为0.0024863135950617355
# 第101个异常样本，被第728个自体检测器错误覆盖，距离0.0004772924377196461，该检测器半径为0.0004817066228851818
# 第103个异常样本，被第87个自体检测器错误覆盖，距离4.086288636680009e-07，该检测器半径为1e-06
# 第104个异常样本，被第1886个自体检测器错误覆盖，距离0.00018500246694482138，该检测器半径为0.000299043979499568
# 第105个异常样本，被第6639个自体检测器错误覆盖，距离0.0007853191939288206，该检测器半径为0.0010771624830390335
# 第106个异常样本，被第1464个自体检测器错误覆盖，距离7.44461777515127e-07，该检测器半径为1e-06
# 第107个异常样本，被第31144个自体检测器错误覆盖，距离4.398939892390604e-05，该检测器半径为5.2309897615050895e-05
# 第109个异常样本，被第288个自体检测器错误覆盖，距离5.953009270515663e-07，该检测器半径为1e-06
# 第110个异常样本，被第2694个自体检测器错误覆盖，距离4.823927355178672e-07，该检测器半径为1e-06
# 第111个异常样本，被第8309个自体检测器错误覆盖，距离0.00041338757877099384，该检测器半径为0.0005982697249168783
# 第112个异常样本，被第728个自体检测器错误覆盖，距离0.00047454083435889883，该检测器半径为0.0004817066228851818
# 第113个异常样本，被第295个自体检测器错误覆盖，距离0.00012785109121038748，该检测器半径为0.00040246646445255186
# 第114个异常样本，被第4547个自体检测器错误覆盖，距离1.2197490325337663e-05，该检测器半径为1.7674818743221384e-05
# 第115个异常样本，被第752个自体检测器错误覆盖，距离2.0469379691589608e-05，该检测器半径为0.00010384867318439909
# 第116个异常样本，被第66个自体检测器错误覆盖，距离7.85108810578324e-07，该检测器半径为1e-06
# 第118个异常样本，被第7628个自体检测器错误覆盖，距离8.754987123419365e-07，该检测器半径为1e-06
# 第120个异常样本，被第9872个自体检测器错误覆盖，距离0.0005830233523966164，该检测器半径为0.0006162112713459649
# 第121个异常样本，被第6101个自体检测器错误覆盖，距离2.200331940082111e-06，该检测器半径为3.0089278358267795e-06
# 第122个异常样本，被第295个自体检测器错误覆盖，距离0.00019811633301494025，该检测器半径为0.00040246646445255186
# 第123个异常样本，被第295个自体检测器错误覆盖，距离0.0002794517018191005，该检测器半径为0.00040246646445255186
# 第124个异常样本，被第605个自体检测器错误覆盖，距离6.629356372808857e-05，该检测器半径为0.00010555879412769592
# 第125个异常样本，被第2097个自体检测器错误覆盖，距离3.291774164360605e-07，该检测器半径为1e-06
# 第126个异常样本，被第11543个自体检测器错误覆盖，距离4.872661482916565e-05，该检测器半径为8.030204037699904e-05
# 第128个异常样本，被第31522个自体检测器错误覆盖，距离0.0006624892848161183，该检测器半径为0.0017160349053328716
# 第129个异常样本，被第694个自体检测器错误覆盖，距离3.793216366310291e-07，该检测器半径为1e-06
# 第130个异常样本，被第6639个自体检测器错误覆盖，距离0.0007355529482697692，该检测器半径为0.0010771624830390335
# 第131个异常样本，被第1886个自体检测器错误覆盖，距离0.00014960331265583712，该检测器半径为0.000299043979499568
# 第132个异常样本，被第1503个自体检测器错误覆盖，距离7.884953380193138e-07，该检测器半径为1e-06
# 第133个异常样本，被第8309个自体检测器错误覆盖，距离0.0003460400064959263，该检测器半径为0.0005982697249168783
# 第134个异常样本，被第4830个自体检测器错误覆盖，距离0.011373073320278709，该检测器半径为0.015047244166147153
# 第135个异常样本，被第17025个自体检测器错误覆盖，距离0.00010470232812029922，该检测器半径为0.0003093035008921291
# 第136个异常样本，被第1464个自体检测器错误覆盖，距离2.0212918469683135e-07，该检测器半径为1e-06
# 第137个异常样本，被第574个自体检测器错误覆盖，距离0.0007023230852263218，该检测器半径为0.0014667170229121626
# 第138个异常样本，被第47171个自体检测器错误覆盖，距离2.3958917449958345e-06，该检测器半径为3.5159478508634436e-06
# 第140个异常样本，被第694个自体检测器错误覆盖，距离4.664801369249379e-07，该检测器半径为1e-06
# 第141个异常样本，被第315个自体检测器错误覆盖，距离2.8894423592941596e-07，该检测器半径为1e-06
# 第142个异常样本，被第1526个自体检测器错误覆盖，距离7.312204925051509e-07，该检测器半径为1e-06
# 第143个异常样本，被第8309个自体检测器错误覆盖，距离0.0003935988024414213，该检测器半径为0.0005982697249168783
# 第144个异常样本，被第25223个自体检测器错误覆盖，距离5.408608418638966e-06，该检测器半径为6.163337154233864e-06
# 第145个异常样本，被第4426个自体检测器错误覆盖，距离0.00018037314165444092，该检测器半径为0.00036991876326851236
# 第146个异常样本，被第1503个自体检测器错误覆盖，距离8.754987135210604e-07，该检测器半径为1e-06
# 第147个异常样本，被第288个自体检测器错误覆盖，距离8.237525823564986e-07，该检测器半径为1e-06
# 第149个异常样本，被第1886个自体检测器错误覆盖，距离0.00012206052958646552，该检测器半径为0.000299043979499568
# 第150个异常样本，被第10991个自体检测器错误覆盖，距离8.413708211829407e-06，该检测器半径为1.3026589661105935e-05
# 第151个异常样本，被第126个自体检测器错误覆盖，距离9.438447828406049e-07，该检测器半径为1e-06
# 第153个异常样本，被第6559个自体检测器错误覆盖，距离0.0006278569913805754，该检测器半径为0.0007474388805345792
# 第154个异常样本，被第4426个自体检测器错误覆盖，距离0.00017668590283277332，该检测器半径为0.00036991876326851236
# 第155个异常样本，被第1886个自体检测器错误覆盖，距离0.0002551924140707459，该检测器半径为0.000299043979499568
# 第156个异常样本，被第8309个自体检测器错误覆盖，距离0.0003808491973647899，该检测器半径为0.0005982697249168783
# 第157个异常样本，被第42992个自体检测器错误覆盖，距离0.0003673498317693505，该检测器半径为0.00036805062270704985
# 第158个异常样本，被第87个自体检测器错误覆盖，距离3.182017365835586e-07，该检测器半径为1e-06
# 第159个异常样本，被第4830个自体检测器错误覆盖，距离0.014191853363174387，该检测器半径为0.015047244166147153
# 第160个异常样本，被第162个自体检测器错误覆盖，距离0.0004906945224954302，该检测器半径为0.0008798354174571309
# 第161个异常样本，被第23262个自体检测器错误覆盖，距离0.00013462288628441203，该检测器半径为0.00017410687188262108
# 第162个异常样本，被第24642个自体检测器错误覆盖，距离1.3180580539113733e-06，该检测器半径为2.377470812222854e-06
# 第163个异常样本，被第4426个自体检测器错误覆盖，距离0.00022563280414931885，该检测器半径为0.00036991876326851236
# 第164个异常样本，被第1070个自体检测器错误覆盖，距离0.01586225457112469，该检测器半径为0.02497850360576969
# 第165个异常样本，被第284个自体检测器错误覆盖，距离3.8971594021392777e-07，该检测器半径为1e-06
# 第167个异常样本，被第1464个自体检测器错误覆盖，距离8.046627176444759e-07，该检测器半径为1e-06
# 第168个异常样本，被第516个自体检测器错误覆盖，距离0.00015801939462668983，该检测器半径为0.0002458494114801882
# 第169个异常样本，被第315个自体检测器错误覆盖，距离5.832429511268044e-07，该检测器半径为1e-06
# 第170个异常样本，被第1886个自体检测器错误覆盖，距离0.0002689645198021355，该检测器半径为0.000299043979499568
# 第172个异常样本，被第1464个自体检测器错误覆盖，距离9.073816172648201e-07，该检测器半径为1e-06
# 第173个异常样本，被第694个自体检测器错误覆盖，距离8.210526424829402e-07，该检测器半径为1e-06
# 第174个异常样本，被第1464个自体检测器错误覆盖，距离1.812804499357408e-07，该检测器半径为1e-06
# 第175个异常样本，被第516个自体检测器错误覆盖，距离4.1625342273630305e-05，该检测器半径为0.0002458494114801882
# 第177个异常样本，被第1886个自体检测器错误覆盖，距离0.00018862882909891838，该检测器半径为0.000299043979499568
# 第178个异常样本，被第9790个自体检测器错误覆盖，距离8.62785520085585e-05，该检测器半径为0.00021986984994190782
# 第179个异常样本，被第23262个自体检测器错误覆盖，距离0.0001336274522666689，该检测器半径为0.00017410687188262108
# 第180个异常样本，被第1886个自体检测器错误覆盖，距离0.00011451690031537172，该检测器半径为0.000299043979499568
# 第181个异常样本，被第1886个自体检测器错误覆盖，距离0.0002869047364713786，该检测器半径为0.000299043979499568
# 第182个异常样本，被第8309个自体检测器错误覆盖，距离0.0004776955046574978，该检测器半径为0.0005982697249168783
# 第184个异常样本，被第513个自体检测器错误覆盖，距离1.1071071494494092e-06，该检测器半径为1.3314669074826644e-06
# 第185个异常样本，被第4013个自体检测器错误覆盖，距离0.00026674033360156164，该检测器半径为0.000310929146113397
# 第186个异常样本，被第87个自体检测器错误覆盖，距离7.851088092793826e-07，该检测器半径为1e-06
# 第189个异常样本，被第513个自体检测器错误覆盖，距离1.088090921107455e-06，该检测器半径为1.3314669074826644e-06
# 第191个异常样本，被第87个自体检测器错误覆盖，距离4.042583759723491e-07，该检测器半径为1e-06
# 第193个异常样本，被第1618个自体检测器错误覆盖，距离3.3453024552395865e-07，该检测器半径为1e-06
# 第194个异常样本，被第3053个自体检测器错误覆盖，距离0.002135055904438288，该检测器半径为0.002676447922496021
# 第196个异常样本，被第26212个自体检测器错误覆盖，距离1.772301310386635e-05，该检测器半径为3.16800369139805e-05
# 第198个异常样本，被第6559个自体检测器错误覆盖，距离0.0006889772758730653，该检测器半径为0.0007474388805345792
# 第199个异常样本，被第315个自体检测器错误覆盖，距离5.990192708526217e-07，该检测器半径为1e-06
# 第200个异常样本，被第4615个自体检测器错误覆盖，距离4.768371637854651e-07，该检测器半径为1e-06
# 第202个异常样本，被第8309个自体检测器错误覆盖，距离0.00037803136424035676，该检测器半径为0.0005982697249168783
# 第203个异常样本，被第18465个自体检测器错误覆盖，距离2.1380835185978965e-05，该检测器半径为2.1534441338937737e-05
# 第204个异常样本，被第605个自体检测器错误覆盖，距离4.586259866535844e-05，该检测器半径为0.00010555879412769592
# 第205个异常样本，被第288个自体检测器错误覆盖，距离4.235705916059107e-07，该检测器半径为1e-06
# 第206个异常样本，被第315个自体检测器错误覆盖，距离2.980232238769531e-07，该检测器半径为1e-06
# 第207个异常样本，被第13666个自体检测器错误覆盖，距离0.007665843152662297，该检测器半径为0.013694260230188356
# 第208个异常样本，被第284个自体检测器错误覆盖，距离2.0861626940212994e-07，该检测器半径为1e-06
# 第209个异常样本，被第87个自体检测器错误覆盖，距离4.2146849141899465e-07，该检测器半径为1e-06
# 第211个异常样本，被第1164个自体检测器错误覆盖，距离6.750078136193118e-07，该检测器半径为1e-06
# 第215个异常样本，被第694个自体检测器错误覆盖，距离4.1509831780777735e-07，该检测器半径为1e-06
# 第216个异常样本，被第447个自体检测器错误覆盖，距离9.185692776548333e-07，该检测器半径为1e-06
# 第217个异常样本，被第791个自体检测器错误覆盖，距离0.00043602981848467456，该检测器半径为0.0004933714091057292
# 第218个异常样本，被第8309个自体检测器错误覆盖，距离0.00041086559064714166，该检测器半径为0.0005982697249168783
# 第220个异常样本，被第28884个自体检测器错误覆盖，距离8.328669468046824e-07，该检测器半径为1e-06
# 第221个异常样本，被第1886个自体检测器错误覆盖，距离0.00023182019367923713，该检测器半径为0.000299043979499568
# 第222个异常样本，被第8309个自体检测器错误覆盖，距离0.00037115613924239743，该检测器半径为0.0005982697249168783
# 第223个异常样本，被第1886个自体检测器错误覆盖，距离0.0002162902577200238，该检测器半径为0.000299043979499568
# 第224个异常样本，被第25264个自体检测器错误覆盖，距离0.0003211219681421419，该检测器半径为0.000436208387503222
# 第226个异常样本，被第6615个自体检测器错误覆盖，距离0.00729435018222566，该检测器半径为0.010485424660025753
# 第228个异常样本，被第13666个自体检测器错误覆盖，距离0.00401116215253845，该检测器半径为0.013694260230188356
# 第229个异常样本，被第1886个自体检测器错误覆盖，距离0.00027066827036091254，该检测器半径为0.000299043979499568
# 第230个异常样本，被第4426个自体检测器错误覆盖，距离0.0001950763434466463，该检测器半径为0.00036991876326851236
# 第231个异常样本，被第295个自体检测器错误覆盖，距离0.00011870274734978694，该检测器半径为0.00040246646445255186
# 第232个异常样本，被第728个自体检测器错误覆盖，距离0.0004770260098190886，该检测器半径为0.0004817066228851818
# 第233个异常样本，被第8851个自体检测器错误覆盖，距离3.593212293852024e-05，该检测器半径为3.730546997563464e-05
# 第234个异常样本，被第295个自体检测器错误覆盖，距离0.0001149490139524986，该检测器半径为0.00040246646445255186
# 第235个异常样本，被第6559个自体检测器错误覆盖，距离0.0007416433362439156，该检测器半径为0.0007474388805345792
# 第236个异常样本，被第1886个自体检测器错误覆盖，距离0.00023785856348944472，该检测器半径为0.000299043979499568
# 第239个异常样本，被第2033个自体检测器错误覆盖，距离9.024741637210414e-07，该检测器半径为1e-06
# 第241个异常样本，被第1886个自体检测器错误覆盖，距离0.00022525734014813432，该检测器半径为0.000299043979499568
# 第242个异常样本，被第1464个自体检测器错误覆盖，距离9.000104016369025e-07，该检测器半径为1e-06
# 第244个异常样本，被第26212个自体检测器错误覆盖，距离1.6839182661481246e-05，该检测器半径为3.16800369139805e-05
# 第246个异常样本，被第4023个自体检测器错误覆盖，距离0.0005383945499816214，该检测器半径为0.0023223451694683182
# 第247个异常样本，被第2095个自体检测器错误覆盖，距离5.170509739123346e-07，该检测器半径为1e-06
# 第248个异常样本，被第7945个自体检测器错误覆盖，距离0.000739740226437672，该检测器半径为0.0007444174779908042
# 第250个异常样本，被第8602个自体检测器错误覆盖，距离0.0005553029875532493，该检测器半径为0.0007474873918755931
# 第251个异常样本，被第284个自体检测器错误覆盖，距离5.607273534097909e-07，该检测器半径为1e-06
# 第252个异常样本，被第1464个自体检测器错误覆盖，距离7.498112835079114e-07，该检测器半径为1e-06
# 第253个异常样本，被第5546个自体检测器错误覆盖，距离0.004363462548087353，该检测器半径为0.005155255821574273
# 第254个异常样本，被第8309个自体检测器错误覆盖，距离0.000477894369129394，该检测器半径为0.0005982697249168783
# 第255个异常样本，被第839个自体检测器错误覆盖，距离6.194296421697612e-07，该检测器半径为1e-06
# 第256个异常样本，被第36828个自体检测器错误覆盖，距离0.00016112196666693632，该检测器半径为0.00020930903857954928
# 第257个异常样本，被第3864个自体检测器错误覆盖，距离0.00011465797803678143，该检测器半径为0.00013224024272502944
# 第258个异常样本，被第31144个自体检测器错误覆盖，距离3.5357538584486485e-05，该检测器半径为5.2309897615050895e-05
# 第259个异常样本，被第4426个自体检测器错误覆盖，距离0.0002067950573408495，该检测器半径为0.00036991876326851236
# 第260个异常样本，被第2735个自体检测器错误覆盖，距离0.003390850734906725，该检测器半径为0.0036766143594249624
# 第262个异常样本，被第1464个自体检测器错误覆盖，距离8.895881030895218e-07，该检测器半径为1e-06
# 第265个异常样本，被第1886个自体检测器错误覆盖，距离0.00012857041727775743，该检测器半径为0.000299043979499568
# 第266个异常样本，被第9106个自体检测器错误覆盖，距离5.80923640807593e-06，该检测器半径为9.736036039029745e-06
# 第268个异常样本，被第1886个自体检测器错误覆盖，距离0.00016541768235656825，该检测器半径为0.000299043979499568
# 第269个异常样本，被第1464个自体检测器错误覆盖，距离1.9542691048333467e-07，该检测器半径为1e-06
# 第271个异常样本，被第1886个自体检测器错误覆盖，距离0.00015784818269386436，该检测器半径为0.000299043979499568
# 第272个异常样本，被第126个自体检测器错误覆盖，距离5.740332725738752e-07，该检测器半径为1e-06
# 第273个异常样本，被第45个自体检测器错误覆盖，距离0.0003179830054897408，该检测器半径为0.00043756297970661624
# 第274个异常样本，被第25103个自体检测器错误覆盖，距离8.492502648378139e-05，该检测器半径为0.00010613917468223686
# 第275个异常样本，被第9195个自体检测器错误覆盖，距离0.0003121945265372354，该检测器半径为0.003673344580233931
# 第276个异常样本，被第25103个自体检测器错误覆盖，距离9.585263181034204e-05，该检测器半径为0.00010613917468223686
# 第277个异常样本，被第2379个自体检测器错误覆盖，距离2.5636928126588687e-07，该检测器半径为1e-06
# 第278个异常样本，被第2601个自体检测器错误覆盖，距离4.410340960904581e-07，该检测器半径为1e-06
# 第281个异常样本，被第11390个自体检测器错误覆盖，距离0.004474238743715098，该检测器半径为0.005523557566888872
# 第282个异常样本，被第36828个自体检测器错误覆盖，距离0.00016724105289576922，该检测器半径为0.00020930903857954928
# 第283个异常样本，被第605个自体检测器错误覆盖，距离3.840410579793284e-05，该检测器半径为0.00010555879412769592
# 第284个异常样本，被第513个自体检测器错误覆盖，距离2.1073424255447017e-07，该检测器半径为1.3314669074826644e-06
# 第285个异常样本，被第66个自体检测器错误覆盖，距离4.1616679004394423e-07，该检测器半径为1e-06
# 第286个异常样本，被第11390个自体检测器错误覆盖，距离0.0036961565402393024，该检测器半径为0.005523557566888872
# 第287个异常样本，被第1886个自体检测器错误覆盖，距离1.0657945516714758e-05，该检测器半径为0.000299043979499568
# 第288个异常样本，被第694个自体检测器错误覆盖，距离3.8513088179856877e-07，该检测器半径为1e-06
# 第289个异常样本，被第9341个自体检测器错误覆盖，距离3.434578984451542e-05，该检测器半径为5.392326604942038e-05
# 第290个异常样本，被第4830个自体检测器错误覆盖，距离0.014535041196698715，该检测器半径为0.015047244166147153
# 第291个异常样本，被第2383个自体检测器错误覆盖，距离0.0043775572187388975，该检测器半径为0.008219895856449416
# 第293个异常样本，被第21775个自体检测器错误覆盖，距离0.004987857383548349，该检测器半径为0.006961842249797368
# 第294个异常样本，被第1619个自体检测器错误覆盖，距离3.1539813415972557e-07，该检测器半径为1e-06
# 第295个异常样本，被第1503个自体检测器错误覆盖，距离4.256623108906654e-07，该检测器半径为1e-06
# 第296个异常样本，被第447个自体检测器错误覆盖，距离3.9424766765007236e-07，该检测器半径为1e-06
# 第297个异常样本，被第8046个自体检测器错误覆盖，距离9.520453459118666e-05，该检测器半径为0.00043574675211844455
# 第299个异常样本，被第8309个自体检测器错误覆盖，距离0.0003774659517318184，该检测器半径为0.0005982697249168783
# 第300个异常样本，被第1886个自体检测器错误覆盖，距离0.0001365459643229914，该检测器半径为0.000299043979499568
# 第301个异常样本，被第1464个自体检测器错误覆盖，距离2.0212919786596934e-07，该检测器半径为1e-06
# 第302个异常样本，被第23262个自体检测器错误覆盖，距离0.00011581794079061083，该检测器半径为0.00017410687188262108
# 第303个异常样本，被第1886个自体检测器错误覆盖，距离0.00020412621830866233，该检测器半径为0.000299043979499568
# 第307个异常样本，被第447个自体检测器错误覆盖，距离8.704115182575353e-07，该检测器半径为1e-06
# 第308个异常样本，被第8309个自体检测器错误覆盖，距离0.0003952337556773769，该检测器半径为0.0005982697249168783
# 第309个异常样本，被第284个自体检测器错误覆盖，距离3.97612579019737e-07，该检测器半径为1e-06
# 第312个异常样本，被第87个自体检测器错误覆盖，距离5.356133259004285e-07，该检测器半径为1e-06
# 第313个异常样本，被第8309个自体检测器错误覆盖，距离0.0003205477129649157，该检测器半径为0.0005982697249168783
# 第314个异常样本，被第10488个自体检测器错误覆盖，距离5.0518233463689085e-06，该检测器半径为7.320111071910964e-06
# 第317个异常样本，被第958个自体检测器错误覆盖，距离7.873681211171388e-07，该检测器半径为1e-06
# 第318个异常样本，被第1886个自体检测器错误覆盖，距离0.00012744254330406075，该检测器半径为0.000299043979499568
# 第319个异常样本，被第1886个自体检测器错误覆盖，距离0.0002741810566204976，该检测器半径为0.000299043979499568
# 第320个异常样本，被第28225个自体检测器错误覆盖，距离0.0004137863314913341，该检测器半径为0.0013875601335665783
# 第321个异常样本，被第6559个自体检测器错误覆盖，距离0.0007327950656546947，该检测器半径为0.0007474388805345792
# 第322个异常样本，被第513个自体检测器错误覆盖，距离2.1073424255447017e-07，该检测器半径为1.3314669074826644e-06
# 第324个异常样本，被第8309个自体检测器错误覆盖，距离0.00037699267087117706，该检测器半径为0.0005982697249168783
# 第326个异常样本，被第8309个自体检测器错误覆盖，距离0.00038824324852545404，该检测器半径为0.0005982697249168783
# 第327个异常样本，被第905个自体检测器错误覆盖，距离9.70293328853876e-07，该检测器半径为1e-06
# 第328个异常样本，被第955个自体检测器错误覆盖，距离2.1768490299666815e-05，该检测器半径为2.8078410306887734e-05
# 第330个异常样本，被第66个自体检测器错误覆盖，距离5.247240374006292e-07，该检测器半径为1e-06
# 第331个异常样本，被第24642个自体检测器错误覆盖，距离1.9741648832341736e-06，该检测器半径为2.377470812222854e-06
# 第332个异常样本，被第13832个自体检测器错误覆盖，距离0.0005413299723087897，该检测器半径为0.0005497556818776013
# 第333个异常样本，被第26212个自体检测器错误覆盖，距离4.101691839773292e-06，该检测器半径为3.16800369139805e-05
# 第334个异常样本，被第2379个自体检测器错误覆盖，距离2.950279395762582e-07，该检测器半径为1e-06
# 第336个异常样本，被第131个自体检测器错误覆盖，距离5.031211135586457e-07，该检测器半径为1e-06
# 第337个异常样本，被第1886个自体检测器错误覆盖，距离0.0001901064239017748，该检测器半径为0.000299043979499568
# 第338个异常样本，被第25103个自体检测器错误覆盖，距离9.148509634677754e-05，该检测器半径为0.00010613917468223686
# 第339个异常样本，被第36117个自体检测器错误覆盖，距离4.846887597126842e-06，该检测器半径为7.332734091797959e-06
# 第340个异常样本，被第284个自体检测器错误覆盖，距离4.897021315117365e-07，该检测器半径为1e-06
# 第343个异常样本，被第15628个自体检测器错误覆盖，距离0.004216651031097887，该检测器半径为0.0059534324981029415
# 第344个异常样本，被第1366个自体检测器错误覆盖，距离0.013639387918750826，该检测器半径为0.027769726216170385
# 第348个异常样本，被第1464个自体检测器错误覆盖，距离9.753148756222347e-07，该检测器半径为1e-06
# 第349个异常样本，被第66个自体检测器错误覆盖，距离7.64474604770169e-07，该检测器半径为1e-06
# 第350个异常样本，被第1886个自体检测器错误覆盖，距离0.00022168985709526573，该检测器半径为0.000299043979499568
# 第351个异常样本，被第15289个自体检测器错误覆盖，距离1.9137755844729853e-05，该检测器半径为2.2642327918151903e-05
# 第352个异常样本，被第36857个自体检测器错误覆盖，距离1.3437509935155728e-06，该检测器半径为1.47559120216097e-06
# 第354个异常样本，被第9849个自体检测器错误覆盖，距离3.8092218471369432e-06，该检测器半径为4.466671226061295e-06
# 第355个异常样本，被第12744个自体检测器错误覆盖，距离1.4338943953678063e-05，该检测器半径为2.220028485362865e-05
# 第356个异常样本，被第18988个自体检测器错误覆盖，距离8.21526464214055e-05，该检测器半径为0.00023727683990723181
# 第357个异常样本，被第8309个自体检测器错误覆盖，距离0.0003749739560760092，该检测器半径为0.0005982697249168783
# 第358个异常样本，被第17025个自体检测器错误覆盖，距离0.00011922840621661833，该检测器半径为0.0003093035008921291
# 第359个异常样本，被第32462个自体检测器错误覆盖，距离0.00031806279028154895，该检测器半径为0.0003241991737907873
# 第360个异常样本，被第9143个自体检测器错误覆盖，距离8.582732530794824e-05，该检测器半径为0.0001278050335739671
# 第362个异常样本，被第728个自体检测器错误覆盖，距离0.0004723929336599463，该检测器半径为0.0004817066228851818
# 第363个异常样本，被第516个自体检测器错误覆盖，距离0.00018645647648589503，该检测器半径为0.0002458494114801882
# 第366个异常样本，被第905个自体检测器错误覆盖，距离8.647810407980211e-07，该检测器半径为1e-06
# 第367个异常样本，被第126个自体检测器错误覆盖，距离9.698355353350564e-07，该检测器半径为1e-06
# 第370个异常样本，被第4426个自体检测器错误覆盖，距离0.0002053465157161455，该检测器半径为0.00036991876326851236
# 第371个异常样本，被第9790个自体检测器错误覆盖，距离0.00012227896144298506，该检测器半径为0.00021986984994190782
# 第372个异常样本，被第516个自体检测器错误覆盖，距离7.249726567660259e-05，该检测器半径为0.0002458494114801882
# 第373个异常样本，被第839个自体检测器错误覆盖，距离6.286806837023956e-07，该检测器半径为1e-06
# 第374个异常样本，被第4426个自体检测器错误覆盖，距离0.00026876045470544094，该检测器半径为0.00036991876326851236
# 第375个异常样本，被第1886个自体检测器错误覆盖，距离0.0001476137728906628，该检测器半径为0.000299043979499568
# 第376个异常样本，被第1173个自体检测器错误覆盖，距离9.978216422210366e-07，该检测器半径为1e-06
# 第377个异常样本，被第26768个自体检测器错误覆盖，距离1.5439559186745176e-05，该检测器半径为2.4299773641530947e-05
# 第379个异常样本，被第694个自体检测器错误覆盖，距离2.79570574681183e-07，该检测器半径为1e-06
# 第380个异常样本，被第22635个自体检测器错误覆盖，距离1.9443565989394624e-05，该检测器半径为2.791619506143828e-05
# 第381个异常样本，被第4426个自体检测器错误覆盖，距离0.0002023325430015495，该检测器半径为0.00036991876326851236
# 第382个异常样本，被第9790个自体检测器错误覆盖，距离0.00013157280823214277，该检测器半径为0.00021986984994190782
# 第384个异常样本，被第674个自体检测器错误覆盖，距离4.721575831697839e-07，该检测器半径为1e-06
# 第385个异常样本，被第295个自体检测器错误覆盖，距离0.00029585334637521925，该检测器半径为0.00040246646445255186
# 第386个异常样本，被第4975个自体检测器错误覆盖，距离7.557107548811279e-07，该检测器半径为1e-06
# 第387个异常样本，被第6321个自体检测器错误覆盖，距离0.00018295676055105284，该检测器半径为0.00022985184211532993
# 第388个异常样本，被第35244个自体检测器错误覆盖，距离2.3772840243241643e-06，该检测器半径为5.861159182428538e-06
# 第389个异常样本，被第4830个自体检测器错误覆盖，距离0.013357777100299013，该检测器半径为0.015047244166147153
# 第390个异常样本，被第11207个自体检测器错误覆盖，距离1.0674890789493384e-06，该检测器半径为1.5969985385619205e-06
# 第392个异常样本，被第25750个自体检测器错误覆盖，距离0.0001820367861120329，该检测器半径为0.0002198647034766237
# 第394个异常样本，被第315个自体检测器错误覆盖，距离1.5769906706002895e-07，该检测器半径为1e-06
# 第396个异常样本，被第4013个自体检测器错误覆盖，距离0.00027608570992051747，该检测器半径为0.000310929146113397
# 第397个异常样本，被第1503个自体检测器错误覆盖，距离5.389196114076975e-07，该检测器半径为1e-06
# 第398个异常样本，被第1503个自体检测器错误覆盖，距离5.397430184629755e-07，该检测器半径为1e-06
# 第399个异常样本，被第38527个自体检测器错误覆盖，距离0.00015633642332623873，该检测器半径为0.0004445722736955238
# 第400个异常样本，被第441个自体检测器错误覆盖，距离0.0003250374840918377，该检测器半径为0.0003791414060520321
# 第401个异常样本，被第513个自体检测器错误覆盖，距离2.3654861183292964e-07，该检测器半径为1.3314669074826644e-06
# 第402个异常样本，被第49873个自体检测器错误覆盖，距离1.8147705724721545e-05，该检测器半径为1.8829638181047635e-05
# 第403个异常样本，被第8309个自体检测器错误覆盖，距离0.00040413864068511153，该检测器半径为0.0005982697249168783
# 第404个异常样本，被第3140个自体检测器错误覆盖，距离0.00034396668415866686，该检测器半径为0.0007820413484637409
# 第405个异常样本，被第284个自体检测器错误覆盖，距离7.456538821283801e-07，该检测器半径为1e-06
# 第408个异常样本，被第6559个自体检测器错误覆盖，距离0.0006683610407258975，该检测器半径为0.0007474388805345792
# 第410个异常样本，被第66个自体检测器错误覆盖，距离2.6320698458933376e-07，该检测器半径为1e-06
# 第412个异常样本，被第295个自体检测器错误覆盖，距离0.00039805623040985844，该检测器半径为0.00040246646445255186
# 第414个异常样本，被第284个自体检测器错误覆盖，距离6.495265619484222e-07，该检测器半径为1e-06
# 第415个异常样本，被第50166个自体检测器错误覆盖，距离0.0007612774815169772，该检测器半径为0.0020739048601762055
# 第416个异常样本，被第45459个自体检测器错误覆盖，距离3.849252315646216e-05，该检测器半径为6.481850967547366e-05
# 第417个异常样本，被第8309个自体检测器错误覆盖，距离0.0004510062123357933，该检测器半径为0.0005982697249168783
# 第418个异常样本，被第6101个自体检测器错误覆盖，距离2.8510715349381538e-06，该检测器半径为3.0089278358267795e-06
# 第419个异常样本，被第22871个自体检测器错误覆盖，距离3.1104545742330915e-06，该检测器半径为3.3527791499614716e-05
# 第421个异常样本，被第47171个自体检测器错误覆盖，距离2.151554321867519e-06，该检测器半径为3.5159478508634436e-06
# 第422个异常样本，被第1886个自体检测器错误覆盖，距离0.00019942374507756573，该检测器半径为0.000299043979499568
# 第423个异常样本，被第23262个自体检测器错误覆盖，距离3.900123252125408e-05，该检测器半径为0.00017410687188262108
# 第424个异常样本，被第11952个自体检测器错误覆盖，距离0.005673276180087245，该检测器半径为0.005814218141121463
# 第425个异常样本，被第284个自体检测器错误覆盖，距离6.129433030338115e-07，该检测器半径为1e-06
# 第427个异常样本，被第21168个自体检测器错误覆盖，距离0.00017489985291136044，该检测器半径为0.0011530490086106102
# 第430个异常样本，被第28712个自体检测器错误覆盖，距离0.00023625333520028264，该检测器半径为0.0002616802034767565
# 第431个异常样本，被第8309个自体检测器错误覆盖，距离0.00038638928317582405，该检测器半径为0.0005982697249168783
# 第432个异常样本，被第8309个自体检测器错误覆盖，距离0.00048554088697994735，该检测器半径为0.0005982697249168783
# 第433个异常样本，被第6738个自体检测器错误覆盖，距离6.034510397710703e-07，该检测器半径为1e-06
# 第434个异常样本，被第8309个自体检测器错误覆盖，距离0.00038304299258519947，该检测器半径为0.0005982697249168783
# 第435个异常样本，被第6559个自体检测器错误覆盖，距离0.0005830728188944254，该检测器半径为0.0007474388805345792
# 第437个异常样本，被第31144个自体检测器错误覆盖，距离3.928658297183734e-05，该检测器半径为5.2309897615050895e-05
# 第439个异常样本，被第18988个自体检测器错误覆盖，距离0.00010677411430821994，该检测器半径为0.00023727683990723181
# 第440个异常样本，被第1464个自体检测器错误覆盖，距离3.538829785415683e-07，该检测器半径为1e-06
# 第442个异常样本，被第154个自体检测器错误覆盖，距离8.915826965250015e-07，该检测器半径为1e-06
# 第443个异常样本，被第4426个自体检测器错误覆盖，距离0.000167757029185143，该检测器半径为0.00036991876326851236
# 第444个异常样本，被第23262个自体检测器错误覆盖，距离8.580627918496986e-05，该检测器半径为0.00017410687188262108
# 第445个异常样本，被第66个自体检测器错误覆盖，距离6.880400438842721e-07，该检测器半径为1e-06
# 第446个异常样本，被第699个自体检测器错误覆盖，距离1.5088424774183457e-05，该检测器半径为1.749040259325924e-05
# 第447个异常样本，被第284个自体检测器错误覆盖，距离3.97612579019737e-07，该检测器半径为1e-06
# 第449个异常样本，被第1886个自体检测器错误覆盖，距离0.00017246578732564477，该检测器半径为0.000299043979499568
# 第450个异常样本，被第24642个自体检测器错误覆盖，距离1.7906211703395835e-06，该检测器半径为2.377470812222854e-06
# 第451个异常样本，被第31055个自体检测器错误覆盖，距离6.539257120434072e-05，该检测器半径为0.0022564377310168963
# 第453个异常样本，被第36864个自体检测器错误覆盖，距离0.00015228256245315304，该检测器半径为0.0001574388326279927
# 第454个异常样本，被第8309个自体检测器错误覆盖，距离0.00037318846394658064，该检测器半径为0.0005982697249168783
# 第455个异常样本，被第1886个自体检测器错误覆盖，距离0.0002571106650851461，该检测器半径为0.000299043979499568
# 第456个异常样本，被第26212个自体检测器错误覆盖，距离2.3299241452208432e-06，该检测器半径为3.16800369139805e-05
# 第457个异常样本，被第7628个自体检测器错误覆盖，距离8.835773028024152e-07，该检测器半径为1e-06
# 第458个异常样本，被第66个自体检测器错误覆盖，距离6.867479487766023e-07，该检测器半径为1e-06
# 第459个异常样本，被第23262个自体检测器错误覆盖，距离7.246612256802299e-05，该检测器半径为0.00017410687188262108
# 第460个异常样本，被第31144个自体检测器错误覆盖，距离4.9072363234247626e-05，该检测器半径为5.2309897615050895e-05
# 第462个异常样本，被第1886个自体检测器错误覆盖，距离0.00026658214692619687，该检测器半径为0.000299043979499568
# 第463个异常样本，被第15673个自体检测器错误覆盖，距离1.7696658307415571e-06，该检测器半径为1.2304254328263447e-05
# 第464个异常样本，被第1886个自体检测器错误覆盖，距离0.0002546314558250163，该检测器半径为0.000299043979499568
# 第465个异常样本，被第13666个自体检测器错误覆盖，距离0.005912866491024672，该检测器半径为0.013694260230188356
# 第466个异常样本，被第513个自体检测器错误覆盖，距离1.0241771013070305e-06，该检测器半径为1.3314669074826644e-06
# 第467个异常样本，被第66个自体检测器错误覆盖，距离7.85108810578324e-07，该检测器半径为1e-06
# 第468个异常样本，被第66个自体检测器错误覆盖，距离5.662441300408342e-07，该检测器半径为1e-06
# 第469个异常样本，被第1503个自体检测器错误覆盖，距离4.380029040419515e-07，该检测器半径为1e-06
# 第470个异常样本，被第15983个自体检测器错误覆盖，距离0.00010755924873481518，该检测器半径为0.00021972487949381984
# 第473个异常样本，被第6101个自体检测器错误覆盖，距离1.691659207010087e-06，该检测器半径为3.0089278358267795e-06
# 第474个异常样本，被第87个自体检测器错误覆盖，距离8.210526412408636e-07，该检测器半径为1e-06
# 第475个异常样本，被第28884个自体检测器错误覆盖，距离5.204751899010116e-07，该检测器半径为1e-06
# 第476个异常样本，被第1503个自体检测器错误覆盖，距离3.793216365980463e-07，该检测器半径为1e-06
# 第477个异常样本，被第66个自体检测器错误覆盖，距离8.714313329114407e-07，该检测器半径为1e-06
# 第478个异常样本，被第315个自体检测器错误覆盖，距离3.1256940106181265e-07，该检测器半径为1e-06
# 第480个异常样本，被第4426个自体检测器错误覆盖，距离0.00016760745034659447，该检测器半径为0.00036991876326851236
# 第481个异常样本，被第728个自体检测器错误覆盖，距离0.00047436044330654783，该检测器半径为0.0004817066228851818
# 第482个异常样本，被第1618个自体检测器错误覆盖，距离7.719894680337207e-07，该检测器半径为1e-06
# 第483个异常样本，被第295个自体检测器错误覆盖，距离0.00031816277683416853，该检测器半径为0.00040246646445255186
# 第484个异常样本，被第1886个自体检测器错误覆盖，距离0.0002430733064424648，该检测器半径为0.000299043979499568
# 第487个异常样本，被第447个自体检测器错误覆盖，距离9.339117877410725e-07，该检测器半径为1e-06
# 第489个异常样本，被第1618个自体检测器错误覆盖，距离6.314998929005931e-07，该检测器半径为1e-06
# 第490个异常样本，被第47849个自体检测器错误覆盖，距离4.3225708478615794e-05，该检测器半径为5.222499230779306e-05
# 第491个异常样本，被第1886个自体检测器错误覆盖，距离0.00013793855132215974，该检测器半径为0.000299043979499568
# 第492个异常样本，被第14393个自体检测器错误覆盖，距离0.0007378444534461478，该检测器半径为0.000953461179790786
# 第493个异常样本，被第18988个自体检测器错误覆盖，距离0.00015504956027801443，该检测器半径为0.00023727683990723181
# 第494个异常样本，被第23262个自体检测器错误覆盖，距离4.485949472916913e-05，该检测器半径为0.00017410687188262108
# 第496个异常样本，被第23262个自体检测器错误覆盖，距离0.00013372496330835083，该检测器半径为0.00017410687188262108
# 第497个异常样本，被第44982个自体检测器错误覆盖，距离0.0004536316542290047，该检测器半径为0.0008705580367075172
# 第498个异常样本，被第126个自体检测器错误覆盖，距离6.508925604953098e-07，该检测器半径为1e-06
# 第499个异常样本，被第24642个自体检测器错误覆盖，距离1.5158224224216278e-06，该检测器半径为2.377470812222854e-06
# 第500个异常样本，被第8015个自体检测器错误覆盖，距离5.143332597461084e-05，该检测器半径为7.72711922907326e-05
# 第501个异常样本，被第23262个自体检测器错误覆盖，距离3.432769608422168e-05，该检测器半径为0.00017410687188262108
# 第502个异常样本，被第18988个自体检测器错误覆盖，距离0.00013477931848355883，该检测器半径为0.00023727683990723181
# 第505个异常样本，被第7183个自体检测器错误覆盖，距离0.0005721240488465901，该检测器半径为0.0005784907984339018
# 第506个异常样本，被第15289个自体检测器错误覆盖，距离1.3812275375341883e-05，该检测器半径为2.2642327918151903e-05
# 第508个异常样本，被第1503个自体检测器错误覆盖，距离6.467859436124e-07，该检测器半径为1e-06
# 第509个异常样本，被第6321个自体检测器错误覆盖，距离9.553267740458702e-05，该检测器半径为0.00022985184211532993
# 第511个异常样本，被第4013个自体检测器错误覆盖，距离0.000248262865610225，该检测器半径为0.000310929146113397
# 第512个异常样本，被第694个自体检测器错误覆盖，距离9.447853369810782e-07，该检测器半径为1e-06
# 第513个异常样本，被第447个自体检测器错误覆盖，距离7.140129074772213e-07，该检测器半径为1e-06
# 第516个异常样本，被第1618个自体检测器错误覆盖，距离5.575504023926181e-07，该检测器半径为1e-06
# 第517个异常样本，被第2525个自体检测器错误覆盖，距离8.835772950003551e-07，该检测器半径为1e-06
# 第518个异常样本，被第1503个自体检测器错误覆盖，距离7.69107815464378e-07，该检测器半径为1e-06
# 第519个异常样本，被第1418个自体检测器错误覆盖，距离9.597088232985743e-07，该检测器半径为1e-06
# 第520个异常样本，被第39987个自体检测器错误覆盖，距离3.600781663768669e-06，该检测器半径为6.142731472068041e-06
# 第522个异常样本，被第1886个自体检测器错误覆盖，距离0.0002300281398928199，该检测器半径为0.000299043979499568
# 第523个异常样本，被第147个自体检测器错误覆盖，距离0.003682167821492314，该检测器半径为0.0037146805573873717
# 第526个异常样本，被第46511个自体检测器错误覆盖，距离7.458223394368452e-05，该检测器半径为0.00015070093024069717
# 第527个异常样本，被第839个自体检测器错误覆盖，距离6.440336383248272e-07，该检测器半径为1e-06
# 第528个异常样本，被第284个自体检测器错误覆盖，距离5.272569104850533e-07，该检测器半径为1e-06
# 第530个异常样本，被第7310个自体检测器错误覆盖，距离0.000531518323934085，该检测器半径为0.0005903668563761014
# 第531个异常样本，被第4426个自体检测器错误覆盖，距离0.00023672674284438218，该检测器半径为0.00036991876326851236
# 第532个异常样本，被第23262个自体检测器错误覆盖，距离3.851278837600947e-05，该检测器半径为0.00017410687188262108
# 第533个异常样本，被第8665个自体检测器错误覆盖，距离1.9082798668345545e-07，该检测器半径为1e-06
# 第534个异常样本，被第18988个自体检测器错误覆盖，距离0.00011025423443708181，该检测器半径为0.00023727683990723181
# 第537个异常样本，被第284个自体检测器错误覆盖，距离8.627244751349119e-07，该检测器半径为1e-06
# 第538个异常样本，被第18988个自体检测器错误覆盖，距离0.00010224113566934312，该检测器半径为0.00023727683990723181
# 第539个异常样本，被第791个自体检测器错误覆盖，距离0.0004342978286322495，该检测器半径为0.0004933714091057292
# 第540个异常样本，被第8309个自体检测器错误覆盖，距离0.0003428913516672005，该检测器半径为0.0005982697249168783
# 第541个异常样本，被第4830个自体检测器错误覆盖，距离0.0036864805276230262，该检测器半径为0.015047244166147153
# 第542个异常样本，被第47171个自体检测器错误覆盖，距离2.9730711076567574e-06，该检测器半径为3.5159478508634436e-06
# 第544个异常样本，被第3457个自体检测器错误覆盖，距离9.049312145093095e-07，该检测器半径为1e-06
# 第545个异常样本，被第87个自体检测器错误覆盖，距离2.2101993826016942e-07，该检测器半径为1e-06
# 第546个异常样本，被第36792个自体检测器错误覆盖，距离0.00021498713715442774，该检测器半径为0.00022509593506992267
# 第547个异常样本，被第2900个自体检测器错误覆盖，距离1.884864366154897e-07，该检测器半径为1e-06
# 第548个异常样本，被第5301个自体检测器错误覆盖，距离0.0003954257960332511，该检测器半径为0.0004392189233020771
# 第549个异常样本，被第8309个自体检测器错误覆盖，距离0.0004648448281035603，该检测器半径为0.0005982697249168783
# 第551个异常样本，被第1618个自体检测器错误覆盖，距离9.195356842943738e-07，该检测器半径为1e-06
# 第552个异常样本，被第1886个自体检测器错误覆盖，距离0.00028892650984866736，该检测器半径为0.000299043979499568
# 第553个异常样本，被第295个自体检测器错误覆盖，距离0.0001247594486268219，该检测器半径为0.00040246646445255186
# 第554个异常样本，被第2516个自体检测器错误覆盖，距离1.6324438055501827e-05，该检测器半径为2.6736225502948227e-05
# 第555个异常样本，被第6657个自体检测器错误覆盖，距离3.016613391066248e-05，该检测器半径为5.248512413322276e-05
# 第556个异常样本，被第6559个自体检测器错误覆盖，距离0.0006304718443010339，该检测器半径为0.0007474388805345792
# 第557个异常样本，被第66个自体检测器错误覆盖，距离9.054218356762878e-07，该检测器半径为1e-06
# 第558个异常样本，被第162个自体检测器错误覆盖，距离0.0003915573483963565，该检测器半径为0.0008798354174571309
# 第559个异常样本，被第3085个自体检测器错误覆盖，距离0.000955513174171317，该检测器半径为0.0028974593105448214
# 第560个异常样本，被第35149个自体检测器错误覆盖，距离5.2912997387178115e-05，该检测器半径为9.160323863126172e-05
# 第561个异常样本，被第839个自体检测器错误覆盖，距离9.87981833024596e-07，该检测器半径为1e-06
# 第564个异常样本，被第905个自体检测器错误覆盖，距离9.205010763329517e-07，该检测器半径为1e-06
# 第567个异常样本，被第2356个自体检测器错误覆盖，距离2.8805143322735185e-06，该检测器半径为4.334547755617825e-06
# 第568个异常样本，被第284个自体检测器错误覆盖，距离7.312205070020405e-07，该检测器半径为1e-06
# 第569个异常样本，被第6321个自体检测器错误覆盖，距离0.00019444365541046167，该检测器半径为0.00022985184211532993
# 第570个异常样本，被第1624个自体检测器错误覆盖，距离5.3264188112387575e-05，该检测器半径为0.00020468098869833222
# 第573个异常样本，被第288个自体检测器错误覆盖，距离9.513431719837116e-07，该检测器半径为1e-06
# 第578个异常样本，被第11416个自体检测器错误覆盖，距离0.0003464102573045171，该检测器半径为0.00047384449879527295
# 第579个异常样本，被第9179个自体检测器错误覆盖，距离0.00040679630230187766，该检测器半径为0.00041165381052809966
# 第580个异常样本，被第66个自体检测器错误覆盖，距离8.930757190893253e-07，该检测器半径为1e-06
# 第581个异常样本，被第4426个自体检测器错误覆盖，距离0.00022052424947130913，该检测器半径为0.00036991876326851236
# 第584个异常样本，被第10469个自体检测器错误覆盖，距离7.171159634476105e-07，该检测器半径为1e-06
# 第585个异常样本，被第295个自体检测器错误覆盖，距离0.0003952941867377559，该检测器半径为0.00040246646445255186
# 第588个异常样本，被第9790个自体检测器错误覆盖，距离0.00016030921857690988，该检测器半径为0.00021986984994190782
# 第589个异常样本，被第4785个自体检测器错误覆盖，距离9.490062818020023e-07，该检测器半径为1e-06
# 第592个异常样本，被第26212个自体检测器错误覆盖，距离3.348089009202521e-06，该检测器半径为3.16800369139805e-05
# 第593个异常样本，被第1464个自体检测器错误覆盖，距离5.938070713158308e-07，该检测器半径为1e-06
# 第595个异常样本，被第14714个自体检测器错误覆盖，距离9.281880587618544e-07，该检测器半径为1e-06
# 第598个异常样本，被第6532个自体检测器错误覆盖，距离0.010149000878325562，该检测器半径为0.011346927120192495
# 第599个异常样本，被第36864个自体检测器错误覆盖，距离0.00014559468837706165，该检测器半径为0.0001574388326279927
# 第602个异常样本，被第31144个自体检测器错误覆盖，距离4.916457429019852e-05，该检测器半径为5.2309897615050895e-05
# 第603个异常样本，被第985个自体检测器错误覆盖，距离1.9542689693874122e-07，该检测器半径为1e-06
# 第604个异常样本，被第1886个自体检测器错误覆盖，距离0.00028077854685229676，该检测器半径为0.000299043979499568
# 第605个异常样本，被第288个自体检测器错误覆盖，距离5.136039290590494e-07，该检测器半径为1e-06
# 第607个异常样本，被第22614个自体检测器错误覆盖，距离0.012715092047881588，该检测器半径为0.013971658353309914
# 第608个异常样本，被第8309个自体检测器错误覆盖，距离0.0004962741462102733，该检测器半径为0.0005982697249168783
# 第610个异常样本，被第173个自体检测器错误覆盖，距离9.638644345457274e-07，该检测器半径为1e-06
# 第612个异常样本，被第28225个自体检测器错误覆盖，距离0.0006301728263847034，该检测器半径为0.0013875601335665783
# 第613个异常样本，被第14936个自体检测器错误覆盖，距离8.785368892969788e-07，该检测器半径为1e-06
# 第614个异常样本，被第839个自体检测器错误覆盖，距离8.935728389150018e-07，该检测器半径为1e-06
# 第615个异常样本，被第66个自体检测器错误覆盖，距离3.0827761986221675e-07，该检测器半径为1e-06
# 第616个异常样本，被第447个自体检测器错误覆盖，距离4.683802675016413e-07，该检测器半径为1e-06
# 第617个异常样本，被第31144个自体检测器错误覆盖，距离4.9930551579632003e-05，该检测器半径为5.2309897615050895e-05
# 第618个异常样本，被第2286个自体检测器错误覆盖，距离5.794233745153466e-07，该检测器半径为1e-06
# 第619个异常样本，被第447个自体检测器错误覆盖，距离8.508028075585776e-07，该检测器半径为1e-06
# 第620个异常样本，被第126个自体检测器错误覆盖，距离7.89058357376684e-07，该检测器半径为1e-06
# 第622个异常样本，被第295个自体检测器错误覆盖，距离0.00021983234595210013，该检测器半径为0.00040246646445255186
# 第624个异常样本，被第8766个自体检测器错误覆盖，距离0.0，该检测器半径为1e-06
# 第625个异常样本，被第162个自体检测器错误覆盖，距离0.00022781084387075363，该检测器半径为0.0008798354174571309
# 第626个异常样本，被第1418个自体检测器错误覆盖，距离6.474721724510321e-07，该检测器半径为1e-06
# 第627个异常样本，被第745个自体检测器错误覆盖，距离6.515744699845429e-07，该检测器半径为1e-06
# 第629个异常样本，被第21996个自体检测器错误覆盖，距离0.00023630121976820866，该检测器半径为0.0003365778519720795
# 第630个异常样本，被第9195个自体检测器错误覆盖，距离0.0009344620256323695，该检测器半径为0.003673344580233931
# 第631个异常样本，被第447个自体检测器错误覆盖，距离8.301966387436492e-07，该检测器半径为1e-06
# 第632个异常样本，被第288个自体检测器错误覆盖，距离8.780312577040243e-07，该检测器半径为1e-06
# 第633个异常样本，被第18988个自体检测器错误覆盖，距离0.00012317273163360776，该检测器半径为0.00023727683990723181
# 第635个异常样本，被第66个自体检测器错误覆盖，距离3.8628225406246266e-07，该检测器半径为1e-06
# 第636个异常样本，被第24783个自体检测器错误覆盖，距离1.1542389828584841e-07，该检测器半径为1e-06
# 第637个异常样本，被第447个自体检测器错误覆盖，距离5.990192708735076e-07，该检测器半径为1e-06
# 第638个异常样本，被第905个自体检测器错误覆盖，距离8.95558558736064e-07，该检测器半径为1e-06
# 第639个异常样本，被第8665个自体检测器错误覆盖，距离1.6593232447193586e-07，该检测器半径为1e-06
# 第641个异常样本，被第8309个自体检测器错误覆盖，距离0.0005789071774009439，该检测器半径为0.0005982697249168783
# 第643个异常样本，被第5330个自体检测器错误覆盖，距离0.0005546141002763576，该检测器半径为0.0005924396626892595
# 第644个异常样本，被第728个自体检测器错误覆盖，距离0.0004731519637344485，该检测器半径为0.0004817066228851818
# 第645个异常样本，被第6411个自体检测器错误覆盖，距离6.034510389129806e-07，该检测器半径为1e-06
# 第646个异常样本，被第8309个自体检测器错误覆盖，距离0.00038568898175449527，该检测器半径为0.0005982697249168783
# 第648个异常样本，被第17025个自体检测器错误覆盖，距离0.0002885788023543729，该检测器半径为0.0003093035008921291
# 第649个异常样本，被第8309个自体检测器错误覆盖，距离0.000402139413721794，该检测器半径为0.0005982697249168783
# 第650个异常样本，被第23262个自体检测器错误覆盖，距离5.85812236606294e-05，该检测器半径为0.00017410687188262108
# 第651个异常样本，被第2598个自体检测器错误覆盖，距离8.496218819215072e-05，该检测器半径为9.781740799662816e-05
# 第653个异常样本，被第315个自体检测器错误覆盖，距离3.976125736274223e-07，该检测器半径为1e-06
# 第654个异常样本，被第513个自体检测器错误覆盖，距离5.824810397295572e-07，该检测器半径为1.3314669074826644e-06
# 第655个异常样本，被第66个自体检测器错误覆盖，距离2.5288109106536417e-07，该检测器半径为1e-06
# 第656个异常样本，被第513个自体检测器错误覆盖，距离6.049210809977031e-07，该检测器半径为1.3314669074826644e-06
# 第657个异常样本，被第29616个自体检测器错误覆盖，距离0.0002585073226187951，该检测器半径为0.0002673493379362835
# 第659个异常样本，被第295个自体检测器错误覆盖，距离0.00015608934131063784，该检测器半径为0.00040246646445255186
# 第660个异常样本，被第23262个自体检测器错误覆盖，距离0.0001116985158983049，该检测器半径为0.00017410687188262108
# 第661个异常样本，被第1886个自体检测器错误覆盖，距离0.00021501345198372872，该检测器半径为0.000299043979499568
# 第662个异常样本，被第6575个自体检测器错误覆盖，距离0.0005594844708240276，该检测器半径为0.0024863135950617355
# 第663个异常样本，被第8309个自体检测器错误覆盖，距离0.00047685647717106026，该检测器半径为0.0005982697249168783
# 第664个异常样本，被第9131个自体检测器错误覆盖，距离0.0001703787849877759，该检测器半径为0.0002834043975349729
# 第665个异常样本，被第66个自体检测器错误覆盖，距离5.031211125590338e-07，该检测器半径为1e-06
# 第666个异常样本，被第447个自体检测器错误覆盖，距离7.300048336237446e-07，该检测器半径为1e-06
# 第667个异常样本，被第1256个自体检测器错误覆盖，距离0.0032517462626196784，该检测器半径为0.003538218769083844
# 第668个异常样本，被第8309个自体检测器错误覆盖，距离0.0005155119703060169，该检测器半径为0.0005982697249168783
# 第669个异常样本，被第728个自体检测器错误覆盖，距离0.00047583417912340015，该检测器半径为0.0004817066228851818
# 第670个异常样本，被第7293个自体检测器错误覆盖，距离4.7590492994637737e-07，该检测器半径为1e-06
# 第671个异常样本，被第23262个自体检测器错误覆盖，距离0.00015243804291975878，该检测器半径为0.00017410687188262108
# 第672个异常样本，被第8099个自体检测器错误覆盖，距离0.00035835599880237217，该检测器半径为0.0003844115609808272
# 第673个异常样本，被第8309个自体检测器错误覆盖，距离0.0004476830997572947，该检测器半径为0.0005982697249168783
# 第674个异常样本，被第1886个自体检测器错误覆盖，距离0.00018954196442334993，该检测器半径为0.000299043979499568
# 第676个异常样本，被第66个自体检测器错误覆盖，距离3.3717479593761446e-07，该检测器半径为1e-06
# 第677个异常样本，被第8665个自体检测器错误覆盖，距离1.3978528260658472e-07，该检测器半径为1e-06
# 第679个异常样本，被第1464个自体检测器错误覆盖，距离6.8997364967611e-07，该检测器半径为1e-06
# 第680个异常样本，被第8309个自体检测器错误覆盖，距离0.00039635202000341927，该检测器半径为0.0005982697249168783
# 第681个异常样本，被第1813个自体检测器错误覆盖，距离7.913063826434883e-07，该检测器半径为1e-06
# 第683个异常样本，被第447个自体检测器错误覆盖，距离8.344650300275345e-07，该检测器半径为1e-06
# 第684个异常样本，被第6559个自体检测器错误覆盖，距离0.0006414054481119296，该检测器半径为0.0007474388805345792
# 第685个异常样本，被第1173个自体检测器错误覆盖，距离8.805565181174093e-07，该检测器半径为1e-06
# 第686个异常样本，被第29616个自体检测器错误覆盖，距离0.000153521841718411，该检测器半径为0.0002673493379362835
# 第688个异常样本，被第694个自体检测器错误覆盖，距离7.86803890969099e-07，该检测器半径为1e-06
# 第689个异常样本，被第2379个自体检测器错误覆盖，距离9.49006281786313e-07，该检测器半径为1e-06
# 第690个异常样本，被第938个自体检测器错误覆盖，距离0.0010950709945335359，该检测器半径为0.002519036766751294
# 第691个异常样本，被第839个自体检测器错误覆盖，距离9.834766495724656e-07，该检测器半径为1e-06
# 第692个异常样本，被第31144个自体检测器错误覆盖，距离4.2811313593511904e-05，该检测器半径为5.2309897615050895e-05
# 第694个异常样本，被第87个自体检测器错误覆盖，距离3.397987637999797e-07，该检测器半径为1e-06
# 第695个异常样本，被第9790个自体检测器错误覆盖，距离9.405133697839347e-05，该检测器半径为0.00021986984994190782
# 第696个异常样本，被第25575个自体检测器错误覆盖，距离2.5109425005023487e-05，该检测器半径为2.5130824920081664e-05
# 第697个异常样本，被第315个自体检测器错误覆盖，距离3.0827761986221675e-07，该检测器半径为1e-06
# 第698个异常样本，被第605个自体检测器错误覆盖，距离5.3663118319970864e-05，该检测器半径为0.00010555879412769592
# 第699个异常样本，被第4830个自体检测器错误覆盖，距离0.014250019054498332，该检测器半径为0.015047244166147153
# 第700个异常样本，被第791个自体检测器错误覆盖，距离0.00043421840129662586，该检测器半径为0.0004933714091057292
# 第701个异常样本，被第315个自体检测器错误覆盖，距离9.419608519330201e-07，该检测器半径为1e-06
# 第702个异常样本，被第8309个自体检测器错误覆盖，距离0.0003400123948107012，该检测器半径为0.0005982697249168783
# 第703个异常样本，被第2355个自体检测器错误覆盖，距离3.637837130205984e-07，该检测器半径为1e-06
# 第704个异常样本，被第35125个自体检测器错误覆盖，距离1.7893806882970754e-06，该检测器半径为3.3886957355748124e-06
# 第705个异常样本，被第31144个自体检测器错误覆盖，距离4.051709851769138e-05，该检测器半径为5.2309897615050895e-05
# 第706个异常样本，被第14935个自体检测器错误覆盖，距离0.0009730653756775534，该检测器半径为0.0020562379257681924
# 第707个异常样本，被第513个自体检测器错误覆盖，距离4.6932744795569884e-07，该检测器半径为1.3314669074826644e-06
# 第708个异常样本，被第87个自体检测器错误覆盖，距离5.221788775572185e-07，该检测器半径为1e-06
# 第711个异常样本，被第6639个自体检测器错误覆盖，距离0.0004433988924091355，该检测器半径为0.0010771624830390335
# 第712个异常样本，被第1173个自体检测器错误覆盖，距离5.630983050293267e-07，该检测器半径为1e-06
# 第713个异常样本，被第2631个自体检测器错误覆盖，距离1.0044753376218468e-06，该检测器半径为1.170950654558965e-06
# 第714个异常样本，被第47171个自体检测器错误覆盖，距离1.0477540483746928e-06，该检测器半径为3.5159478508634436e-06
# 第715个异常样本，被第1193个自体检测器错误覆盖，距离3.29177409922697e-07，该检测器半径为1e-06
# 第716个异常样本，被第1886个自体检测器错误覆盖，距离0.00015166578720632887，该检测器半径为0.000299043979499568
# 第717个异常样本，被第66个自体检测器错误覆盖，距离4.2878075769777944e-07，该检测器半径为1e-06
# 第718个异常样本，被第288个自体检测器错误覆盖，距离4.645722290313213e-07，该检测器半径为1e-06
# 第719个异常样本，被第4426个自体检测器错误覆盖，距离0.0003055735750789669，该检测器半径为0.00036991876326851236
# 第721个异常样本，被第6639个自体检测器错误覆盖，距离0.0005521582418754512，该检测器半径为0.0010771624830390335
# 第722个异常样本，被第694个自体检测器错误覆盖，距离5.306152696058564e-07，该检测器半径为1e-06
# 第723个异常样本，被第21124个自体检测器错误覆盖，距离8.621105688621295e-05，该检测器半径为9.7860298012581e-05
# 第724个异常样本，被第4830个自体检测器错误覆盖，距离0.012344828972398093，该检测器半径为0.015047244166147153
# 第725个异常样本，被第295个自体检测器错误覆盖，距离0.00027637791011665664，该检测器半径为0.00040246646445255186
# 第726个异常样本，被第66个自体检测器错误覆盖，距离4.712160960887644e-07，该检测器半径为1e-06
# 第728个异常样本，被第1886个自体检测器错误覆盖，距离0.00013246506404514298，该检测器半径为0.000299043979499568
# 第731个异常样本，被第28225个自体检测器错误覆盖，距离0.0013669471234503301，该检测器半径为0.0013875601335665783
# 第732个异常样本，被第2286个自体检测器错误覆盖，距离6.063875576262727e-07，该检测器半径为1e-06
# 第733个异常样本，被第694个自体检测器错误覆盖，距离5.331201540151775e-07，该检测器半径为1e-06
# 第734个异常样本，被第315个自体检测器错误覆盖，距离9.55070289668699e-07，该检测器半径为1e-06
# 第736个异常样本，被第14837个自体检测器错误覆盖，距离1.249922342202802e-06，该检测器半径为2.7268717846150097e-06
# 第737个异常样本，被第4830个自体检测器错误覆盖，距离0.014801403287412578，该检测器半径为0.015047244166147153
# 第738个异常样本，被第818个自体检测器错误覆盖，距离0.0011407031327446732，该检测器半径为0.003830920429692912
# 第739个异常样本，被第1886个自体检测器错误覆盖，距离0.00014965337601185108，该检测器半径为0.000299043979499568
# 第740个异常样本，被第447个自体检测器错误覆盖，距离4.683802675016413e-07，该检测器半径为1e-06
# 第741个异常样本，被第24642个自体检测器错误覆盖，距离1.9878394889621802e-06，该检测器半径为2.377470812222854e-06
# 第742个异常样本，被第899个自体检测器错误覆盖，距离5.794233753833231e-07，该检测器半径为1e-06
# 第743个异常样本，被第25103个自体检测器错误覆盖，距离0.00010407966048002097，该检测器半径为0.00010613917468223686
# 第751个异常样本，被第315个自体检测器错误覆盖，距离9.86632438736514e-07，该检测器半径为1e-06
# 第752个异常样本，被第1886个自体检测器错误覆盖，距离0.00012986127646619173，该检测器半径为0.000299043979499568
# 第753个异常样本，被第23262个自体检测器错误覆盖，距离5.732399823199464e-05，该检测器半径为0.00017410687188262108
# 第754个异常样本，被第958个自体检测器错误覆盖，距离7.592284239307426e-07，该检测器半径为1e-06
# 第755个异常样本，被第1886个自体检测器错误覆盖，距离0.0002541776043964114，该检测器半径为0.000299043979499568
# 第756个异常样本，被第30699个自体检测器错误覆盖，距离8.350595843161448e-05，该检测器半径为8.691969562593412e-05
# 第758个异常样本，被第1618个自体检测器错误覆盖，距离7.603973765972384e-07，该检测器半径为1e-06
# 第763个异常样本，被第19868个自体检测器错误覆盖，距离1.8475012274322982e-05，该检测器半径为0.00011902377149074721
# 第764个异常样本，被第25103个自体检测器错误覆盖，距离8.873833039979779e-05，该检测器半径为0.00010613917468223686
# 第767个异常样本，被第15019个自体检测器错误覆盖，距离0.003832337942286037，该检测器半径为0.00445192043024391
# 第769个异常样本，被第1464个自体检测器错误覆盖，距离8.466167999181231e-07，该检测器半径为1e-06
# 第771个异常样本，被第8309个自体检测器错误覆盖，距离0.00037500886109113354，该检测器半径为0.0005982697249168783
# 第772个异常样本，被第1348个自体检测器错误覆盖，距离0.0006857029736721141，该检测器半径为0.0007392610108168777
# 第773个异常样本，被第1464个自体检测器错误覆盖，距离9.019819492281534e-07，该检测器半径为1e-06
# 第774个异常样本，被第6639个自体检测器错误覆盖，距离0.00053554856336332，该检测器半径为0.0010771624830390335
# 第776个异常样本，被第23262个自体检测器错误覆盖，距离3.625457112116278e-05，该检测器半径为0.00017410687188262108
# 第777个异常样本，被第447个自体检测器错误覆盖，距离9.343871829927071e-07，该检测器半径为1e-06
# 第778个异常样本，被第574个自体检测器错误覆盖，距离0.0005629954558578492，该检测器半径为0.0014667170229121626
# 第781个异常样本，被第12786个自体检测器错误覆盖，距离5.953009395226527e-07，该检测器半径为1e-06
# 第782个异常样本，被第938个自体检测器错误覆盖，距离0.0014398766534901841，该检测器半径为0.002519036766751294
# 第783个异常样本，被第2286个自体检测器错误覆盖，距离6.68396401394612e-07，该检测器半径为1e-06
# 第785个异常样本，被第1173个自体检测器错误覆盖，距离9.56464214433543e-07，该检测器半径为1e-06
# 第786个异常样本，被第4830个自体检测器错误覆盖，距离0.0027750916341026366，该检测器半径为0.015047244166147153
# 第788个异常样本，被第1886个自体检测器错误覆盖，距离0.0001710243889625078，该检测器半径为0.000299043979499568
# 第790个异常样本，被第18988个自体检测器错误覆盖，距离0.0001306866769941654，该检测器半径为0.00023727683990723181
# 第791个异常样本，被第66个自体检测器错误覆盖，距离9.902267399564414e-07，该检测器半径为1e-06
# 第792个异常样本，被第162个自体检测器错误覆盖，距离0.00036027779126751423，该检测器半径为0.0008798354174571309
# 第794个异常样本，被第66个自体检测器错误覆盖，距离3.2373608622551607e-07，该检测器半径为1e-06
# 第795个异常样本，被第18988个自体检测器错误覆盖，距离6.78090008716718e-05，该检测器半径为0.00023727683990723181
# 第796个异常样本，被第1618个自体检测器错误覆盖，距离8.05214422074825e-07，该检测器半径为1e-06
# 第797个异常样本，被第958个自体检测器错误覆盖，距离8.018984954866399e-07，该检测器半径为1e-06
# 第799个异常样本，被第24642个自体检测器错误覆盖，距离1.9369217138139046e-06，该检测器半径为2.377470812222854e-06
# 第802个异常样本，被第87个自体检测器错误覆盖，距离7.372687515368326e-07，该检测器半径为1e-06
# 第803个异常样本，被第6559个自体检测器错误覆盖，距离0.0006285966525176011，该检测器半径为0.0007474388805345792
# 第804个异常样本，被第1464个自体检测器错误覆盖，距离3.72230887317562e-07，该检测器半径为1e-06
# 第806个异常样本，被第21996个自体检测器错误覆盖，距离0.00019559945770874465，该检测器半径为0.0003365778519720795
# 第807个异常样本，被第7628个自体检测器错误覆盖，距离8.835773028024152e-07，该检测器半径为1e-06
# 第809个异常样本，被第23262个自体检测器错误覆盖，距离3.0422215950812026e-05，该检测器半径为0.00017410687188262108
# 第810个异常样本，被第154个自体检测器错误覆盖，距离1.7120132049201147e-07，该检测器半径为1e-06
# 第811个异常样本，被第2694个自体检测器错误覆盖，距离6.657334577361578e-07，该检测器半径为1e-06
# 第812个异常样本，被第28225个自体检测器错误覆盖，距离0.0006392311232365598，该检测器半径为0.0013875601335665783
# 第814个异常样本，被第3400个自体检测器错误覆盖，距离9.446207026367719e-05，该检测器半径为0.0001286800906931115
# 第815个异常样本，被第2273个自体检测器错误覆盖，距离4.4504357943141694e-07，该检测器半径为1e-06
# 第816个异常样本，被第694个自体检测器错误覆盖，距离4.68380266427886e-07，该检测器半径为1e-06
# 第817个异常样本，被第2137个自体检测器错误覆盖，距离0.0012290733320863957，该检测器半径为0.002373937113988125
# 第819个异常样本，被第1886个自体检测器错误覆盖，距离0.0001539310463761145，该检测器半径为0.000299043979499568
# 第820个异常样本，被第364个自体检测器错误覆盖，距离9.969311264400444e-07，该检测器半径为1e-06
# 第821个异常样本，被第31144个自体检测器错误覆盖，距离4.5372144403948535e-05，该检测器半径为5.2309897615050895e-05
# 第823个异常样本，被第513个自体检测器错误覆盖，距离7.402743438017964e-07，该检测器半径为1.3314669074826644e-06
# 第824个异常样本，被第447个自体检测器错误覆盖，距离9.46663638582168e-07，该检测器半径为1e-06
# 第825个异常样本，被第17566个自体检测器错误覆盖，距离9.071491678102853e-05，该检测器半径为9.680585444602471e-05
# 第826个异常样本，被第6559个自体检测器错误覆盖，距离0.0005822052703738789，该检测器半径为0.0007474388805345792
# 第827个异常样本，被第2368个自体检测器错误覆盖，距离0.0009432734910226245，该检测器半径为0.001090436711300067
# 第828个异常样本，被第8309个自体检测器错误覆盖，距离0.00041394977258289587，该检测器半径为0.0005982697249168783
# 第829个异常样本，被第2694个自体检测器错误覆盖，距离3.793216365980463e-07，该检测器半径为1e-06
# 第831个异常样本，被第295个自体检测器错误覆盖，距离0.00018736821290490322，该检测器半径为0.00040246646445255186
# 第833个异常样本，被第26212个自体检测器错误覆盖，距离4.6279082652323225e-06，该检测器半径为3.16800369139805e-05
# 第835个异常样本，被第16个自体检测器错误覆盖，距离2.1314349460002334e-05，该检测器半径为2.8075954759585307e-05
# 第836个异常样本，被第694个自体检测器错误覆盖，距离4.064494877463195e-07，该检测器半径为1e-06
# 第837个异常样本，被第15052个自体检测器错误覆盖，距离0.0006415436577661743，该检测器半径为0.0007982226163701098
# 第838个异常样本，被第288个自体检测器错误覆盖，距离4.1935584781975413e-07，该检测器半径为1e-06
# 第839个异常样本，被第288个自体检测器错误覆盖，距离1.548574096771071e-07，该检测器半径为1e-06
# 第840个异常样本，被第15052个自体检测器错误覆盖，距离0.000437077170917454，该检测器半径为0.0007982226163701098
# 第842个异常样本，被第447个自体检测器错误覆盖，距离3.588674837339549e-07，该检测器半径为1e-06
# 第843个异常样本，被第23262个自体检测器错误覆盖，距离3.06475120564837e-05，该检测器半径为0.00017410687188262108
# 第845个异常样本，被第35149个自体检测器错误覆盖，距离5.253896711235793e-05，该检测器半径为9.160323863126172e-05
# 第846个异常样本，被第87个自体检测器错误覆盖，距离5.075152677821766e-07，该检测器半径为1e-06
# 第848个异常样本，被第8309个自体检测器错误覆盖，距离0.0004717402964616195，该检测器半径为0.0005982697249168783
# 第849个异常样本，被第9179个自体检测器错误覆盖，距离0.0003757584793624533，该检测器半径为0.00041165381052809966
# 第850个异常样本，被第315个自体检测器错误覆盖，距离4.32903738210617e-07，该检测器半径为1e-06
# 第851个异常样本，被第66个自体检测器错误覆盖，距离3.2373608622551607e-07，该检测器半径为1e-06
# 第852个异常样本，被第1464个自体检测器错误覆盖，距离2.4934411839666234e-07，该检测器半径为1e-06
# 第853个异常样本，被第1886个自体检测器错误覆盖，距离0.0002745622585449046，该检测器半径为0.000299043979499568
# 第854个异常样本，被第1047个自体检测器错误覆盖，距离4.645722347559188e-07，该检测器半径为1e-06
# 第855个异常样本，被第13926个自体检测器错误覆盖，距离0.00018671999555588349，该检测器半径为0.000216772979620595
# 第857个异常样本，被第284个自体检测器错误覆盖，距离4.823927344493666e-07，该检测器半径为1e-06
# 第858个异常样本，被第284个自体检测器错误覆盖，距离8.580792102901979e-07，该检测器半径为1e-06
# ...
# 第886个异常样本，被第1464个自体检测器错误覆盖，距离5.495276762694914e-07，该检测器半径为1e-06
# 第887个异常样本，被第8309个自体检测器错误覆盖，距离0.00048810209670295816，该检测器半径为0.0005982697249168783
# 第889个异常样本，被第8309个自体检测器错误覆盖，距离0.0003416890225329903，该检测器半径为0.0005982697249168783
# 第890个异常样本，被第87个自体检测器错误覆盖，距离1.4600096599955427e-07，该检测器半径为1e-06
# 第891个异常样本，被第31144个自体检测器错误覆盖，距离3.9730329842118856e-05，该检测器半径为5.2309897615050895e-05
# 第892个异常样本，被第6639个自体检测器错误覆盖，距离0.0008989469396643307，该检测器半径为0.0010771624830390335
# 第893个异常样本，被第1886个自体检测器错误覆盖，距离0.0001074312007620076，该检测器半径为0.000299043979499568
# 第894个异常样本，被第17025个自体检测器错误覆盖，距离0.00021367137871884838，该检测器半径为0.0003093035008921291
# 第895个异常样本，被第66个自体检测器错误覆盖，距离8.291261170797363e-07，该检测器半径为1e-06
# 第896个异常样本，被第1503个自体检测器错误覆盖，距离4.256623108906654e-07，该检测器半径为1e-06
# 第897个异常样本，被第513个自体检测器错误覆盖，距离9.214654580661955e-07，该检测器半径为1.3314669074826644e-06
# 第898个异常样本，被第23262个自体检测器错误覆盖，距离0.0001616392331911945，该检测器半径为0.00017410687188262108
# 第900个异常样本，被第87个自体检测器错误覆盖，距离4.860611740915041e-07，该检测器半径为1e-06
# 第903个异常样本，被第861个自体检测器错误覆盖，距离0.0008393783140260342，该检测器半径为0.041597698295582256
# 第905个异常样本，被第15289个自体检测器错误覆盖，距离1.9262009065597122e-05，该检测器半径为2.2642327918151903e-05
# 第906个异常样本，被第1886个自体检测器错误覆盖，距离0.0001841229541557733，该检测器半径为0.000299043979499568
# 第907个异常样本，被第4541个自体检测器错误覆盖，距离0.0011745531715670432，该检测器半径为0.026488901486374707
# 第908个异常样本，被第295个自体检测器错误覆盖，距离0.00024698909096956416，该检测器半径为0.00040246646445255186
# 第909个异常样本，被第728个自体检测器错误覆盖，距离0.00047405232896075185，该检测器半径为0.0004817066228851818
# 第910个异常样本，被第1503个自体检测器错误覆盖，距离9.253129422731059e-07，该检测器半径为1e-06
# 第911个异常样本，被第9143个自体检测器错误覆盖，距离9.227011263833667e-05，该检测器半径为0.0001278050335739671
# 第912个异常样本，被第6559个自体检测器错误覆盖，距离0.0006738519471486551，该检测器半径为0.0007474388805345792
# 第913个异常样本，被第791个自体检测器错误覆盖，距离0.00043779662308027136，该检测器半径为0.0004933714091057292
# 第915个异常样本，被第1514个自体检测器错误覆盖，距离0.012736667086020297，该检测器半径为0.014781164527198031
# 第917个异常样本，被第23262个自体检测器错误覆盖，距离6.638043008605212e-05，该检测器半径为0.00017410687188262108
# 第918个异常样本，被第6559个自体检测器错误覆盖，距离0.000583229004981383，该检测器半径为0.0007474388805345792
# 第919个异常样本，被第44982个自体检测器错误覆盖，距离0.00019877157287779784，该检测器半径为0.0008705580367075172
# 第920个异常样本，被第87个自体检测器错误覆盖，距离5.004661024229448e-07，该检测器半径为1e-06
# 第921个异常样本，被第8665个自体检测器错误覆盖，距离2.210199501797582e-07，该检测器半径为1e-06
# 第922个异常样本，被第9195个自体检测器错误覆盖，距离0.0009723029104748539，该检测器半径为0.003673344580233931
# 第923个异常样本，被第284个自体检测器错误覆盖，距离1.2990531157078367e-07，该检测器半径为1e-06
# 第924个异常样本，被第36828个自体检测器错误覆盖，距离0.00018261127364498577，该检测器半径为0.00020930903857954928
# 第925个异常样本，被第31144个自体检测器错误覆盖，距离3.964908631835677e-05，该检测器半径为5.2309897615050895e-05
# 第927个异常样本，被第1886个自体检测器错误覆盖，距离0.0002843990467366938，该检测器半径为0.000299043979499568
# 第928个异常样本，被第1886个自体检测器错误覆盖，距离0.00024406819301127773，该检测器半径为0.000299043979499568
# 第929个异常样本，被第23262个自体检测器错误覆盖，距离0.00010070874581595649，该检测器半径为0.00017410687188262108
# 第930个异常样本，被第26212个自体检测器错误覆盖，距离1.515746251617007e-05，该检测器半径为3.16800369139805e-05
# 第932个异常样本，被第295个自体检测器错误覆盖，距离0.00014693565616274046，该检测器半径为0.00040246646445255186
# 第934个异常样本，被第713个自体检测器错误覆盖，距离0.001115532003428353，该检测器半径为0.001722286437317822
# 第935个异常样本，被第1886个自体检测器错误覆盖，距离0.00022834076154707266，该检测器半径为0.000299043979499568
# 第936个异常样本，被第9872个自体检测器错误覆盖，距离0.0005982879186617219，该检测器半径为0.0006162112713459649
# 第937个异常样本，被第10744个自体检测器错误覆盖，距离1.688506069391995e-06，该检测器半径为2.597037711431589e-06
# 第938个异常样本，被第8309个自体检测器错误覆盖，距离0.0003354237668603262，该检测器半径为0.0005982697249168783
# 第939个异常样本，被第9790个自体检测器错误覆盖，距离0.00015041206422924643，该检测器半径为0.00021986984994190782
# 第941个异常样本，被第66个自体检测器错误覆盖，距离9.112885610803091e-07，该检测器半径为1e-06
# 第942个异常样本，被第791个自体检测器错误覆盖，距离0.00044874368726266186，该检测器半径为0.0004933714091057292
# 第943个异常样本，被第1256个自体检测器错误覆盖，距离0.003288143660409258，该检测器半径为0.003538218769083844
# 第944个异常样本，被第12786个自体检测器错误覆盖，距离6.447228089804631e-07，该检测器半径为1e-06
# 第945个异常样本，被第9195个自体检测器错误覆盖，距离0.0002964346913461305，该检测器半径为0.003673344580233931
# 第947个异常样本，被第66个自体检测器错误覆盖，距离8.19428401039101e-07，该检测器半径为1e-06
# 第948个异常样本，被第958个自体检测器错误覆盖，距离1.6593232447193586e-07，该检测器半径为1e-06
# 第949个异常样本，被第2525个自体检测器错误覆盖，距离8.248300852418481e-07，该检测器半径为1e-06
# 第951个异常样本，被第1464个自体检测器错误覆盖，距离3.538829785415683e-07，该检测器半径为1e-06
# 第952个异常样本，被第24642个自体检测器错误覆盖，距离1.4274037058043652e-06，该检测器半径为2.377470812222854e-06
# 第953个异常样本，被第6639个自体检测器错误覆盖，距离0.000552997092470199，该检测器半径为0.0010771624830390335
# 第954个异常样本，被第66个自体检测器错误覆盖，距离2.9950963321688443e-07，该检测器半径为1e-06
# 第955个异常样本，被第4830个自体检测器错误覆盖，距离0.011544062036736639，该检测器半径为0.015047244166147153
# 第956个异常样本，被第8309个自体检测器错误覆盖，距离0.0003846115146930312，该检测器半径为0.0005982697249168783
# 第957个异常样本，被第4426个自体检测器错误覆盖，距离0.00016748579581159242，该检测器半径为0.00036991876326851236
# 第958个异常样本，被第1886个自体检测器错误覆盖，距离0.00019569532233359486，该检测器半径为0.000299043979499568
# 第960个异常样本，被第1503个自体检测器错误覆盖，距离6.405766551141882e-07，该检测器半径为1e-06
# 第961个异常样本，被第87个自体检测器错误覆盖，距离4.042583759723491e-07，该检测器半径为1e-06
# 第962个异常样本，被第3693个自体检测器错误覆盖，距离1.027748123595999e-05，该检测器半径为1.2408775905127897e-05
# 第965个异常样本，被第1173个自体检测器错误覆盖，距离5.314515431895892e-07，该检测器半径为1e-06
# 第966个异常样本，被第2048个自体检测器错误覆盖，距离5.255696850282509e-07，该检测器半径为1e-06
# 第967个异常样本，被第4426个自体检测器错误覆盖，距离0.00018254968311858584，该检测器半径为0.00036991876326851236
# 第968个异常样本，被第47550个自体检测器错误覆盖，距离0.0004327527044529648，该检测器半径为0.0010613308517351504
# 第970个异常样本，被第1503个自体检测器错误覆盖，距离7.924280181214015e-07，该检测器半径为1e-06
# 第972个异常样本，被第329个自体检测器错误覆盖，距离9.879818260192813e-07，该检测器半径为1e-06
# 第974个异常样本，被第295个自体检测器错误覆盖，距离0.00020861418119777687，该检测器半径为0.00040246646445255186
# 第975个异常样本，被第3798个自体检测器错误覆盖，距离0.0001463786641714041，该检测器半径为0.0005198637028503735
# 第977个异常样本，被第1886个自体检测器错误覆盖，距离0.0002947741846991483，该检测器半径为0.000299043979499568
# 第978个异常样本，被第87个自体检测器错误覆盖，距离9.480699235144684e-07，该检测器半径为1e-06
# 第979个异常样本，被第295个自体检测器错误覆盖，距离0.00017210976128613362，该检测器半径为0.00040246646445255186
# 第980个异常样本，被第12131个自体检测器错误覆盖，距离6.8189381302842804e-06，该检测器半径为7.220423735776376e-06
# 第981个异常样本，被第288个自体检测器错误覆盖，距离7.935480476036048e-07，该检测器半径为1e-06
# 第982个异常样本，被第8309个自体检测器错误覆盖，距离0.0005761395955627813，该检测器半径为0.0005982697249168783
# 第983个异常样本，被第1618个自体检测器错误覆盖，距离4.3800290289372667e-07，该检测器半径为1e-06
# 第984个异常样本，被第32556个自体检测器错误覆盖，距离0.0001174512814831689，该检测器半径为0.000336274352625705
# 第987个异常样本，被第839个自体检测器错误覆盖，距离9.725790652468605e-07，该检测器半径为1e-06
# 第989个异常样本，被第1464个自体检测器错误覆盖，距离8.205115760431411e-07，该检测器半径为1e-06
# 第990个异常样本，被第513个自体检测器错误覆盖，距离4.897021325642884e-07，该检测器半径为1.3314669074826644e-06
# 第991个异常样本，被第6639个自体检测器错误覆盖，距离0.0007408637188125288，该检测器半径为0.0010771624830390335
# 第992个异常样本，被第728个自体检测器错误覆盖，距离0.00047701898943310116，该检测器半径为0.0004817066228851818
# 第993个异常样本，被第8309个自体检测器错误覆盖，距离0.0004162759096811637，该检测器半径为0.0005982697249168783
# 第995个异常样本，被第66个自体检测器错误覆盖，距离3.674277140994878e-07，该检测器半径为1e-06
# 第996个异常样本，被第31144个自体检测器错误覆盖，距离4.083247719792351e-05，该检测器半径为5.2309897615050895e-05
# 第997个异常样本，被第26212个自体检测器错误覆盖，距离2.9397238005945912e-06，该检测器半径为3.16800369139805e-05
# 第998个异常样本，被第4830个自体检测器错误覆盖，距离0.010525339482808418，该检测器半径为0.015047244166147153
# 第999个异常样本，被第694个自体检测器错误覆盖，距离9.93808041767807e-07，该检测器半径为1e-06
# 第1001个异常样本，被第5686个自体检测器错误覆盖，距离1.9700530026623253e-05，该检测器半径为4.5139321486593e-05
# 第1002个异常样本，被第2379个自体检测器错误覆盖，距离9.471326249217067e-07，该检测器半径为1e-06
# 第1003个异常样本，被第23262个自体检测器错误覆盖，距离0.00014135590234713456，该检测器半径为0.00017410687188262108
# 第1004个异常样本，被第145个自体检测器错误覆盖，距离0.019903030607512206，该检测器半径为0.029530857911948608
# 第1006个异常样本，被第11543个自体检测器错误覆盖，距离6.219946026809427e-05，该检测器半径为8.030204037699904e-05
# 第1007个异常样本，被第23262个自体检测器错误覆盖，距离5.2916698493591234e-05，该检测器半径为0.00017410687188262108
# 第1008个异常样本，被第1886个自体检测器错误覆盖，距离0.0002549285901493062，该检测器半径为0.000299043979499568
# 第1010个异常样本，被第2806个自体检测器错误覆盖，距离0.027343842198306656，该检测器半径为0.035070473154467506
# 第1012个异常样本，被第37831个自体检测器错误覆盖，距离0.00012002371798801922，该检测器半径为0.00017865604207256472
# 第1013个异常样本，被第8309个自体检测器错误覆盖，距离0.0004798283505408853，该检测器半径为0.0005982697249168783
# 第1014个异常样本，被第66个自体检测器错误覆盖，距离4.2878075652485877e-07，该检测器半径为1e-06
# 第1015个异常样本，被第1886个自体检测器错误覆盖，距离0.00022518394988014075，该检测器半径为0.000299043979499568
# 第1017个异常样本，被第2352个自体检测器错误覆盖，距离7.551228818201223e-07，该检测器半径为1e-06
# 第1019个异常样本，被第1464个自体检测器错误覆盖，距离8.523672633335977e-07，该检测器半径为1e-06
# 第1020个异常样本，被第5546个自体检测器错误覆盖，距离0.005039867771513863，该检测器半径为0.005155255821574273
# 第1021个异常样本，被第728个自体检测器错误覆盖，距离0.00047529073481242636，该检测器半径为0.0004817066228851818
# 第1023个异常样本，被第295个自体检测器错误覆盖，距离0.00021219806258590296，该检测器半径为0.00040246646445255186
# 第1025个异常样本，被第295个自体检测器错误覆盖，距离0.00015873563220205835，该检测器半径为0.00040246646445255186
# 第1026个异常样本，被第8309个自体检测器错误覆盖，距离0.0005969422954451649，该检测器半径为0.0005982697249168783
# 第1029个异常样本，被第4615个自体检测器错误覆盖，距离5.013526631074317e-07，该检测器半径为1e-06
# 第1030个异常样本，被第4830个自体检测器错误覆盖，距离0.0016822483487886086，该检测器半径为0.015047244166147153
# 第1032个异常样本，被第3074个自体检测器错误覆盖，距离2.344423896452422e-05，该检测器半径为2.572183007738e-05
# 第1033个异常样本，被第1553个自体检测器错误覆盖，距离0.02997120559159802，该检测器半径为0.06409102856013635
# 第1034个异常样本，被第1886个自体检测器错误覆盖，距离0.00022523150444382463，该检测器半径为0.000299043979499568
# 第1035个异常样本，被第28225个自体检测器错误覆盖，距离0.0003760123215952856，该检测器半径为0.0013875601335665783
# 第1036个异常样本，被第4785个自体检测器错误覆盖，距离3.371747881313111e-07，该检测器半径为1e-06
# 第1037个异常样本，被第284个自体检测器错误覆盖，距离4.960095024745383e-07，该检测器半径为1e-06
# 第1038个异常样本，被第1886个自体检测器错误覆盖，距离0.00021211565284182216，该检测器半径为0.000299043979499568
# 第1039个异常样本，被第24642个自体检测器错误覆盖，距离1.1653432210437713e-06，该检测器半径为2.377470812222854e-06
# 第1040个异常样本，被第605个自体检测器错误覆盖，距离2.8808103200317594e-05，该检测器半径为0.00010555879412769592
# 第1041个异常样本，被第24783个自体检测器错误覆盖，距离9.504091087583552e-07，该检测器半径为1e-06
# 第1042个异常样本，被第9195个自体检测器错误覆盖，距离0.0009367087780852993，该检测器半径为0.003673344580233931
# 第1043个异常样本，被第1173个自体检测器错误覆盖，距离6.049210809770209e-07，该检测器半径为1e-06
# 第1045个异常样本，被第4013个自体检测器错误覆盖，距离0.0002702275965081987，该检测器半径为0.000310929146113397
# 第1046个异常样本，被第31055个自体检测器错误覆盖，距离0.0002522288198284926，该检测器半径为0.0022564377310168963
# 第1047个异常样本，被第295个自体检测器错误覆盖，距离0.00013949007478247989，该检测器半径为0.00040246646445255186
# 第1048个异常样本，被第23262个自体检测器错误覆盖，距离0.00017387837766680154，该检测器半径为0.00017410687188262108
# 第1049个异常样本，被第22614个自体检测器错误覆盖，距离0.012669607253042144，该检测器半径为0.013971658353309914
# 第1051个异常样本，被第315个自体检测器错误覆盖，距离3.039252468516481e-07，该检测器半径为1e-06
# 第1052个异常样本，被第87个自体检测器错误覆盖，距离7.679521403167558e-07，该检测器半径为1e-06
# 第1053个异常样本，被第22984个自体检测器错误覆盖，距离0.0014757984538956335，该检测器半径为0.0028050435997958737
# 第1055个异常样本，被第2430个自体检测器错误覆盖，距离5.280985032215273e-07，该检测器半径为1e-06
# 第1056个异常样本，被第8309个自体检测器错误覆盖，距离0.00046980219560804854，该检测器半径为0.0005982697249168783
# 第1057个异常样本，被第12786个自体检测器错误覆盖，距离6.925433935372017e-07，该检测器半径为1e-06
# 第1058个异常样本，被第4426个自体检测器错误覆盖，距离0.00016978454470999244，该检测器半径为0.00036991876326851236
# 第1059个异常样本，被第4502个自体检测器错误覆盖，距离9.884312220920283e-07，该检测器半径为1e-06
# 第1060个异常样本，被第1464个自体检测器错误覆盖，距离8.88089217308325e-07，该检测器半径为1e-06
# 第1063个异常样本，被第1886个自体检测器错误覆盖，距离0.00026960449691842893，该检测器半径为0.000299043979499568
# 第1064个异常样本，被第4830个自体检测器错误覆盖，距离0.008105006342605138，该检测器半径为0.015047244166147153
# 第1065个异常样本，被第447个自体检测器错误覆盖，距离3.998401124775034e-07，该检测器半径为1e-06
# 第1067个异常样本，被第1886个自体检测器错误覆盖，距离0.00018588734588304993，该检测器半径为0.000299043979499568
# 第1068个异常样本，被第15628个自体检测器错误覆盖，距离0.004149400700767975，该检测器半径为0.0059534324981029415
# 第1069个异常样本，被第16845个自体检测器错误覆盖，距离0.010224584393838606，该检测器半径为0.019234412131090468
# 第1070个异常样本，被第87个自体检测器错误覆盖，距离1.9768624254567572e-07，该检测器半径为1e-06
# 第1071个异常样本，被第26212个自体检测器错误覆盖，距离1.2422421790467173e-05，该检测器半径为3.16800369139805e-05
# 第1072个异常样本，被第9195个自体检测器错误覆盖，距离0.0016742388201225037，该检测器半径为0.003673344580233931
# 第1073个异常样本，被第958个自体检测器错误覆盖，距离4.0094924113374084e-07，该检测器半径为1e-06
# 第1074个异常样本，被第44362个自体检测器错误覆盖，距离0.002769653575146052，该检测器半径为0.003397070154114875
# 第1075个异常样本，被第1503个自体检测器错误覆盖，距离8.724499566501399e-07，该检测器半径为1e-06
# 第1078个异常样本，被第899个自体检测器错误覆盖，距离9.452552625740458e-07，该检测器半径为1e-06
# 第1079个异常样本，被第694个自体检测器错误覆盖，距离7.462492033262783e-07，该检测器半径为1e-06
# 第1080个异常样本，被第4785个自体检测器错误覆盖，距离4.814712531102051e-07，该检测器半径为1e-06
# 第1082个异常样本，被第25103个自体检测器错误覆盖，距离0.00010034918579785727，该检测器半径为0.00010613917468223686
# 第1083个异常样本，被第8309个自体检测器错误覆盖，距离0.0003482109571554574，该检测器半径为0.0005982697249168783
# 第1084个异常样本，被第87个自体检测器错误覆盖，距离4.204134998299924e-07，该检测器半径为1e-06
# 第1086个异常样本，被第288个自体检测器错误覆盖，距离1.7881393432617188e-07，该检测器半径为1e-06
# 第1087个异常样本，被第13625个自体检测器错误覆盖，距离2.339949240944751e-05，该检测器半径为0.0007372809067057293
# 第1088个异常样本，被第4830个自体检测器错误覆盖，距离0.012614160317911105，该检测器半径为0.015047244166147153
# 第1089个异常样本，被第47495个自体检测器错误覆盖，距离3.832699206270133e-06，该检测器半径为5.267239053960613e-06
# 第1091个异常样本，被第839个自体检测器错误覆盖，距离9.518098598433269e-07，该检测器半径为1e-06
# 第1094个异常样本，被第8309个自体检测器错误覆盖，距离0.0004766886925174213，该检测器半径为0.0005982697249168783
# 第1097个异常样本，被第1464个自体检测器错误覆盖，距离3.168030409416055e-07，该检测器半径为1e-06
# 第1098个异常样本，被第12786个自体检测器错误覆盖，距离2.827296549232345e-07，该检测器半径为1e-06
# 第1099个异常样本，被第1886个自体检测器错误覆盖，距离0.00017822233825074454，该检测器半径为0.000299043979499568
# 第1100个异常样本，被第18988个自体检测器错误覆盖，距离0.00010240553706412846，该检测器半径为0.00023727683990723181
# 第1101个异常样本，被第1886个自体检测器错误覆盖，距离0.00014969697933375068，该检测器半径为0.000299043979499568
# 第1102个异常样本，被第793个自体检测器错误覆盖，距离3.874301979106115e-07，该检测器半径为1e-06
# 第1103个异常样本，被第18988个自体检测器错误覆盖，距离0.00011417476633452197，该检测器半径为0.00023727683990723181
# 第1104个异常样本，被第16845个自体检测器错误覆盖，距离0.009984730935347255，该检测器半径为0.019234412131090468
# 第1105个异常样本，被第1503个自体检测器错误覆盖，距离9.789507441023806e-07，该检测器半径为1e-06
# 第1106个异常样本，被第288个自体检测器错误覆盖，距离8.466167899268862e-07，该检测器半径为1e-06
# 第1107个异常样本，被第87个自体检测器错误覆盖，距离2.980232328007175e-07，该检测器半径为1e-06
# 第1108个异常样本，被第8309个自体检测器错误覆盖，距离0.0002794797233930298，该检测器半径为0.0005982697249168783
# 第1110个异常样本，被第284个自体检测器错误覆盖，距离6.880400446334101e-07，该检测器半径为1e-06
# 第1111个异常样本，被第66个自体检测器错误覆盖，距离2.827296549232345e-07，该检测器半径为1e-06
# 第1112个异常样本，被第23262个自体检测器错误覆盖，距离8.335036675257314e-05，该检测器半径为0.00017410687188262108
# 第1117个异常样本，被第315个自体检测器错误覆盖，距离3.500980175873855e-07，该检测器半径为1e-06
# 第1121个异常样本，被第15983个自体检测器错误覆盖，距离0.0001601186954033457，该检测器半径为0.00021972487949381984
# 第1123个异常样本，被第87个自体检测器错误覆盖，距离5.196212514012646e-07，该检测器半径为1e-06
# 第1124个异常样本，被第8665个自体检测器错误覆盖，距离2.289159934479531e-07，该检测器半径为1e-06
# 第1125个异常样本，被第12608个自体检测器错误覆盖，距离3.6622919651345872e-06，该检测器半径为7.505749062096283e-06
# 第1130个异常样本，被第6559个自体检测器错误覆盖，距离0.0006248094587416057，该检测器半径为0.0007474388805345792
# 第1132个异常样本，被第23262个自体检测器错误覆盖，距离0.00015896726937084208，该检测器半径为0.00017410687188262108
# 第1133个异常样本，被第87个自体检测器错误覆盖，距离5.221788775572185e-07，该检测器半径为1e-06
# 第1134个异常样本，被第728个自体检测器错误覆盖，距离0.00047444675828005306，该检测器半径为0.0004817066228851818
# 第1136个异常样本，被第40554个自体检测器错误覆盖，距离0.022331089610140496，该检测器半径为0.023707418948388403
# 第1137个异常样本，被第2525个自体检测器错误覆盖，距离8.890887463334838e-07，该检测器半径为1e-06
# 第1138个异常样本，被第29016个自体检测器错误覆盖，距离0.0002195501369222407，该检测器半径为0.0011605513346916309
# 第1139个异常样本，被第295个自体检测器错误覆盖，距离0.00019388296116652323，该检测器半径为0.00040246646445255186
# 第1140个异常样本，被第13666个自体检测器错误覆盖，距离0.00401116215253845，该检测器半径为0.013694260230188356
# 第1141个异常样本，被第23262个自体检测器错误覆盖，距离9.480515514505395e-05，该检测器半径为0.00017410687188262108
# 第1142个异常样本，被第47171个自体检测器错误覆盖，距离2.1718921723299734e-06，该检测器半径为3.5159478508634436e-06
# 第1143个异常样本，被第25103个自体检测器错误覆盖，距离9.389474117332053e-05，该检测器半径为0.00010613917468223686
# 第1144个异常样本，被第6639个自体检测器错误覆盖，距离0.00045195315445616276，该检测器半径为0.0010771624830390335
# 第1146个异常样本，被第295个自体检测器错误覆盖，距离0.00014366888551907965，该检测器半径为0.00040246646445255186
# 第1147个异常样本，被第154个自体检测器错误覆盖，距离2.2101994790428123e-07，该检测器半径为1e-06
# 第1148个异常样本，被第905个自体检测器错误覆盖，距离9.112885610803091e-07，该检测器半径为1e-06
# 第1151个异常样本，被第25264个自体检测器错误覆盖，距离0.00034514516551160306，该检测器半径为0.000436208387503222
# 第1152个异常样本，被第1886个自体检测器错误覆盖，距离0.00018307513034453767，该检测器半径为0.000299043979499568
# 第1153个异常样本，被第66个自体检测器错误覆盖，距离7.504033177336725e-07，该检测器半径为1e-06
# 第1154个异常样本，被第1886个自体检测器错误覆盖，距离0.00027943255196875643，该检测器半径为0.000299043979499568
# 第1155个异常样本，被第441个自体检测器错误覆盖，距离0.00019173179319973647，该检测器半径为0.0003791414060520321
# 第1156个异常样本，被第17025个自体检测器错误覆盖，距离0.00013669261333716786，该检测器半径为0.0003093035008921291
# 第1157个异常样本，被第791个自体检测器错误覆盖，距离0.00045878559391464746，该检测器半径为0.0004933714091057292
# 第1158个异常样本，被第13304个自体检测器错误覆盖，距离0.018232874706048428，该检测器半径为0.0192875497932932
# 第1159个异常样本，被第1886个自体检测器错误覆盖，距离0.00023873088358726798，该检测器半径为0.000299043979499568
# 第1160个异常样本，被第87个自体检测器错误覆盖，距离3.068336973136937e-07，该检测器半径为1e-06
# 第1161个异常样本，被第6559个自体检测器错误覆盖，距离0.0007149888493227799，该检测器半径为0.0007474388805345792
# 第1162个异常样本，被第3318个自体检测器错误覆盖，距离4.414668680865344e-06，该检测器半径为8.78239854423514e-06
# 第1163个异常样本，被第8309个自体检测器错误覆盖，距离0.0004243333635596147，该检测器半径为0.0005982697249168783
# 第1164个异常样本，被第4426个自体检测器错误覆盖，距离0.0001743289618438447，该检测器半径为0.00036991876326851236
# true_self:9559, false_self:152, true_nonself:285, false_nonself:880
# 自体准确率：0.9843476469982494， 非自体识别准确率：0.2446351931330472

# %% [markdown]
# ### 测试已知攻击检测率

# %%
# 对上述生成的检测器，进行已知攻击样本测试

def test(normal_sample, attack_sample, self_detector, detector_radius):

    true_self, false_self, true_nonself, false_nonself = 0, 0, 0, 0
    detector_num = self_detector.shape[0]
    error_nonself = pd.DataFrame(columns=["attack_sample", "self_detector", "detector_radius"])
    error_self = pd.DataFrame(columns=['normal_sample'])  # 未落入任何自体检测器的正常样本

    # 对每一个正常的样本,遍历所有自体检测器，计算正常自体被检测出的个数
    t=0
    for i in range(0, len(normal_sample)):
        flag = 0
        for k in range(0, detector_num):
            distance = np.linalg.norm(normal_sample[i] - self_detector[k])
            if distance < detector_radius[k]:
                true_self = true_self + 1
                flag = 1
                break
        if flag == 0:
          error_self.loc[t] = [i]
          t = t + 1
          


    # 对每一个异常样本，遍历所有自体检测器，计算异常点被检测器覆盖个数
    for i in range(0, len(attack_sample)):
        for k in range(0, detector_num):
            distance = np.linalg.norm(attack_sample[i] - self_detector[k])
            if distance < detector_radius[k]:
                false_nonself = false_nonself + 1
                error_nonself.loc[false_nonself] = [i, k, detector_radius[k]]
                print("第{}个异常样本，被第{}个自体检测器错误覆盖，距离{}，该检测器半径为{}".format(i, k, distance, detector_radius[k]))
                break

    false_self = len(normal_sample) - true_self
    true_nonself = len(attack_sample) - false_nonself
    print('true_self:{}, false_self:{}, true_nonself:{}, false_nonself:{}'.format(true_self, false_self, true_nonself, false_nonself))
    print('自体准确率：{}， 非自体识别准确率：{}'.format(true_self / len(normal_sample), true_nonself / len(attack_sample)))
    return error_nonself, error_self




#  矩阵计算欧式距离
def EuclideanDistance(A, B):
    m, n = A.shape[0], B.shape[0]
    # AA经过pow函数对矩阵每个元素求二次方，axis=1横向求和，此时AA.shape=(m,1),扩展n-1次，AA.shape=(m,n)
    AA = torch.pow(A, 2).sum(1, keepdim=True).expand(m, n)
    # sum操作后BB.shape=(n,1)
    BB = torch.pow(B, 2).sum(1, keepdim=True).expand(n, m).T
    dist = AA + BB
    # 表示dist - 2* A * B.T
    dist.addmm_(1, -2, A, B.t())
    # clamp()函数可以限定dist内元素的最大最小范围，dist最后开方，得到样本之间的距离矩阵
    dist = dist.clamp(min=1e-12).sqrt()
    return dist



#test_Self = AE_2_encoded_test[y_test==0,:]
'''test_NonSelf1 = AE_2_encoded_test[y_test==1,:]
test_NonSelf = np.r_[test_NonSelf1, test_NonSelf2]'''

error_nonself, error_self = test(test_Self, test_NonSelf, Normaldata, Radius)
# Out:
# 第0个异常样本，被第7525个自体检测器错误覆盖，距离4.4901726189945825e-07，该检测器半径为1e-06
# 第1个异常样本，被第447个自体检测器错误覆盖，距离3.513641989991544e-07，该检测器半径为1e-06
# 第2个异常样本，被第694个自体检测器错误覆盖，距离5.204751899010116e-07，该检测器半径为1e-06
# 第6个异常样本，被第1722个自体检测器错误覆盖，距离0.00025863200422715873，该检测器半径为0.0004888416564472845
# 第7个异常样本，被第8288个自体检测器错误覆盖，距离0.007609855068089561，该检测器半径为0.008435844708329329
# 第8个异常样本，被第8087个自体检测器错误覆盖，距离5.306152672612581e-07，该检测器半径为1e-06
# 第12个异常样本，被第694个自体检测器错误覆盖，距离5.289387549789351e-07，该检测器半径为1e-06
# 第15个异常样本，被第958个自体检测器错误覆盖，距离6.906169826307093e-07，该检测器半径为1e-06
# 第17个异常样本，被第2392个自体检测器错误覆盖，距离0.0093395897657163，该检测器半径为0.011158385693387961
# 第19个异常样本，被第958个自体检测器错误覆盖，距离6.041865205982132e-07，该检测器半径为1e-06
# 第21个异常样本，被第22091个自体检测器错误覆盖，距离0.0003047538075124706，该检测器半径为0.00041392263496978205
# 第23个异常样本，被第2095个自体检测器错误覆盖，距离7.232821679658152e-07，该检测器半径为1e-06
# 第35个异常样本，被第447个自体检测器错误覆盖，距离9.381816631436724e-07，该检测器半径为1e-06
# 第39个异常样本，被第7525个自体检测器错误覆盖，距离4.56860951320298e-07，该检测器半径为1e-06
# 第46个异常样本，被第11807个自体检测器错误覆盖，距离1.1279106198866622e-05，该检测器半径为1.5614127558233785e-05
# 第49个异常样本，被第4950个自体检测器错误覆盖，距离0.00011707868951863093，该检测器半径为0.00025895078432248536
# 第51个异常样本，被第284个自体检测器错误覆盖，距离3.1256940263079126e-07，该检测器半径为1e-06
# 第55个异常样本，被第7525个自体检测器错误覆盖，距离2.715120786173433e-07，该检测器半径为1e-06
# 第58个异常样本，被第7525个自体检测器错误覆盖，距离3.2510495560060776e-07，该检测器半径为1e-06
# 第59个异常样本，被第13329个自体检测器错误覆盖，距离0.00065789972935691，该检测器半径为0.0009201842636529436
# 第64个异常样本，被第66个自体检测器错误覆盖，距离3.0827761986221675e-07，该检测器半径为1e-06
# 第66个异常样本，被第8087个自体检测器错误覆盖，距离3.8397606758236565e-07，该检测器半径为1e-06
# 第67个异常样本，被第1503个自体检测器错误覆盖，距离8.434636538438535e-07，该检测器半径为1e-06
# 第71个异常样本，被第13149个自体检测器错误覆盖，距离0.0003407804796090577，该检测器半径为0.00034081204335330826
# 第75个异常样本，被第14054个自体检测器错误覆盖，距离7.925984170459965e-05，该检测器半径为0.0001513277430863725
# 第77个异常样本，被第5476个自体检测器错误覆盖，距离0.0011412917962972573，该检测器半径为0.0011594450625823165
# 第83个异常样本，被第17061个自体检测器错误覆盖，距离4.728109095412607e-05，该检测器半径为0.00010495689029217477
# 第90个异常样本，被第7525个自体检测器错误覆盖，距离5.187659045881642e-07，该检测器半径为1e-06
# 第92个异常样本，被第7525个自体检测器错误覆盖，距离5.397430176507265e-07，该检测器半径为1e-06
# 第95个异常样本，被第1435个自体检测器错误覆盖，距离0.000988234417290749，该检测器半径为0.003305399471800981
# 第102个异常样本，被第1374个自体检测器错误覆盖，距离0.0005044271553195524，该检测器半径为0.0006811592102293127
# 第103个异常样本，被第3104个自体检测器错误覆盖，距离4.5976784160784243e-07，该检测器半径为1e-06
# 第106个异常样本，被第27264个自体检测器错误覆盖，距离0.00029357332171508224，该检测器半径为0.0003646752371486295
# 第107个异常样本，被第7525个自体检测器错误覆盖，距离1.837138534477048e-07，该检测器半径为1e-06
# 第112个异常样本，被第154个自体检测器错误覆盖，距离6.467859420163211e-07，该检测器半径为1e-06
# 第120个异常样本，被第18706个自体检测器错误覆盖，距离0.0022431118940600893，该检测器半径为0.0024077486412072196
# 第126个异常样本，被第2379个自体检测器错误覆盖，距离1.3657141760873155e-07，该检测器半径为1e-06
# 第127个异常样本，被第7525个自体检测器错误覆盖，距离9.315311690184172e-07，该检测器半径为1e-06
# 第130个异常样本，被第66个自体检测器错误覆盖，距离5.559551199059142e-07，该检测器半径为1e-06
# 第139个异常样本，被第12786个自体检测器错误覆盖，距离8.875890172641655e-07，该检测器半径为1e-06
# 第140个异常样本，被第11592个自体检测器错误覆盖，距离0.0001550610692906897，该检测器半径为0.00018926446348035736
# 第141个异常样本，被第793个自体检测器错误覆盖，距离4.086288571596768e-07，该检测器半径为1e-06
# 第142个异常样本，被第1503个自体检测器错误覆盖，距离2.2500259981366246e-07，该检测器半径为1e-06
# 第147个异常样本，被第1000个自体检测器错误覆盖，距离7.171159671213077e-07，该检测器半径为1e-06
# 第149个异常样本，被第315个自体检测器错误覆盖，距离3.976125736274223e-07，该检测器半径为1e-06
# 第150个异常样本，被第5223个自体检测器错误覆盖，距离9.973764757488852e-07，该检测器半径为1e-06
# 第152个异常样本，被第1526个自体检测器错误覆盖，距离9.978216342502283e-07，该检测器半径为1e-06
# 第153个异常样本，被第1813个自体检测器错误覆盖，距离8.128989872043466e-07，该检测器半径为1e-06
# 第158个异常样本，被第2379个自体检测器错误覆盖，距离3.513642065325854e-07，该检测器半径为1e-06
# 第161个异常样本，被第4785个自体检测器错误覆盖，距离9.9782163426515e-07，该检测器半径为1e-06
# 第165个异常样本，被第2033个自体检测器错误覆盖，距离8.013444936281854e-07，该检测器半径为1e-06
# 第169个异常样本，被第1871个自体检测器错误覆盖，距离0.0023324536269991557，该检测器半径为0.002361321116053201
# 第171个异常样本，被第15260个自体检测器错误覆盖，距离0.00029317238568148167，该检测器半径为0.00031899698248277953
# 第172个异常样本，被第4154个自体检测器错误覆盖，距离4.5099097821265947e-07，该检测器半径为1e-06
# 第173个异常样本，被第315个自体检测器错误覆盖，距离3.0683368864616754e-07，该检测器半径为1e-06
# 第176个异常样本，被第20531个自体检测器错误覆盖，距离8.813328288756838e-06，该检测器半径为1.0069067569555863e-05
# 第181个异常样本，被第284个自体检测器错误覆盖，距离9.64325062739156e-07，该检测器半径为1e-06
# 第182个异常样本，被第38085个自体检测器错误覆盖，距离0.000338124163265394，该检测器半径为0.0006108326782016508
# 第186个异常样本，被第154个自体检测器错误覆盖，距离8.183437748144901e-07，该检测器半径为1e-06
# 第189个异常样本，被第839个自体检测器错误覆盖，距离6.59702532166595e-07，该检测器半径为1e-06
# 第195个异常样本，被第7525个自体检测器错误覆盖，距离4.897021299982577e-07，该检测器半径为1e-06
# 第196个异常样本，被第66个自体检测器错误覆盖，距离3.828177680550172e-07，该检测器半径为1e-06
# 第197个异常样本，被第688个自体检测器错误覆盖，距离0.00012320305668216393，该检测器半径为0.00012983593856706399
# 第198个异常样本，被第364个自体检测器错误覆盖，距离9.587829106130258e-07，该检测器半径为1e-06
# 第200个异常样本，被第4615个自体检测器错误覆盖，距离6.158345436981864e-07，该检测器半径为1e-06
# 第205个异常样本，被第4785个自体检测器错误覆盖，距离9.443151663553352e-07，该检测器半径为1e-06
# 第206个异常样本，被第154个自体检测器错误覆盖，距离6.43343736031866e-07，该检测器半径为1e-06
# 第208个异常样本，被第66个自体检测器错误覆盖，距离2.421152116249788e-07，该检测器半径为1e-06
# 第212个异常样本，被第7293个自体检测器错误覆盖，距离7.164964247026601e-07，该检测器半径为1e-06
# 第215个异常样本，被第839个自体检测器错误覆盖，距离3.885747435809761e-07，该检测器半径为1e-06
# 第216个异常样本，被第8087个自体检测器错误覆盖，距离8.77019107127151e-07，该检测器半径为1e-06
# 第217个异常样本，被第839个自体检测器错误覆盖，距离5.272569104850533e-07，该检测器半径为1e-06
# 第222个异常样本，被第7525个自体检测器错误覆盖，距离9.049312160431378e-07，该检测器半径为1e-06
# 第228个异常样本，被第11710个自体检测器错误覆盖，距离8.253683104590314e-07，该检测器半径为1.800452495152408e-06
# 第233个异常样本，被第2379个自体检测器错误覆盖，距离7.202056667361269e-07，该检测器半径为1e-06
# 第234个异常样本，被第1547个自体检测器错误覆盖，距离5.405651721812062e-07，该检测器半径为1e-06
# 第235个异常样本，被第8087个自体检测器错误覆盖，距离6.529361714977188e-07，该检测器半径为1e-06
# 第237个异常样本，被第2694个自体检测器错误覆盖，距离5.543552457677291e-07，该检测器半径为1e-06
# 第248个异常样本，被第447个自体检测器错误覆盖，距离3.251049553134143e-07，该检测器半径为1e-06
# 第249个异常样本，被第1538个自体检测器错误覆盖，距离0.00044911035584217985，该检测器半径为0.0006369976516738033
# 第252个异常样本，被第447个自体检测器错误覆盖，距离7.014633631436837e-07，该检测器半径为1e-06
# 第259个异常样本，被第694个自体检测器错误覆盖，距离8.402986759702905e-07，该检测器半径为1e-06
# 第263个异常样本，被第288个自体检测器错误覆盖，距离4.6932744228910274e-07，该检测器半径为1e-06
# 第264个异常样本，被第1503个自体检测器错误覆盖，距离1.5769906706002895e-07，该检测器半径为1e-06
# 第272个异常样本，被第7014个自体检测器错误覆盖，距离4.70272718017033e-07，该检测器半径为1e-06
# 第274个异常样本，被第958个自体检测器错误覆盖，距离9.466636396726517e-07，该检测器半径为1e-06
# 第275个异常样本，被第694个自体检测器错误覆盖，距离9.518098598301824e-07，该检测器半径为1e-06
# 第279个异常样本，被第288个自体检测器错误覆盖，距离4.6932744228910274e-07，该检测器半径为1e-06
# 第281个异常样本，被第2724个自体检测器错误覆盖，距离6.020642281156795e-05，该检测器半径为0.00047154423053876235
# 第286个异常样本，被第8087个自体检测器错误覆盖，距离8.601468631601482e-07，该检测器半径为1e-06
# 第288个异常样本，被第9364个自体检测器错误覆盖，距离8.585965837604176e-07，该检测器半径为1e-06
# 第290个异常样本，被第1512个自体检测器错误覆盖，距离1.4673308940221534e-05，该检测器半径为1.589970657864516e-05
# 第295个异常样本，被第131个自体检测器错误覆盖，距离3.2646809132305614e-07，该检测器半径为1e-06
# 第302个异常样本，被第364个自体检测器错误覆盖，距离8.317998490901508e-07，该检测器半径为1e-06
# 第303个异常样本，被第506个自体检测器错误覆盖，距离8.92080648367776e-07，该检测器半径为1e-06
# 第313个异常样本，被第21636个自体检测器错误覆盖，距离7.79830605812171e-06，该检测器半径为1.0163706182827829e-05
# 第314个异常样本，被第2379个自体检测器错误覆盖，距离7.164964380392099e-07，该检测器半径为1e-06
# 第324个异常样本，被第887个自体检测器错误覆盖，距离8.795472749390819e-07，该检测器半径为1e-06
# 第329个异常样本，被第694个自体检测器错误覆盖，距离4.6743116204017766e-07，该检测器半径为1e-06
# 第330个异常样本，被第592个自体检测器错误覆盖，距离1.0071245005388595e-06，该检测器半径为1.2113095183909878e-06
# 第331个异常样本，被第1871个自体检测器错误覆盖，距离0.0013310572947874486，该检测器半径为0.002361321116053201
# 第333个异常样本，被第9195个自体检测器错误覆盖，距离0.002797362659591323，该检测器半径为0.003673344580233931
# 第334个异常样本，被第4615个自体检测器错误覆盖，距离4.246177330598711e-07，该检测器半径为1e-06
# 第345个异常样本，被第284个自体检测器错误覆盖，距离9.780430354631031e-07，该检测器半径为1e-06
# 第346个异常样本，被第9365个自体检测器错误覆盖，距离0.0033419944025226233，该检测器半径为0.003440032274275546
# 第348个异常样本，被第839个自体检测器错误覆盖，距离5.930587310624082e-07，该检测器半径为1e-06
# 第349个异常样本，被第154个自体检测器错误覆盖，距离6.867479495089318e-07，该检测器半径为1e-06
# 第351个异常样本，被第14054个自体检测器错误覆盖，距离0.0001333887078748066，该检测器半径为0.0001513277430863725
# 第354个异常样本，被第839个自体检测器错误覆盖，距离7.414731600593061e-07，该检测器半径为1e-06
# 第366个异常样本，被第839个自体检测器错误覆盖，距离3.95372484964776e-07，该检测器半径为1e-06
# 第371个异常样本，被第1985个自体检测器错误覆盖，距离0.0014846545573979635，该检测器半径为0.0017387509892349466
# 第375个异常样本，被第7525个自体检测器错误覆盖，距离4.287807517714434e-07，该检测器半径为1e-06
# 第377个异常样本，被第315个自体检测器错误覆盖，距离4.031583445807899e-07，该检测器半径为1e-06
# 第382个异常样本，被第66个自体检测器错误覆盖，距离2.511188320272076e-07，该检测器半径为1e-06
# 第384个异常样本，被第1813个自体检测器错误覆盖，距离9.973764831823034e-07，该检测器半径为1e-06
# 第388个异常样本，被第8564个自体检测器错误覆盖，距离0.00014097035620123973，该检测器半径为0.00016969619995060308
# 第389个异常样本，被第1503个自体检测器错误覆盖，距离5.755784670433479e-07，该检测器半径为1e-06
# 第391个异常样本，被第899个自体检测器错误覆盖，距离9.550702896842886e-07，该检测器半径为1e-06
# 第394个异常样本，被第8473个自体检测器错误覆盖，距离0.00012667719782139808，该检测器半径为0.00016450398338031759
# 第395个异常样本，被第7525个自体检测器错误覆盖，距离4.597678378656588e-07，该检测器半径为1e-06
# 第401个异常样本，被第8288个自体检测器错误覆盖，距离0.007669563697344172，该检测器半径为0.008435844708329329
# 第408个异常样本，被第12673个自体检测器错误覆盖，距离7.548362423066714e-05，该检测器半径为9.547700747602282e-05
# 第411个异常样本，被第7293个自体检测器错误覆盖，距离8.38711698210789e-07，该检测器半径为1e-06
# 第413个异常样本，被第629个自体检测器错误覆盖，距离0.00017016788706833953，该检测器半径为0.0009114296059133652
# 第415个异常样本，被第284个自体检测器错误覆盖，距离6.542950553812143e-07，该检测器半径为1e-06
# 第420个异常样本，被第315个自体检测器错误覆盖，距离8.280541922497902e-07，该检测器半径为1e-06
# 第424个异常样本，被第1503个自体检测器错误覆盖，距离3.0392525551978885e-07，该检测器半径为1e-06
# 第430个异常样本，被第1464个自体检测器错误覆盖，距离3.111453889599653e-07，该检测器半径为1e-06
# 第433个异常样本，被第9027个自体检测器错误覆盖，距离9.734918485092669e-07，该检测器半径为1e-06
# 第437个异常样本，被第694个自体检测器错误覆盖，距离4.2357058538624647e-07，该检测器半径为1e-06
# 第445个异常样本，被第839个自体检测器错误覆盖，距离7.058810790351832e-07，该检测器半径为1e-06
# 第447个异常样本，被第3084个自体检测器错误覆盖，距离0.0011854358749804515，该检测器半径为0.0014274724451907126
# 第448个异常样本，被第447个自体检测器错误覆盖，距离9.185692776548333e-07，该检测器半径为1e-06
# 第451个异常样本，被第284个自体检测器错误覆盖，距离9.780430354631031e-07，该检测器半径为1e-06
# 第455个异常样本，被第1526个自体检测器错误覆盖，距离9.05912170026938e-07，该检测器半径为1e-06
# 第458个异常样本，被第602个自体检测器错误覆盖，距离4.44251579620095e-05，该检测器半径为4.509224948973701e-05
# 第462个异常样本，被第19948个自体检测器错误覆盖，距离4.5723037314867975e-05，该检测器半径为8.420733208123162e-05
# 第463个异常样本，被第7525个自体检测器错误覆盖，距离9.049312160431378e-07，该检测器半径为1e-06
# 第465个异常样本，被第4785个自体检测器错误覆盖，距离9.85731807580374e-07，该检测器半径为1e-06
# 第471个异常样本，被第598个自体检测器错误覆盖，距离6.067502536464249e-05，该检测器半径为0.00015772229604103067
# 第473个异常样本，被第7628个自体检测器错误覆盖，距离9.490062890661515e-07，该检测器半径为1e-06
# 第476个异常样本，被第7525个自体检测器错误覆盖，距离2.7637536810325694e-07，该检测器半径为1e-06
# 第484个异常样本，被第29219个自体检测器错误覆盖，距离4.346645997241822e-06，该检测器半径为5.226655307108139e-06
# 第486个异常样本，被第1526个自体检测器错误覆盖，距离7.077659457792714e-07，该检测器半径为1e-06
# 第489个异常样本，被第1887个自体检测器错误覆盖，距离4.6926243384984514e-05，该检测器半径为5.051343861647805e-05
# 第492个异常样本，被第32067个自体检测器错误覆盖，距离0.0008922088476075151，该检测器半径为0.0010228285180374987
# 第497个异常样本，被第7525个自体检测器错误覆盖，距离4.161667839379816e-07，该检测器半径为1e-06
# 第499个异常样本，被第11710个自体检测器错误覆盖，距离1.5514391905371383e-06，该检测器半径为1.800452495152408e-06
# 第500个异常样本，被第26591个自体检测器错误覆盖，距离0.00012548390557948983，该检测器半径为0.00013584054363206208
# 第507个异常样本，被第288个自体检测器错误覆盖，距离8.534086409465322e-07，该检测器半径为1e-06
# 第510个异常样本，被第8700个自体检测器错误覆盖，距离6.769720739167997e-06，该检测器半径为1.8852572016346604e-05
# 第512个异常样本，被第126个自体检测器错误覆盖，距离9.620197152157193e-07，该检测器半径为1e-06
# 第518个异常样本，被第156个自体检测器错误覆盖，距离0.0018429831487247147，该检测器半径为0.002134028576753615
# 第521个异常样本，被第7014个自体检测器错误覆盖，距离1.8128045051980335e-07，该检测器半径为1e-06
# 第527个异常样本，被第818个自体检测器错误覆盖，距离0.0020018289297040835，该检测器半径为0.003830920429692912
# 第529个异常样本，被第3596个自体检测器错误覆盖，距离0.00017840570386894566，该检测器半径为0.0002331420251550717
# 第530个异常样本，被第66个自体检测器错误覆盖，距离2.6987150723151616e-07，该检测器半径为1e-06
# 第531个异常样本，被第958个自体检测器错误覆盖，距离7.12767887455271e-07，该检测器半径为1e-06
# 第532个异常样本，被第480个自体检测器错误覆盖，距离0.0007174679005038697，该检测器半径为0.0011573787583752
# 第537个异常样本，被第4个自体检测器错误覆盖，距离0.0008624590544942316，该检测器半径为0.002550561838719545
# 第538个异常样本，被第16143个自体检测器错误覆盖，距离3.0445359220014395e-05，该检测器半径为4.303017789516896e-05
# 第539个异常样本，被第2286个自体检测器错误覆盖，距离6.495265611548644e-07，该检测器半径为1e-06
# 第543个异常样本，被第24977个自体检测器错误覆盖，距离0.0013954269330493537，该检测器半径为0.0013954300802740483
# 第546个异常样本，被第839个自体检测器错误覆盖，距离5.331201539917099e-07，该检测器半径为1e-06
# 第548个异常样本，被第7525个自体检测器错误覆盖，距离6.98290738318335e-07，该检测器半径为1e-06
# 第550个异常样本，被第7525个自体检测器错误覆盖，距离7.052516697081323e-07，该检测器半径为1e-06
# 第556个异常样本，被第19184个自体检测器错误覆盖，距离1.1238281509309607e-05，该检测器半径为1.3308480584773403e-05
# 第559个异常样本，被第686个自体检测器错误覆盖，距离0.00011887521051003603，该检测器半径为0.0003323094176525814
# 第561个异常样本，被第50233个自体检测器错误覆盖，距离5.487189657643731e-07，该检测器半径为1e-06
# 第566个异常样本，被第4744个自体检测器错误覆盖，距离0.00048288173792845483，该检测器半径为0.000537649648830362
# 第571个异常样本，被第1145个自体检测器错误覆盖，距离7.985687856062807e-07，该检测器半径为1e-06
# 第572个异常样本，被第154个自体检测器错误覆盖，距离7.851088092793826e-07，该检测器半径为1e-06
# 第573个异常样本，被第958个自体检测器错误覆盖，距离7.811392797280047e-07，该检测器半径为1e-06
# 第578个异常样本，被第1526个自体检测器错误覆盖，距离9.739479234197739e-07，该检测器半径为1e-06
# 第579个异常样本，被第7525个自体检测器错误覆盖，距离8.815645863075762e-07，该检测器半径为1e-06
# 第582个异常样本，被第40116个自体检测器错误覆盖，距离0.0008694054924711077，该检测器半径为0.0009144879986754819
# 第585个异常样本，被第4770个自体检测器错误覆盖，距离0.0004077181197820532，该检测器半径为0.0006313146021961741
# 第586个异常样本，被第4492个自体检测器错误覆盖，距离0.003024538098199057，该检测器半径为0.004022277589692369
# 第587个异常样本，被第14714个自体检测器错误覆盖，距离9.122626730158346e-07，该检测器半径为1e-06
# 第588个异常样本，被第28884个自体检测器错误覆盖，距离7.058810797476627e-07，该检测器半径为1e-06
# 第589个异常样本，被第7525个自体检测器错误覆盖，距离7.492187691564299e-07，该检测器半径为1e-06
# 第591个异常样本，被第7525个自体检测器错误覆盖，距离8.30196637245113e-07，该检测器半径为1e-06
# 第595个异常样本，被第2097个自体检测器错误覆盖，距离5.066394848227293e-07，该检测器半径为1e-06
# 第596个异常样本，被第1173个自体检测器错误覆盖，距离5.153303336543399e-07，该检测器半径为1e-06
# 第597个异常样本，被第1526个自体检测器错误覆盖，距离7.202056630608185e-07，该检测器半径为1e-06
# 第598个异常样本，被第22831个自体检测器错误覆盖，距离0.00018238604713831773，该检测器半径为0.0001902577862898267
# 第601个异常样本，被第1886个自体检测器错误覆盖，距离0.0002952550913979604，该检测器半径为0.000299043979499568
# 第603个异常样本，被第288个自体检测器错误覆盖，距离7.426700498349735e-07，该检测器半径为1e-06
# 第605个异常样本，被第7525个自体检测器错误覆盖，距离8.355287192491322e-07，该检测器半径为1e-06
# 第607个异常样本，被第66个自体检测器错误覆盖，距离7.5981312050993e-07，该检测器半径为1e-06
# 第619个异常样本，被第35330个自体检测器错误覆盖，距离4.4504357943141694e-07，该检测器半径为1e-06
# 第626个异常样本，被第284个自体检测器错误覆盖，距离1.2990531157078367e-07，该检测器半径为1e-06
# 第628个异常样本，被第2033个自体检测器错误覆盖，距离9.933610771546352e-07，该检测器半径为1e-06
# 第632个异常样本，被第7525个自体检测器错误覆盖，距离5.405651674803876e-07，该检测器半径为1e-06
# 第633个异常样本，被第21583个自体检测器错误覆盖，距离0.0002187430329997505，该检测器半径为0.0002301679934512342
# 第646个异常样本，被第2095个自体检测器错误覆盖，距离7.742870518041358e-07，该检测器半径为1e-06
# 第647个异常样本，被第35330个自体检测器错误覆盖，距离1.9314112360500873e-07，该检测器半径为1e-06
# 第653个异常样本，被第4827个自体检测器错误覆盖，距离0.0008589111578401608，该检测器半径为0.0013396079645434317
# 第655个异常样本，被第1503个自体检测器错误覆盖，距离8.709215760329575e-07，该检测器半径为1e-06
# 第659个异常样本，被第288个自体检测器错误覆盖，距离5.551557582553276e-07，该检测器半径为1e-06
# 第662个异常样本，被第6905个自体检测器错误覆盖，距离0.0003543959513255743，该检测器半径为0.00040718201577908075
# 第678个异常样本，被第7525个自体检测器错误覆盖，距离2.763753684863559e-07，该检测器半径为1e-06
# 第691个异常样本，被第1813个自体检测器错误覆盖，距离8.59113662975839e-07，该检测器半径为1e-06
# 第693个异常样本，被第694个自体检测器错误覆盖，距离3.964941113206404e-07，该检测器半径为1e-06
# 第694个异常样本，被第7525个自体检测器错误覆盖，距离6.005001590276969e-07，该检测器半径为1e-06
# 第697个异常样本，被第793个自体检测器错误覆盖，距离4.308471767545033e-07，该检测器半径为1e-06
# 第704个异常样本，被第7525个自体检测器错误覆盖，距离9.471326236081847e-07，该检测器半径为1e-06
# 第708个异常样本，被第364个自体检测器错误覆盖，距离9.933610771420405e-07，该检测器半径为1e-06
# 第713个异常样本，被第2379个自体检测器错误覆盖，距离1.3657139822709083e-07，该检测器半径为1e-06
# 第728个异常样本，被第1813个自体检测器错误覆盖，距离6.474721765622007e-07，该检测器半径为1e-06
# 第729个异常样本，被第364个自体检测器错误覆盖，距离8.052144101921496e-07，该检测器半径为1e-06
# 第736个异常样本，被第9697个自体检测器错误覆盖，距离7.39197751138986e-05，该检测器半径为7.392336158797063e-05
# 第746个异常样本，被第7525个自体检测器错误覆盖，距离3.908537941483743e-07，该检测器半径为1e-06
# 第753个异常样本，被第793个自体检测器错误覆盖，距离4.24617733024806e-07，该检测器半径为1e-06
# 第757个异常样本，被第736个自体检测器错误覆盖，距离0.00011422885728518112，该检测器半径为0.002166115490593534
# 第761个异常样本，被第24970个自体检测器错误覆盖，距离1.3693575382214087e-05，该检测器半径为1.5581057735927752e-05
# 第762个异常样本，被第839个自体检测器错误覆盖，距离4.150983177776372e-07，该检测器半径为1e-06
# 第766个异常样本，被第1503个自体检测器错误覆盖，距离6.912597153867352e-07，该检测器半径为1e-06
# 第775个异常样本，被第694个自体检测器错误覆盖，距离3.942476676818065e-07，该检测器半径为1e-06
# 第781个异常样本，被第10个自体检测器错误覆盖，距离6.104195961298162e-05，该检测器半径为9.162500098090652e-05
# 第782个异常样本，被第481个自体检测器错误覆盖，距离7.303855508756736e-05，该检测器半径为8.930661174568445e-05
# 第785个异常样本，被第19967个自体检测器错误覆盖，距离0.00018360279454958966，该检测器半径为0.00020683642771437144
# 第794个异常样本，被第364个自体检测器错误覆盖，距离9.920190059489494e-07，该检测器半径为1e-06
# 第800个异常样本，被第7525个自体检测器错误覆盖，距离5.438413529708945e-07，该检测器半径为1e-06
# 第803个异常样本，被第447个自体检测器错误覆盖，距离3.488272401904948e-07，该检测器半径为1e-06
# 第805个异常样本，被第7525个自体检测器错误覆盖，距离8.445160001209403e-07，该检测器半径为1e-06
# 第806个异常样本，被第1610个自体检测器错误覆盖，距离0.00025019580771952374，该检测器半径为0.00025024538065805994
# 第811个异常样本，被第1917个自体检测器错误覆盖，距离0.008559298425645923，该检测器半径为0.008604460227655302
# 第812个异常样本，被第958个自体检测器错误覆盖，距离6.906169826307093e-07，该检测器半径为1e-06
# 第814个异常样本，被第958个自体检测器错误覆盖，距离7.121445660592726e-07，该检测器半径为1e-06
# 第815个异常样本，被第6653个自体检测器错误覆盖，距离0.0009009174130917744，该检测器半径为0.0013406301476154394
# 第819个异常样本，被第2694个自体检测器错误覆盖，距离5.430241621091989e-07，该检测器半径为1e-06
# 第823个异常样本，被第7525个自体检测器错误覆盖，距离4.4901726189945825e-07，该检测器半径为1e-06
# 第825个异常样本，被第839个自体检测器错误覆盖，距离6.071194680321628e-07，该检测器半径为1e-06
# 第826个异常样本，被第5840个自体检测器错误覆盖，距离0.002793717846900323，该检测器半径为0.002793717846922163
# 第828个异常样本，被第1503个自体检测器错误覆盖，距离1.8848645065882302e-07，该检测器半径为1e-06
# 第831个异常样本，被第21949个自体检测器错误覆盖，距离1.3529729218613587e-06，该检测器半径为1.8491254341554434e-06
# 第832个异常样本，被第6976个自体检测器错误覆盖，距离0.007607441011496316，该检测器半径为0.011243696607332739
# 第840个异常样本，被第288个自体检测器错误覆盖，距离7.312204954373063e-07，该检测器半径为1e-06
# 第843个异常样本，被第315个自体检测器错误覆盖，距离4.32903738210617e-07，该检测器半径为1e-06
# 第846个异常样本，被第7525个自体检测器错误覆盖，距离7.968987217204128e-07，该检测器半径为1e-06
# 第847个异常样本，被第9027个自体检测器错误覆盖，距离9.329602647590353e-07，该检测器半径为1e-06
# 第853个异常样本，被第284个自体检测器错误覆盖，距离5.230286403119973e-07，该检测器半径为1e-06
# 第856个异常样本，被第1296个自体检测器错误覆盖，距离5.701774681848885e-05，该检测器半径为0.0003140533958226195
# 第858个异常样本，被第7525个自体检测器错误覆盖，距离6.74349578254677e-07，该检测器半径为1e-06
# 第859个异常样本，被第284个自体检测器错误覆盖，距离6.300918780676369e-07，该检测器半径为1e-06
# 第860个异常样本，被第15115个自体检测器错误覆盖，距离0.00199529190604312，该检测器半径为0.0023750422287155976
# 第861个异常样本，被第30974个自体检测器错误覆盖，距离3.8753597870621324e-05，该检测器半径为6.681276235475639e-05
# 第863个异常样本，被第315个自体检测器错误覆盖，距离5.809542191773836e-07，该检测器半径为1e-06
# 第872个异常样本，被第288个自体检测器错误覆盖，距离4.878850443287164e-07，该检测器半径为1e-06
# 第875个异常样本，被第284个自体检测器错误覆盖，距离6.982907514898179e-07，该检测器半径为1e-06
# 第885个异常样本，被第288个自体检测器错误覆盖，距离4.6932744228910274e-07，该检测器半径为1e-06
# 第886个异常样本，被第1818个自体检测器错误覆盖，距离0.00042462834481763384，该检测器半径为0.0006860319012996571
# 第889个异常样本，被第16457个自体检测器错误覆盖，距离0.00011238971495499534，该检测器半径为0.00011824774942788755
# 第890个异常样本，被第958个自体检测器错误覆盖，距离9.476013836613087e-07，该检测器半径为1e-06
# 第892个异常样本，被第66个自体检测器错误覆盖，距离4.042583759414008e-07，该检测器半径为1e-06
# 第893个异常样本，被第11387个自体检测器错误覆盖，距离2.423535413412571e-06，该检测器半径为4.252317297905922e-06
# 第895个异常样本，被第7525个自体检测器错误覆盖，距离3.804905812383802e-07，该检测器半径为1e-06
# 第897个异常样本，被第17378个自体检测器错误覆盖，距离0.0007768613662697461，该检测器半径为0.0030604453561303437
# 第902个异常样本，被第6374个自体检测器错误覆盖，距离6.657334577361578e-07，该检测器半径为1e-06
# 第905个异常样本，被第520个自体检测器错误覆盖，距离0.00026555238080395625，该检测器半径为0.0003786969131324015
# 第907个异常样本，被第1173个自体检测器错误覆盖，距离6.019774086555134e-07，该检测器半径为1e-06
# 第910个异常样本，被第66个自体检测器错误覆盖，距离3.371747880871523e-07，该检测器半径为1e-06
# 第914个异常样本，被第793个自体检测器错误覆盖，距离6.970176467379236e-07，该检测器半径为1e-06
# 第918个异常样本，被第288个自体检测器错误覆盖，距离5.161913707182574e-07，该检测器半径为1e-06
# 第919个异常样本，被第694个自体检测器错误覆盖，距离3.793216366310291e-07，该检测器半径为1e-06
# 第920个异常样本，被第1968个自体检测器错误覆盖，距离0.0001225183115070849，该检测器半径为0.0005078053439450458
# 第921个异常样本，被第1464个自体检测器错误覆盖，距离8.188862626529394e-07，该检测器半径为1e-06
# 第923个异常样本，被第12396个自体检测器错误覆盖，距离0.0015354439294344296，该检测器半径为0.002248452865925488
# 第924个异常样本，被第8665个自体检测器错误覆盖，距离1.1542389828584841e-07，该检测器半径为1e-06
# 第925个异常样本，被第905个自体检测器错误覆盖，距离9.620197152157193e-07，该检测器半径为1e-06
# 第926个异常样本，被第315个自体检测器错误覆盖，距离9.18085685319935e-07，该检测器半径为1e-06
# 第934个异常样本，被第7293个自体检测器错误覆盖，距离9.161487935431528e-07，该检测器半径为1e-06
# 第936个异常样本，被第289个自体检测器错误覆盖，距离0.0005687512340214092，该检测器半径为0.0007292679156496776
# 第937个异常样本，被第39023个自体检测器错误覆盖，距离0.0072987435993327075，该检测器半径为0.007344969418831763
# 第939个异常样本，被第958个自体检测器错误覆盖，距离8.54448746849981e-07，该检测器半径为1e-06
# 第942个异常样本，被第958个自体检测器错误覆盖，距离7.650552815982389e-07，该检测器半径为1e-06
# 第944个异常样本，被第288个自体检测器错误覆盖，距离4.470348358154297e-07，该检测器半径为1e-06
# 第947个异常样本，被第28884个自体检测器错误覆盖，距离7.183534416564932e-07，该检测器半径为1e-06
# 第948个异常样本，被第611个自体检测器错误覆盖，距离4.039873828814472e-05，该检测器半径为0.0003399185057658183
# 第950个异常样本，被第6374个自体检测器错误覆盖，距离3.0246054705212185e-07，该检测器半径为1e-06
# 第951个异常样本，被第694个自体检测器错误覆盖，距离5.356133259004285e-07，该检测器半径为1e-06
# 第961个异常样本，被第288个自体检测器错误覆盖，距离9.69835536401938e-07，该检测器半径为1e-06
# 第979个异常样本，被第50233个自体检测器错误覆盖，距离9.942547964367184e-07，该检测器半径为1e-06
# 第981个异常样本，被第7525个自体检测器错误覆盖，距离9.190525991153149e-07，该检测器半径为1e-06
# 第987个异常样本，被第9706个自体检测器错误覆盖，距离0.0005610440424141502，该检测器半径为0.0007164452097078159
# 第993个异常样本，被第6374个自体检测器错误覆盖，距离4.558878760219285e-07，该检测器半径为1e-06
# 第999个异常样本，被第10826个自体检测器错误覆盖，距离0.0003419266505347381，该检测器半径为0.000354305217574739
# 第1000个异常样本，被第1526个自体检测器错误覆盖，距离8.0023536575422e-07，该检测器半径为1e-06
# 第1001个异常样本，被第7867个自体检测器错误覆盖，距离0.006234079660419287，该检测器半径为0.0064822111183008785
# 第1005个异常样本，被第4154个自体检测器错误覆盖，距离4.519746019954126e-07，该检测器半径为1e-06
# 第1009个异常样本，被第14714个自体检测器错误覆盖，距离9.578561023813586e-07，该检测器半径为1e-06
# 第1012个异常样本，被第1813个自体检测器错误覆盖，距离7.834100416362564e-07，该检测器半径为1e-06
# 第1014个异常样本，被第39293个自体检测器错误覆盖，距离0.004172727722596801，该检测器半径为0.004172727722689726
# 第1020个异常样本，被第2525个自体检测器错误覆盖，距离6.433437212020001e-07，该检测器半径为1e-06
# 第1023个异常样本，被第867个自体检测器错误覆盖，距离0.00018897772472574147，该检测器半径为0.00031646119952832537
# 第1024个异常样本，被第4246个自体检测器错误覆盖，距离7.737132932629762e-07，该检测器半径为1e-06
# 第1028个异常样本，被第33531个自体检测器错误覆盖，距离0.014169788128551821，该检测器半径为0.014192808588770372
# 第1030个异常样本，被第284个自体检测器错误覆盖，距离6.542950553812143e-07，该检测器半径为1e-06
# 第1031个异常样本，被第4267个自体检测器错误覆盖，距离7.351111806069185e-05，该检测器半径为0.0012346619069782574
# 第1032个异常样本，被第7525个自体检测器错误覆盖，距离3.13986950044858e-07，该检测器半径为1e-06
# 第1034个异常样本，被第2286个自体检测器错误覆盖，距离5.551557582553276e-07，该检测器半径为1e-06
# 第1036个异常样本，被第6227个自体检测器错误覆盖，距离2.6277571769831272e-05，该检测器半径为5.170683609956585e-05
# 第1042个异常样本，被第315个自体检测器错误覆盖，距离3.2782554626464844e-07，该检测器半径为1e-06
# 第1043个异常样本，被第364个自体检测器错误覆盖，距离8.714313219316867e-07，该检测器半径为1e-06
# 第1048个异常样本，被第7525个自体检测器错误覆盖，距离1.999200562387517e-07，该检测器半径为1e-06
# 第1051个异常样本，被第694个自体检测器错误覆盖，距离5.213277296933441e-07，该检测器半径为1e-06
# 第1052个异常样本，被第7525个自体检测器错误覆盖，距离5.438413529708945e-07，该检测器半径为1e-06
# 第1054个异常样本，被第284个自体检测器错误覆盖，距离9.248328710486379e-07，该检测器半径为1e-06
# 第1055个异常样本，被第295个自体检测器错误覆盖，距离0.0004005846989693433，该检测器半径为0.00040246646445255186
# 第1058个异常样本，被第1464个自体检测器错误覆盖，距离3.00988710972932e-07，该检测器半径为1e-06
# 第1061个异常样本，被第8087个自体检测器错误覆盖，距离7.146345878372867e-07，该检测器半径为1e-06
# 第1068个异常样本，被第8087个自体检测器错误覆盖，距离6.938246942011105e-07，该检测器半径为1e-06
# 第1069个异常样本，被第154个自体检测器错误覆盖，距离7.609811750501354e-07，该检测器半径为1e-06
# 第1074个异常样本，被第2525个自体检测器错误覆盖，距离6.467859272653801e-07，该检测器半径为1e-06
# 第1075个异常样本，被第7628个自体检测器错误覆盖，距离9.151788179849876e-07，该检测器半径为1e-06
# 第1077个异常样本，被第19785个自体检测器错误覆盖，距离4.6169559406070036e-07，该检测器半径为1e-06
# 第1082个异常样本，被第7525个自体检测器错误覆盖，距离4.2357058560667727e-07，该检测器半径为1e-06
# 第1085个异常样本，被第471个自体检测器错误覆盖，距离0.00028483492251370906，该检测器半径为0.0006717786884053739
# 第1090个异常样本，被第1710个自体检测器错误覆盖，距离0.020320549194843367，该检测器半径为0.03566474113147805
# 第1093个异常样本，被第87个自体检测器错误覆盖，距离6.426530716331606e-07，该检测器半径为1e-06
# 第1094个异常样本，被第7525个自体检测器错误覆盖，距离2.3466372159574645e-07，该检测器半径为1e-06
# 第1095个异常样本，被第52558个自体检测器错误覆盖，距离2.2860751347974527e-05，该检测器半径为2.5431353909244336e-05
# 第1105个异常样本，被第958个自体检测器错误覆盖，距离6.906169826307093e-07，该检测器半径为1e-06
# 第1108个异常样本，被第1618个自体检测器错误覆盖，距离3.039252538650208e-07，该检测器半径为1e-06
# 第1111个异常样本，被第182个自体检测器错误覆盖，距离5.272569114389067e-07，该检测器半径为1e-06
# 第1113个异常样本，被第288个自体检测器错误覆盖，距离4.182955279236495e-07，该检测器半径为1e-06
# 第1118个异常样本，被第7525个自体检测器错误覆盖，距离7.183534399246442e-07，该检测器半径为1e-06
# 第1119个异常样本，被第7525个自体检测器错误覆盖，距离6.085806448012543e-07，该检测器半径为1e-06
# 第1120个异常样本，被第958个自体检测器错误覆盖，距离7.644746047865346e-07，该检测器半径为1e-06
# 第1121个异常样本，被第3295个自体检测器错误覆盖，距离2.1073424255447017e-07，该检测器半径为1e-06
# 第1122个异常样本，被第4785个自体检测器错误覆盖，距离9.982665937650498e-07，该检测器半径为1e-06
# 第1128个异常样本，被第6374个自体检测器错误覆盖，距离4.655271632255055e-07，该检测器半径为1e-06
# 第1132个异常样本，被第1418个自体检测器错误覆盖，距离7.805705606813456e-07，该检测器半径为1e-06
# 第1135个异常样本，被第10937个自体检测器错误覆盖，距离0.0010005630235180945，该检测器半径为0.001000563023795071
# 第1144个异常样本，被第1503个自体检测器错误覆盖，距离5.59141149362366e-07，该检测器半径为1e-06
# 第1146个异常样本，被第284个自体检测器错误覆盖，距离5.048833645238413e-07，该检测器半径为1e-06
# 第1154个异常样本，被第1804个自体检测器错误覆盖，距离1.2990531157078367e-07，该检测器半径为1e-06
# 第1156个异常样本，被第7525个自体检测器错误覆盖，距离2.563692713052161e-07，该检测器半径为1e-06
# 第1160个异常样本，被第2276个自体检测器错误覆盖，距离3.417991189045743e-05，该检测器半径为4.80348771481375e-05
# 第1164个异常样本，被第8330个自体检测器错误覆盖，距离0.008465425519577978，该检测器半径为0.008537256066193398
# 第1165个异常样本，被第2582个自体检测器错误覆盖，距离0.0010969131185563305，该检测器半径为0.0012280145015263143
# 第1170个异常样本，被第839个自体检测器错误覆盖，距离5.771194960157756e-07，该检测器半径为1e-06
# 第1173个异常样本，被第7525个自体检测器错误覆盖，距离7.811392815239691e-07，该检测器半径为1e-06
# 第1174个异常样本，被第10041个自体检测器错误覆盖，距离9.948342426614278e-05，该检测器半径为0.00010336787517093509
# 第1177个异常样本，被第4280个自体检测器错误覆盖，距离0.0012374991225142205，该检测器半径为0.001362700107365075
# 第1178个异常样本，被第793个自体检测器错误覆盖，距离4.053554143373781e-07，该检测器半径为1e-06
# 第1181个异常样本，被第5642个自体检测器错误覆盖，距离1.060811983219566e-06，该检测器半径为1.1081095005618456e-06
# 第1184个异常样本，被第6374个自体检测器错误覆盖，距离5.840038685306836e-07，该检测器半径为1e-06
# 第1185个异常样本，被第594个自体检测器错误覆盖，距离0.00023344661401219658，该检测器半径为0.0004181252783163938
# 第1188个异常样本，被第154个自体检测器错误覆盖，距离4.869739647538025e-07，该检测器半径为1e-06
# 第1194个异常样本，被第210个自体检测器错误覆盖，距离3.425519959418388e-05，该检测器半径为3.480842042893809e-05
# 第1196个异常样本，被第2379个自体检测器错误覆盖，距离9.698355353350564e-07，该检测器半径为1e-06
# 第1197个异常样本，被第1526个自体检测器错误覆盖，距离6.643979830530178e-07，该检测器半径为1e-06
# 第1205个异常样本，被第1526个自体检测器错误覆盖，距离9.978216342502283e-07，该检测器半径为1e-06
# 第1208个异常样本，被第10203个自体检测器错误覆盖，距离0.00041472281250333823，该检测器半径为0.000490665666472051
# 第1209个异常样本，被第694个自体检测器错误覆盖，距离7.121445771924373e-07，该检测器半径为1e-06
# 第1211个异常样本，被第2525个自体检测器错误覆盖，距离7.014633593735655e-07，该检测器半径为1e-06
# 第1217个异常样本，被第694个自体检测器错误覆盖，距离6.79597515119936e-07，该检测器半径为1e-06
# 第1220个异常样本，被第66个自体检测器错误覆盖，距离7.133906753413556e-07，该检测器半径为1e-06
# 第1222个异常样本，被第1503个自体检测器错误覆盖，距离5.04883380227315e-07，该检测器半径为1e-06
# 第1224个异常样本，被第8087个自体检测器错误覆盖，距离6.995615139848728e-07，该检测器半径为1e-06
# 第1225个异常样本，被第7525个自体检测器错误覆盖，距离5.057621855325954e-07，该检测器半径为1e-06
# 第1230个异常样本，被第17077个自体检测器错误覆盖，距离0.0008426752006155649，该检测器半径为0.0009123497584291748
# 第1233个异常样本，被第1813个自体检测器错误覆盖，距离9.624812262523307e-07，该检测器半径为1e-06
# 第1234个异常样本，被第7525个自体检测器错误覆盖，距离5.048833594660199e-07，该检测器半径为1e-06
# 第1237个异常样本，被第4898个自体检测器错误覆盖，距离0.0007317596955743012，该检测器半径为0.0008848318412930631
# 第1243个异常样本，被第9027个自体检测器错误覆盖，距离9.176018456660136e-07，该检测器半径为1e-06
# 第1246个异常样本，被第694个自体检测器错误覆盖，距离4.664801369249379e-07，该检测器半径为1e-06
# 第1255个异常样本，被第2379个自体检测器错误覆盖，距离5.380949452617044e-07，该检测器半径为1e-06
# 第1271个异常样本，被第6481个自体检测器错误覆盖，距离0.0351901651707，该检测器半径为0.03883240664029238
# 第1281个异常样本，被第7293个自体检测器错误覆盖，距离9.108011030509873e-07，该检测器半径为1e-06
# 第1283个异常样本，被第7525个自体检测器错误覆盖，距离4.5295608524722037e-07，该检测器半径为1e-06
# 第1286个异常样本，被第66个自体检测器错误覆盖，距离2.580956827951785e-07，该检测器半径为1e-06
# 第1287个异常样本，被第590个自体检测器错误覆盖，距离0.00028478161039812333，该检测器半径为0.0015538479690792894
# 第1290个异常样本，被第2033个自体检测器错误覆盖，距离7.8284296951053e-07，该检测器半径为1e-06
# 第1293个异常样本，被第1891个自体检测器错误覆盖，距离1.7524500470576104e-05，该检测器半径为7.285224035536708e-05
# 第1294个异常样本，被第15934个自体检测器错误覆盖，距离0.0008358248547975694，该检测器半径为0.0008828956311871872
# 第1295个异常样本，被第694个自体检测器错误覆盖，距离6.93184340815431e-07，该检测器半径为1e-06
# 第1299个异常样本，被第358个自体检测器错误覆盖，距离8.123587288515927e-05，该检测器半径为8.833943190158113e-05
# 第1306个异常样本，被第7628个自体检测器错误覆盖，距离8.835773028024152e-07，该检测器半径为1e-06
# 第1309个异常样本，被第7525个自体检测器错误覆盖，距离4.796229916751321e-07，该检测器半径为1e-06
# 第1310个异常样本，被第40435个自体检测器错误覆盖，距离7.090197383169538e-07，该检测器半径为1e-06
# 第1311个异常样本，被第19785个自体检测器错误覆盖，距离8.955585499733026e-07，该检测器半径为1e-06
# 第1314个异常样本，被第694个自体检测器错误覆盖，距离5.004661024229448e-07，该检测器半径为1e-06
# 第1317个异常样本，被第958个自体检测器错误覆盖，距离9.541398751721228e-07，该检测器半径为1e-06
# 第1321个异常样本，被第7181个自体检测器错误覆盖，距离0.002258281603412802，该检测器半径为0.002269831239074987
# 第1322个异常样本，被第43593个自体检测器错误覆盖，距离3.4281105085777854e-05，该检测器半径为5.239294152993382e-05
# 第1327个异常样本，被第7525个自体检测器错误覆盖，距离9.049312160431378e-07，该检测器半径为1e-06
# 第1331个异常样本，被第2379个自体检测器错误覆盖，距离5.763494897081327e-07，该检测器半径为1e-06
# 第1336个异常样本，被第3890个自体检测器错误覆盖，距离0.0006651592495079135，该检测器半径为0.0006740653002994095
# 第1339个异常样本，被第11227个自体检测器错误覆盖，距离0.010068199773554458，该检测器半径为0.01006822539097417
# 第1346个异常样本，被第288个自体检测器错误覆盖，距离4.786961795153919e-07，该检测器半径为1e-06
# 第1350个异常样本，被第1173个自体检测器错误覆盖，距离9.56464214433543e-07，该检测器半径为1e-06
# 第1354个异常样本，被第6004个自体检测器错误覆盖，距离1.397852832937554e-06，该检测器半径为3.1967766417236036e-06
# 第1360个异常样本，被第2379个自体检测器错误覆盖，距离5.405651721812062e-07，该检测器半径为1e-06
# 第1362个异常样本，被第4615个自体检测器错误覆盖，距离4.00949247772654e-07，该检测器半径为1e-06
# 第1365个异常样本，被第22622个自体检测器错误覆盖，距离0.00489454443577413，该检测器半径为0.004924538800425657
# 第1370个异常样本，被第8665个自体检测器错误覆盖，距离2.308478080380306e-07，该检测器半径为1e-06
# 第1371个异常样本，被第1503个自体检测器错误覆盖，距离4.4103410209221164e-07，该检测器半径为1e-06
# 第1382个异常样本，被第18144个自体检测器错误覆盖，距离1.2152040930891954e-05，该检测器半径为4.931637620374378e-05
# 第1385个异常样本，被第154个自体检测器错误覆盖，距离4.075406292431755e-07，该检测器半径为1e-06
# 第1394个异常样本，被第2694个自体检测器错误覆盖，距离5.70930368218122e-07，该检测器半径为1e-06
# 第1399个异常样本，被第288个自体检测器错误覆盖，距离4.833124500580685e-07，该检测器半径为1e-06
# 第1403个异常样本，被第107个自体检测器错误覆盖，距离8.42454838834763e-05，该检测器半径为0.00015156604090994498
# 第1409个异常样本，被第154个自体检测器错误覆盖，距离7.935480482561363e-07，该检测器半径为1e-06
# 第1410个异常样本，被第7935个自体检测器错误覆盖，距离0.001310839345871456，该检测器半径为0.0016570385740195014
# 第1414个异常样本，被第288个自体检测器错误覆盖，距离4.796229880878652e-07，该检测器半径为1e-06
# 第1416个异常样本，被第2525个自体检测器错误覆盖，距离6.880400407897387e-07，该检测器半径为1e-06
# 第1417个异常样本，被第38586个自体检测器错误覆盖，距离8.668327091546236e-07，该检测器半径为1e-06
# 第1418个异常样本，被第22084个自体检测器错误覆盖，距离9.670842134860906e-07，该检测器半径为1e-06
# 第1419个异常样本，被第7382个自体检测器错误覆盖，距离0.0004934794323585229，该检测器半径为0.0015570766883852179
# 第1427个异常样本，被第958个自体检测器错误覆盖，距离9.466636396726517e-07，该检测器半径为1e-06
# 第1428个异常样本，被第2033个自体检测器错误覆盖，距离8.323335673821643e-07，该检测器半径为1e-06
# 第1429个异常样本，被第7525个自体检测器错误覆盖，距离2.715120790073043e-07，该检测器半径为1e-06
# 第1436个异常样本，被第8591个自体检测器错误覆盖，距离0.0014118695716199149，该检测器半径为0.0017007496932288308
# 第1441个异常样本，被第839个自体检测器错误覆盖，距离6.398830016259707e-07，该检测器半径为1e-06
# 第1445个异常样本，被第7525个自体检测器错误覆盖，距离8.719407835794262e-07，该检测器半径为1e-06
# 第1448个异常样本，被第449个自体检测器错误覆盖，距离7.027284017650245e-07，该检测器半径为1.094804447097891e-06
# 第1453个异常样本，被第2033个自体检测器错误覆盖，距离9.300998796402997e-07，该检测器半径为1e-06
# 第1454个异常样本，被第23618个自体检测器错误覆盖，距离0.0011532207101029204，该检测器半径为0.0012320065594618689
# 第1462个异常样本，被第2033个自体检测器错误覆盖，距离8.018984822830836e-07，该检测器半径为1e-06
# 第1464个异常样本，被第1503个自体检测器错误覆盖，距离5.960464477539063e-08，该检测器半径为1e-06
# 第1467个异常样本，被第3473个自体检测器错误覆盖，距离0.0010479644163692659，该检测器半径为0.0012989150110296723
# 第1468个异常样本，被第7525个自体检测器错误覆盖，距离2.665600753822077e-07，该检测器半径为1e-06
# 第1469个异常样本，被第1173个自体检测器错误覆盖，距离9.55535157203844e-07，该检测器半径为1e-06
# 第1470个异常样本，被第315个自体检测器错误覆盖，距离3.976125736274223e-07，该检测器半径为1e-06
# 第1477个异常样本，被第12477个自体检测器错误覆盖，距离0.0006866295283607359，该检测器半径为0.001284241491241754
# 第1481个异常样本，被第12690个自体检测器错误覆盖，距离0.00040855858631716854，该检测器半径为0.0024776450209606695
# 第1484个异常样本，被第793个自体检测器错误覆盖，距离7.504033071514513e-07，该检测器半径为1e-06
# 第1489个异常样本，被第1245个自体检测器错误覆盖，距离0.0003198109406343662，该检测器半径为0.0009543162295339488
# 第1503个异常样本，被第14816个自体检测器错误覆盖，距离2.08509793750415e-06，该检测器半径为2.880899728016895e-06
# 第1505个异常样本，被第12809个自体检测器错误覆盖，距离7.73857516094926e-05，该检测器半径为9.462272322958076e-05
# 第1507个异常样本，被第7525个自体检测器错误覆盖，距离3.710359217990593e-07，该检测器半径为1e-06
# 第1515个异常样本，被第2579个自体检测器错误覆盖，距离3.457563931126297e-05，该检测器半径为0.00013592204758887188
# 第1518个异常样本，被第12875个自体检测器错误覆盖，距离7.71459302036189e-05，该检测器半径为9.0357543980214e-05
# 第1523个异常样本，被第154个自体检测器错误覆盖，距离4.0205531543996166e-07，该检测器半径为1e-06
# 第1529个异常样本，被第1000个自体检测器错误覆盖，距离6.717102370082055e-07，该检测器半径为1e-06
# 第1532个异常样本，被第14个自体检测器错误覆盖，距离0.0005934936783666793，该检测器半径为0.00099676722041408
# 第1537个异常样本，被第66个自体检测器错误覆盖，距离4.075406357381793e-07，该检测器半径为1e-06
# 第1539个异常样本，被第33122个自体检测器错误覆盖，距离2.4410867418483387e-05，该检测器半径为6.263026563541712e-05
# 第1540个异常样本，被第958个自体检测器错误覆盖，距离7.56885131250064e-07，该检测器半径为1e-06
# 第1541个异常样本，被第31066个自体检测器错误覆盖，距离0.0006652055715629688，该检测器半径为0.0009019381786168828
# 第1557个异常样本，被第6344个自体检测器错误覆盖，距离0.004336008624938244，该检测器半径为0.004469123545546167
# 第1558个异常样本，被第694个自体检测器错误覆盖，距离5.255696840951401e-07，该检测器半径为1e-06
# 第1560个异常样本，被第7628个自体检测器错误覆盖，距离8.835773028024152e-07，该检测器半径为1e-06
# 第1561个异常样本，被第284个自体检测器错误覆盖，距离1.9082797281243946e-07，该检测器半径为1e-06
# 第1562个异常样本，被第1813个自体检测器错误覆盖，距离7.834100416362564e-07，该检测器半径为1e-06
# 第1563个异常样本，被第3457个自体检测器错误覆盖，距离7.811392831356777e-07，该检测器半径为1e-06
# 第1564个异常样本，被第7525个自体检测器错误覆盖，距离4.36987826429164e-07，该检测器半径为1e-06
# 第1571个异常样本，被第7525个自体检测器错误覆盖，距离6.11492530539426e-07，该检测器半径为1e-06
# 第1576个异常样本，被第805个自体检测器错误覆盖，距离0.0012305308028742357，该检测器半径为0.0015888018541118448
# 第1577个异常样本，被第1464个自体检测器错误覆盖，距离5.264139732516068e-07，该检测器半径为1e-06
# 第1581个异常样本，被第1464个自体检测器错误覆盖，距离4.0425837597823187e-07，该检测器半径为1e-06
# 第1588个异常样本，被第1464个自体检测器错误覆盖，距离5.511415642333167e-07，该检测器半径为1e-06
# 第1595个异常样本，被第21041个自体检测器错误覆盖，距离0.0056298197495546105，该检测器半径为0.005930864883762865
# 第1602个异常样本，被第9027个自体检测器错误覆盖，距离9.78496978246093e-07，该检测器半径为1e-06
# 第1606个异常样本，被第839个自体检测器错误覆盖，距离4.674311666270608e-07，该检测器半径为1e-06
# 第1610个异常样本，被第1526个自体检测器错误覆盖，距离7.281775309366355e-07，该检测器半径为1e-06
# 第1613个异常样本，被第1503个自体检测器错误覆盖，距离7.25733978259291e-07，该检测器半径为1e-06
# 第1620个异常样本，被第284个自体检测器错误覆盖，距离1.999200562387517e-07，该检测器半径为1e-06
# 第1622个异常样本，被第6374个自体检测器错误覆盖，距离6.041865074550303e-07，该检测器半径为1e-06
# 第1623个异常样本，被第22635个自体检测器错误覆盖，距离2.419843974271896e-05，该检测器半径为2.791619506143828e-05
# 第1627个异常样本，被第154个自体检测器错误覆盖，距离9.281880662049715e-07，该检测器半径为1e-06
# 第1635个异常样本，被第3693个自体检测器错误覆盖，距离8.682557724082338e-06，该检测器半径为1.2408775905127897e-05
# 第1636个异常样本，被第447个自体检测器错误覆盖，距离8.930757190893253e-07，该检测器半径为1e-06
# 第1638个异常样本，被第2379个自体检测器错误覆盖，距离4.995779631396018e-07，该检测器半径为1e-06
# 第1639个异常样本，被第7525个自体检测器错误覆盖，距离9.620197067281559e-07，该检测器半径为1e-06
# 第1645个异常样本，被第33624个自体检测器错误覆盖，距离0.0005173206576445847，该检测器半径为0.0007793527661091829
# 第1647个异常样本，被第7525个自体检测器错误覆盖，距离4.5588787329301263e-07，该检测器半径为1e-06
# 第1656个异常样本，被第4372个自体检测器错误覆盖，距离1.2990532807551304e-07，该检测器半径为1e-06
# 第1659个异常样本，被第4615个自体检测器错误覆盖，距离5.204751848153168e-07，该检测器半径为1e-06
# 第1667个异常样本，被第26个自体检测器错误覆盖，距离0.0006708012780769927，该检测器半径为0.0008679745595761942
# 第1672个异常样本，被第87个自体检测器错误覆盖，距离5.801893021982787e-07，该检测器半径为1e-06
# 第1675个异常样本，被第1618个自体检测器错误覆盖，距离6.886851823641708e-07，该检测器半径为1e-06
# 第1678个异常样本，被第1526个自体检测器错误覆盖，距离6.743495800995356e-07，该检测器半径为1e-06
# 第1685个异常样本，被第1619个自体检测器错误覆盖，距离9.248328699324131e-07，该检测器半径为1e-06
# 第1693个异常样本，被第19500个自体检测器错误覆盖，距离0.00017621261929495562，该检测器半径为0.0003582999729907988
# 第1697个异常样本，被第2379个自体检测器错误覆盖，距离9.716654152805966e-07，该检测器半径为1e-06
# 第1701个异常样本，被第34309个自体检测器错误覆盖，距离0.00047225879533440237，该检测器半径为0.0005244236251948806
# 第1704个异常样本，被第8665个自体检测器错误覆盖，距离1.228781230931777e-07，该检测器半径为1e-06
# 第1709个异常样本，被第1969个自体检测器错误覆盖，距离0.0007430349101229095，该检测器半径为0.000836021577467677
# 第1714个异常样本，被第5216个自体检测器错误覆盖，距离0.0005640997438254312，该检测器半径为0.0005886928595003298
# 第1717个异常样本，被第1503个自体检测器错误覆盖，距离4.097142011418198e-07，该检测器半径为1e-06
# 第1719个异常样本，被第958个自体检测器错误覆盖，距离7.195887844353698e-07，该检测器半径为1e-06
# 第1721个异常样本，被第7525个自体检测器错误覆盖，距离8.445160001209403e-07，该检测器半径为1e-06
# 第1722个异常样本，被第6374个自体检测器错误覆盖，距离4.81471258576967e-07，该检测器半径为1e-06
# 第1724个异常样本，被第1261个自体检测器错误覆盖，距离0.0005596884515781026，该检测器半径为0.0007955298509585553
# 第1725个异常样本，被第28884个自体检测器错误覆盖，距离5.204751899010116e-07，该检测器半径为1e-06
# 第1727个异常样本，被第284个自体检测器错误覆盖，距离9.780430354631031e-07，该检测器半径为1e-06
# 第1729个异常样本，被第38223个自体检测器错误覆盖，距离0.0038832254359782224，该检测器半径为0.0040117288238703495
# 第1730个异常样本，被第364个自体检测器错误覆盖，距离8.156259201676646e-07，该检测器半径为1e-06
# 第1739个异常样本，被第288个自体检测器错误覆盖，距离6.265579627166655e-07，该检测器半径为1e-06
# 第1740个异常样本，被第7525个自体检测器错误覆盖，距离6.336060671256984e-07，该检测器半径为1e-06
# 第1744个异常样本，被第284个自体检测器错误覆盖，距离5.724839230828446e-07，该检测器半径为1e-06
# 第1747个异常样本，被第447个自体检测器错误覆盖，距离4.172325197718659e-07，该检测器半径为1e-06
# 第1769个异常样本，被第535个自体检测器错误覆盖，距离0.00031636664703301153，该检测器半径为0.0008969874614992314
# 第1770个异常样本，被第1526个自体检测器错误覆盖，距离6.643979830530178e-07，该检测器半径为1e-06
# 第1771个异常样本，被第10670个自体检测器错误覆盖，距离0.0001753823805504857，该检测器半径为0.0001767082534267348
# 第1773个异常样本，被第839个自体检测器错误覆盖，距离9.721223481443985e-07，该检测器半径为1e-06
# 第1778个异常样本，被第8078个自体检测器错误覆盖，距离9.825731257966353e-07，该检测器半径为1e-06
# 第1780个异常样本，被第2033个自体检测器错误覆盖，距离8.024520917796706e-07，该检测器半径为1e-06
# 第1782个异常样本，被第2379个自体检测器错误覆盖，距离3.613339559132499e-07，该检测器半径为1e-06
# 第1787个异常样本，被第5436个自体检测器错误覆盖，距离2.1413295278597593e-05，该检测器半径为0.00022215581611241723
# 第1788个异常样本，被第3197个自体检测器错误覆盖，距离0.0001245282401022452，该检测器半径为0.0006291403276264548
# 第1796个异常样本，被第2048个自体检测器错误覆盖，距离4.298152121453846e-07，该检测器半径为1e-06
# 第1799个异常样本，被第839个自体检测器错误覆盖，距离7.462492033262783e-07，该检测器半径为1e-06
# 第1802个异常样本，被第288个自体检测器错误覆盖，距离6.21576719209713e-07，该检测器半径为1e-06
# 第1804个异常样本，被第1464个自体检测器错误覆盖，距离2.2891598188485527e-07，该检测器半径为1e-06
# 第1806个异常样本，被第7525个自体检测器错误覆盖，距离7.152557392660815e-07，该检测器半径为1e-06
# 第1807个异常样本，被第7525个自体检测器错误覆盖，距离1.7120130796843852e-07，该检测器半径为1e-06
# 第1810个异常样本，被第10209个自体检测器错误覆盖，距离0.002733957084293281，该检测器半径为0.0030512008143076595
# 第1822个异常样本，被第284个自体检测器错误覆盖，距离1.999200562387517e-07，该检测器半径为1e-06
# 第1825个异常样本，被第35330个自体检测器错误覆盖，距离0.0，该检测器半径为1e-06
# 第1829个异常样本，被第66个自体检测器错误覆盖，距离2.827296549232345e-07，该检测器半径为1e-06
# 第1830个异常样本，被第3366个自体检测器错误覆盖，距离8.704115103203557e-07，该检测器半径为1e-06
# 第1834个异常样本，被第21636个自体检测器错误覆盖，距离4.539256719942525e-06，该检测器半径为1.0163706182827829e-05
# 第1836个异常样本，被第6374个自体检测器错误覆盖，距离6.515744699845429e-07，该检测器半径为1e-06
# 第1837个异常样本，被第16578个自体检测器错误覆盖，距离4.884338839512899e-05，该检测器半径为6.795526014828957e-05
# 第1838个异常样本，被第1503个自体检测器错误覆盖，距离5.389196114076975e-07，该检测器半径为1e-06
# 第1839个异常样本，被第2525个自体检测器错误覆盖，距离6.982907363306113e-07，该检测器半径为1e-06
# 第1841个异常样本，被第10817个自体检测器错误覆盖，距离7.330402098197149e-07，该检测器半径为1e-06
# 第1844个异常样本，被第9027个自体检测器错误覆盖，距离9.219472586070311e-07，该检测器半径为1e-06
# 第1854个异常样本，被第958个自体检测器错误覆盖，距离6.995615159324783e-07，该检测器半径为1e-06
# 第1855个异常样本，被第126个自体检测器错误覆盖，距离7.360630782434882e-07，该检测器半径为1e-06
# 第1874个异常样本，被第7525个自体检测器错误覆盖，距离3.874301913133247e-07，该检测器半径为1e-06
# 第1875个异常样本，被第4154个自体检测器错误覆盖，距离4.042583747341616e-07，该检测器半径为1e-06
# 第1879个异常样本，被第7525个自体检测器错误覆盖，距离3.816559456248789e-07，该检测器半径为1e-06
# 第1883个异常样本，被第694个自体检测器错误覆盖，距离5.322865019869154e-07，该检测器半径为1e-06
# 第1885个异常样本，被第839个自体检测器错误覆盖，距离6.165552440176059e-07，该检测器半径为1e-06
# 第1889个异常样本，被第2905个自体检测器错误覆盖，距离1.2510552082105279e-05，该检测器半径为1.2938233006896523e-05
# 第1891个异常样本，被第1526个自体检测器错误覆盖，距离7.788619008882033e-07，该检测器半径为1e-06
# 第1892个异常样本，被第899个自体检测器错误覆盖，距离9.296223015526497e-07，该检测器半径为1e-06
# 第1897个异常样本，被第6481个自体检测器错误覆盖，距离0.03660121740463452，该检测器半径为0.03883240664029238
# 第1898个异常样本，被第3548个自体检测器错误覆盖，距离0.0005212758828924664，该检测器半径为0.0005354028088194398
# 第1904个异常样本，被第8022个自体检测器错误覆盖，距离0.0008648523002731792，该检测器半径为0.000987552542267465
# 第1907个异常样本，被第447个自体检测器错误覆盖，距离3.47551816394645e-07，该检测器半径为1e-06
# 第1910个异常样本，被第839个自体检测器错误覆盖，距离8.513246217960268e-07，该检测器半径为1e-06
# 第1912个异常样本，被第1813个自体检测器错误覆盖，距离6.474721765622007e-07，该检测器半径为1e-06
# 第1914个异常样本，被第22084个自体检测器错误覆盖，距离8.699011516340723e-07，该检测器半径为1e-06
# 第1919个异常样本，被第958个自体检测器错误覆盖，距离7.432677729946699e-07，该检测器半径为1e-06
# 第1924个异常样本，被第36422个自体检测器错误覆盖，距离4.0793403284202474e-05，该检测器半径为4.9359693278159584e-05
# 第1925个异常样本，被第2525个自体检测器错误覆盖，距离6.723710401684045e-07，该检测器半径为1e-06
# 第1927个异常样本，被第8087个自体检测器错误覆盖，距离6.944644589199397e-07，该检测器半径为1e-06
# 第1929个异常样本，被第2033个自体检测器错误覆盖，距离8.194283926080868e-07，该检测器半径为1e-06
# 第1940个异常样本，被第12786个自体检测器错误覆盖，距离9.461944051576727e-07，该检测器半径为1e-06
# 第1943个异常样本，被第7525个自体检测器错误覆盖，距离9.476013850300478e-07，该检测器半径为1e-06
# 第1944个异常样本，被第6374个自体检测器错误覆盖，距离6.515744699845429e-07，该检测器半径为1e-06
# 第1946个异常样本，被第16945个自体检测器错误覆盖，距离0.0005399949213026589，该检测器半径为0.0008577330934673895
# 第1949个异常样本，被第24980个自体检测器错误覆盖，距离3.6478334891402825e-06，该检测器半径为2.4429380133919174e-05
# 第1952个异常样本，被第12786个自体检测器错误覆盖，距离7.83976703561045e-07，该检测器半径为1e-06
# 第1956个异常样本，被第1503个自体检测器错误覆盖，距离1.7631291696726132e-07，该检测器半径为1e-06
# 第1962个异常样本，被第1618个自体检测器错误覆盖，距离9.452552614794213e-07，该检测器半径为1e-06
# 第1964个异常样本，被第34172个自体检测器错误覆盖，距离0.0023649972167038096，该检测器半径为0.0023774817201153583
# 第1965个异常样本，被第36150个自体检测器错误覆盖，距离0.0004692693511866248，该检测器半径为0.0005707374772687924
# 第1972个异常样本，被第2379个自体检测器错误覆盖，距离2.648888454621406e-07，该检测器半径为1e-06
# 第1980个异常样本，被第7014个自体检测器错误覆盖，距离7.996802267093309e-07，该检测器半径为1e-06
# 第1982个异常样本，被第8087个自体检测器错误覆盖，距离2.6987150762384774e-07，该检测器半径为1e-06
# 第1984个异常样本，被第2379个自体检测器错误覆盖，距离6.54295053803453e-07，该检测器半径为1e-06
# 第1988个异常样本，被第284个自体检测器错误覆盖，距离4.924151844704957e-07，该检测器半径为1e-06
# 第1997个异常样本，被第16130个自体检测器错误覆盖，距离0.0004722742459679151，该检测器半径为0.0008404202753159424
# 第2001个异常样本，被第7525个自体检测器错误覆盖，距离1.7881393432617188e-07，该检测器半径为1e-06
# 第2002个异常样本，被第793个自体检测器错误覆盖，距离3.746093836419742e-07，该检测器半径为1e-06
# 第2006个异常样本，被第22569个自体检测器错误覆盖，距离0.0001814061595411016，该检测器半径为0.00018492087533972582
# 第2009个异常样本，被第2379个自体检测器错误覆盖，距离1.1151007970493857e-07，该检测器半径为1e-06
# 第2012个异常样本，被第1000个自体检测器错误覆盖，距离8.544487580333204e-07，该检测器半径为1e-06
# 第2014个异常样本，被第44747个自体检测器错误覆盖，距离9.039491944979595e-07，该检测器半径为1e-06
# 第2016个异常样本，被第12786个自体检测器错误覆盖，距离8.460920903864448e-07，该检测器半径为1e-06
# 第2018个异常样本，被第284个自体检测器错误覆盖，距离1.3978528260658472e-07，该检测器半径为1e-06
# 第2019个异常样本，被第7525个自体检测器错误覆盖，距离2.5111883244883713e-07，该检测器半径为1e-06
# 第2020个异常样本，被第1464个自体检测器错误覆盖，距离6.623897346256689e-07，该检测器半径为1e-06
# 第2021个异常样本，被第315个自体检测器错误覆盖，距离4.0535540904806387e-07，该检测器半径为1e-06
# 第2022个异常样本，被第1464个自体检测器错误覆盖，距离6.522556763451464e-07，该检测器半径为1e-06
# 第2024个异常样本，被第1173个自体检测器错误覆盖，距离9.291444694714421e-07，该检测器半径为1e-06
# 第2038个异常样本，被第7525个自体检测器错误覆盖，距离7.396741895909545e-07，该检测器半径为1e-06
# 第2040个异常样本，被第868个自体检测器错误覆盖，距离0.0004090350957533166，该检测器半径为0.0006664264870100469
# 第2043个异常样本，被第1418个自体检测器错误覆盖，距离6.237164001600846e-07，该检测器半径为1e-06
# 第2044个异常样本，被第7525个自体检测器错误覆盖，距离6.391886054004842e-07，该检测器半径为1e-06
# 第2049个异常样本，被第2033个自体检测器错误覆盖，距离9.866324307006715e-07，该检测器半径为1e-06
# 第2056个异常样本，被第2379个自体检测器错误覆盖，距离5.709303681920431e-07，该检测器半径为1e-06
# 第2061个异常样本，被第154个自体检测器错误覆盖，距离2.995096403754259e-07，该检测器半径为1e-06
# 第2068个异常样本，被第17783个自体检测器错误覆盖，距离1.216967899963949e-05，该检测器半径为1.3299363584187404e-05
# 第2070个异常样本，被第694个自体检测器错误覆盖，距离6.912597160927456e-07，该检测器半径为1e-06
# 第2072个异常样本，被第7525个自体检测器错误覆盖，距离3.674277068954096e-07，该检测器半径为1e-06
# 第2073个异常样本，被第284个自体检测器错误覆盖，距离9.334361525710629e-07，该检测器半径为1e-06
# 第2075个异常样本，被第284个自体检测器错误覆盖，距离2.2891598188485527e-07，该检测器半径为1e-06
# 第2078个异常样本，被第11770个自体检测器错误覆盖，距离0.001969319787682033，该检测器半径为0.002074322792419845
# 第2079个异常样本，被第1558个自体检测器错误覆盖，距离0.000821943927369653，该检测器半径为0.0011726897659092325
# 第2080个异常样本，被第7525个自体检测器错误覆盖，距离5.794233732362235e-07，该检测器半径为1e-06
# 第2088个异常样本，被第73个自体检测器错误覆盖，距离7.719894584331515e-07，该检测器半径为1e-06
# 第2091个异常样本，被第528个自体检测器错误覆盖，距离6.743495761928573e-07，该检测器半径为1e-06
# 第2094个异常样本，被第8866个自体检测器错误覆盖，距离0.026340501208559998，该检测器半径为0.035507031472404776
# 第2110个异常样本，被第8665个自体检测器错误覆盖，距离1.5769908384502246e-07，该检测器半径为1e-06
# 第2120个异常样本，被第7134个自体检测器错误覆盖，距离0.00029745347173015807，该检测器半径为0.0005953338936664864
# 第2125个异常样本，被第694个自体检测器错误覆盖，距离8.744836422355947e-07，该检测器半径为1e-06
# 第2127个异常样本，被第7525个自体检测器错误覆盖，距离7.414731566322113e-07，该检测器半径为1e-06
# 第2131个异常样本，被第154个自体检测器错误覆盖，距离2.6320698458933376e-07，该检测器半径为1e-06
# 第2132个异常样本，被第284个自体检测器错误覆盖，距离6.763223398250352e-07，该检测器半径为1e-06
# 第2133个异常样本，被第284个自体检测器错误覆盖，距离1.86115443658781e-07，该检测器半径为1e-06
# 第2144个异常样本，被第4728个自体检测器错误覆盖，距离0.0010119912587001692，该检测器半径为0.001037103429012562
# 第2150个异常样本，被第17471个自体检测器错误覆盖，距离9.978216342502283e-07，该检测器半径为1e-06
# 第2155个异常样本，被第447个自体检测器错误覆盖，距离3.851308817660834e-07，该检测器半径为1e-06
# 第2159个异常样本，被第839个自体检测器错误覆盖，距离8.528881197851249e-07，该检测器半径为1e-06
# 第2162个异常样本，被第1464个自体检测器错误覆盖，距离3.182017365910323e-07，该检测器半径为1e-06
# 第2167个异常样本，被第1418个自体检测器错误覆盖，距离4.6361533361983434e-07，该检测器半径为1e-06
# 第2168个异常样本，被第1572个自体检测器错误覆盖，距离0.0012371689935570872，该检测器半径为0.00193812926289371
# 第2169个异常样本，被第10379个自体检测器错误覆盖，距离4.7327833276590946e-05，该检测器半径为0.00010501249836714194
# 第2178个异常样本，被第7525个自体检测器错误覆盖，距离4.214684881863215e-07，该检测器半径为1e-06
# 第2179个异常样本，被第28225个自体检测器错误覆盖，距离0.0011568883881426198，该检测器半径为0.0013875601335665783
# 第2180个异常样本，被第19785个自体检测器错误覆盖，距离2.0212918469683135e-07，该检测器半径为1e-06
# 第2182个异常样本，被第13757个自体检测器错误覆盖，距离0.0015555605818356924，该检测器半径为0.001634454820879762
# 第2187个异常样本，被第16715个自体检测器错误覆盖，距离0.0003382508497587868，该检测器半径为0.0003389453358491922
# 第2188个异常样本，被第22084个自体检测器错误覆盖，距离9.90226729279066e-07，该检测器半径为1e-06
# 第2193个异常样本，被第10422个自体检测器错误覆盖，距离6.6735911753381625e-06，该检测器半径为1.3897903325429212e-05
# 第2199个异常样本，被第16901个自体检测器错误覆盖，距离7.247481187918342e-06，该检测器半径为8.045040190488345e-06
# 第2202个异常样本，被第35330个自体检测器错误覆盖，距离9.424323207021104e-08，该检测器半径为1e-06
# 第2210个异常样本，被第2525个自体检测器错误覆盖，距离6.886851831160601e-07，该检测器半径为1e-06
# 第2213个异常样本，被第7628个自体检测器错误覆盖，距离8.835773028024152e-07，该检测器半径为1e-06
# 第2226个异常样本，被第39478个自体检测器错误覆盖，距离2.999393154306587e-06，该检测器半径为8.129126328932192e-06
# 第2229个异常样本，被第14159个自体检测器错误覆盖，距离0.0001127922757308993，该检测器半径为0.0001558218373268748
# 第2230个异常样本，被第447个自体检测器错误覆盖，距离5.575504032722062e-07，该检测器半径为1e-06
# 第2242个异常样本，被第1526个自体检测器错误覆盖，距离8.36591055847299e-07，该检测器半径为1e-06
# 第2243个异常样本，被第7525个自体检测器错误覆盖，距离6.809031785243308e-07，该检测器半径为1e-06
# 第2244个异常样本，被第288个自体检测器错误覆盖，距离7.996802276361437e-07，该检测器半径为1e-06
# 第2245个异常样本，被第2419个自体检测器错误覆盖，距离0.0008434405247228706，该检测器半径为0.0010329663511746017
# 第2247个异常样本，被第1503个自体检测器错误覆盖，距离5.430241572621057e-07，该检测器半径为1e-06
# 第2249个异常样本，被第7525个自体检测器错误覆盖，距离6.657334539003735e-07，该检测器半径为1e-06
# 第2253个异常样本，被第154个自体检测器错误覆盖，距离5.709303681920431e-07，该检测器半径为1e-06
# 第2258个异常样本，被第154个自体检测器错误覆盖，距离2.5288109954386333e-07，该检测器半径为1e-06
# 第2262个异常样本，被第284个自体检测器错误覆盖，距离3.828177694014461e-07，该检测器半径为1e-06
# 第2264个异常样本，被第899个自体检测器错误覆盖，距离5.543552457677291e-07，该检测器半径为1e-06
# 第2268个异常样本，被第9个自体检测器错误覆盖，距离8.429369702178807e-08，该检测器半径为1e-06
# 第2269个异常样本，被第958个自体检测器错误覆盖，距离6.995615159324783e-07，该检测器半径为1e-06
# 第2272个异常样本，被第8695个自体检测器错误覆盖，距离7.603273949587478e-05，该检测器半径为0.0006563642267387646
# 第2275个异常样本，被第4064个自体检测器错误覆盖，距离6.230039925457403e-07，该检测器半径为1e-06
# 第2276个异常样本，被第66个自体检测器错误覆盖，距离4.053554155780814e-07，该检测器半径为1e-06
# 第2283个异常样本，被第33715个自体检测器错误覆盖，距离0.00028011747180737575，该检测器半径为0.00028137354477371357
# 第2284个异常样本，被第1618个自体检测器错误覆盖，距离9.947013515031246e-07，该检测器半径为1e-06
# 第2288个异常样本，被第1503个自体检测器错误覆盖，距离1.6593232447193586e-07，该检测器半径为1e-06
# 第2290个异常样本，被第9027个自体检测器错误覆盖，距离8.487123767076815e-07，该检测器半径为1e-06
# 第2293个异常样本，被第315个自体检测器错误覆盖，距离7.396741930263845e-07，该检测器半径为1e-06
# 第2298个异常样本，被第22898个自体检测器错误覆盖，距离9.508762539866514e-07，该检测器半径为1e-06
# 第2300个异常样本，被第1503个自体检测器错误覆盖，距离2.8429604549952383e-07，该检测器半径为1e-06
# 第2302个异常样本，被第7525个自体检测器错误覆盖，距离8.52888110583958e-07，该检测器半径为1e-06
# 第2316个异常样本，被第7525个自体检测器错误覆盖，距离9.634035765931262e-07，该检测器半径为1e-06
# 第2318个异常样本，被第1618个自体检测器错误覆盖，距离9.334361514651261e-07，该检测器半径为1e-06
# 第2320个异常样本，被第12016个自体检测器错误覆盖，距离0.0002451522718313111，该检测器半径为0.0002543440253000258
# 第2324个异常样本，被第4246个自体检测器错误覆盖，距离7.656355283658397e-07，该检测器半径为1e-06
# 第2327个异常样本，被第154个自体检测器错误覆盖，距离6.717102370082055e-07，该检测器半径为1e-06
# 第2328个异常样本，被第34976个自体检测器错误覆盖，距离2.0283912581719704e-05，该检测器半径为2.8403411324974622e-05
# 第2331个异常样本，被第887个自体检测器错误覆盖，距离2.5111884056520567e-07，该检测器半径为1e-06
# 第2332个异常样本，被第364个自体检测器错误覆盖，距离8.107108180961277e-07，该检测器半径为1e-06
# 第2334个异常样本，被第66个自体检测器错误覆盖，距离7.725645081249253e-07，该检测器半径为1e-06
# 第2337个异常样本，被第8087个自体检测器错误覆盖，距离2.2302015940987714e-07，该检测器半径为1e-06
# 第2343个异常样本，被第447个自体检测器错误覆盖，距离4.5588787021572457e-07，该检测器半径为1e-06
# 第2346个异常样本，被第1503个自体检测器错误覆盖，距离5.397430184629755e-07，该检测器半径为1e-06
# 第2347个异常样本，被第288个自体检测器错误覆盖，距离4.6838026182358597e-07，该检测器半径为1e-06
# 第2349个异常样本，被第461个自体检测器错误覆盖，距离0.0008594582755343856，该检测器半径为0.001254543352113373
# 第2351个异常样本，被第315个自体检测器错误覆盖，距离6.251387925589092e-07，该检测器半径为1e-06
# 第2355个异常样本，被第1526个自体检测器错误覆盖，距离6.549734208417288e-07，该检测器半径为1e-06
# 第2358个异常样本，被第3585个自体检测器错误覆盖，距离4.470348358154297e-07，该检测器半径为1e-06
# 第2359个异常样本，被第694个自体检测器错误覆盖，距离7.817075911411133e-07，该检测器半径为1e-06
# 第2363个异常样本，被第8078个自体检测器错误覆盖，距离9.821210535337973e-07，该检测器半径为1e-06
# 第2367个异常样本，被第22820个自体检测器错误覆盖，距离5.242465701740437e-05，该检测器半径为0.0005216495464074466
# 第2373个异常样本，被第1000个自体检测器错误覆盖，距离8.544487580333204e-07，该检测器半径为1e-06
# 第2377个异常样本，被第6102个自体检测器错误覆盖，距离0.0014130594335668495，该检测器半径为0.0014781282460104366
# 第2383个异常样本，被第7525个自体检测器错误覆盖，距离3.851308817660834e-07，该检测器半径为1e-06
# 第2385个异常样本，被第1618个自体检测器错误覆盖，距离9.522763179088467e-07，该检测器半径为1e-06
# 第2393个异常样本，被第1418个自体检测器错误覆盖，距离4.777675730550706e-07，该检测器半径为1e-06
# 第2395个异常样本，被第8793个自体检测器错误覆盖，距离6.508925499041253e-07，该检测器半径为1e-06
# 第2403个异常样本，被第8879个自体检测器错误覆盖，距离0.0021332609101534145，该检测器半径为0.0024196353489873163
# 第2404个异常样本，被第7293个自体检测器错误覆盖，距离7.354594874106925e-07，该检测器半径为1e-06
# 第2408个异常样本，被第288个自体检测器错误覆盖，距离4.235705853567092e-07，该检测器半径为1e-06
# 第2409个异常样本，被第101个自体检测器错误覆盖，距离0.001444346702848279，该检测器半径为0.0022915729094640986
# 第2411个异常样本，被第7525个自体检测器错误覆盖，距离1.7881393432617188e-07，该检测器半径为1e-06
# 第2413个异常样本，被第6374个自体检测器错误覆盖，距离5.264139742069876e-07，该检测器半径为1e-06
# 第2414个异常样本，被第797个自体检测器错误覆盖，距离0.00012571744010960454，该检测器半径为0.0002975302676107017
# 第2415个异常样本，被第154个自体检测器错误覆盖，距离1.6593230851978128e-07，该检测器半径为1e-06
# 第2418个异常样本，被第694个自体检测器错误覆盖，距离8.210526424829402e-07，该检测器半径为1e-06
# 第2428个异常样本，被第7525个自体检测器错误覆盖，距离5.38919610004811e-07，该检测器半径为1e-06
# 第2434个异常样本，被第66个自体检测器错误覆盖，距离4.053554155780814e-07，该检测器半径为1e-06
# 第2444个异常样本，被第288个自体检测器错误覆盖，距离5.057621821307283e-07，该检测器半径为1e-06
# 第2445个异常样本，被第1173个自体检测器错误覆盖，距离9.471326333058904e-07，该检测器半径为1e-06
# 第2447个异常样本，被第5979个自体检测器错误覆盖，距离0.0006782158817386836，该检测器半径为0.0006931607365353361
# 第2448个异常样本，被第338个自体检测器错误覆盖，距离1.954268970027606e-07，该检测器半径为1e-06
# 第2449个异常样本，被第447个自体检测器错误覆盖，距离5.575504032722062e-07，该检测器半径为1e-06
# 第2450个异常样本，被第940个自体检测器错误覆盖，距离2.22295760676582e-05，该检测器半径为3.293114650845051e-05
# 第2451个异常样本，被第1769个自体检测器错误覆盖，距离0.0014833182977726483，该检测器半径为0.0026456053917233067
# 第2452个异常样本，被第16901个自体检测器错误覆盖，距离7.792324279043324e-06，该检测器半径为8.045040190488345e-06
# 第2455个异常样本，被第1464个自体检测器错误覆盖，距离3.613339632800283e-07，该检测器半径为1e-06
# 第2457个异常样本，被第66个自体检测器错误覆盖，距离3.6133396323882194e-07，该检测器半径为1e-06
# 第2463个异常样本，被第2982个自体检测器错误覆盖，距离0.000193228849545322，该检测器半径为0.0009221484419516088
# 第2464个异常样本，被第1572个自体检测器错误覆盖，距离0.0017497312558309526，该检测器半径为0.00193812926289371
# 第2467个异常样本，被第364个自体检测器错误覆盖，距离8.339326727171672e-07，该检测器半径为1e-06
# ...
# 第8558个异常样本，被第288个自体检测器错误覆盖，距离4.6743116204017766e-07，该检测器半径为1e-06
# 第8559个异常样本，被第854个自体检测器错误覆盖，距离7.667947012509313e-07，该检测器半径为1e-06
# 第8562个异常样本，被第8087个自体检测器错误覆盖，距离1.6323404302645325e-07，该检测器半径为1e-06
# 第8566个异常样本，被第10154个自体检测器错误覆盖，距离0.0008639986508914454，该检测器半径为0.0008639986510351094
# 第8568个异常样本，被第2525个自体检测器错误覆盖，距离6.854534149387139e-07，该检测器半径为1e-06
# 第8577个异常样本，被第1618个自体检测器错误覆盖，距离7.856742460000774e-07，该检测器半径为1e-06
# 第8579个异常样本，被第66个自体检测器错误覆盖，距离4.075406357381793e-07，该检测器半径为1e-06
# 第8580个异常样本，被第154个自体检测器错误覆盖，距离2.4027400458748785e-07，该检测器半径为1e-06
# 第8582个异常样本，被第66个自体检测器错误覆盖，距离4.5686095578155254e-07，该检测器半径为1e-06
# 第8589个异常样本，被第17177个自体检测器错误覆盖，距离0.0011479901934330495，该检测器半径为0.001561054786830361
# 第8590个异常样本，被第4954个自体检测器错误覆盖，距离0.00015207373176349555，该检测器半径为0.0001575087611736931
# 第8591个异常样本，被第8452个自体检测器错误覆盖，距离0.00025081577864550613，该检测器半径为0.0005659432107682441
# 第8594个异常样本，被第694个自体检测器错误覆盖，距离5.454720661158264e-07，该检测器半径为1e-06
# 第8598个异常样本，被第18144个自体检测器错误覆盖，距离2.9669690214757117e-05，该检测器半径为4.931637620374378e-05
# 第8603个异常样本，被第3034个自体检测器错误覆盖，距离9.018249743425725e-05，该检测器半径为0.00023738863278608582
# 第8606个异常样本，被第9969个自体检测器错误覆盖，距离9.661653782950476e-07，该检测器半径为1e-06
# 第8608个异常样本，被第147个自体检测器错误覆盖，距离0.0030383337409642308，该检测器半径为0.0037146805573873717
# 第8613个异常样本，被第447个自体检测器错误覆盖，距离8.508028075585776e-07，该检测器半径为1e-06
# 第8615个异常样本，被第1619个自体检测器错误覆盖，距离5.397430193903569e-07，该检测器半径为1e-06
# 第8619个异常样本，被第1081个自体检测器错误覆盖，距离0.0004392220815669289，该检测器半径为0.0009450565232609696
# 第8620个异常样本，被第7525个自体检测器错误覆盖，距离6.957422233346246e-07，该检测器半径为1e-06
# 第8622个异常样本，被第7525个自体检测器错误覆盖，距离7.366661503223932e-07，该检测器半径为1e-06
# 第8628个异常样本，被第7525个自体检测器错误覆盖，距离2.6987150762384774e-07，该检测器半径为1e-06
# 第8630个异常样本，被第839个自体检测器错误覆盖，距离7.74860385496149e-07，该检测器半径为1e-06
# 第8631个异常样本，被第1464个自体检测器错误覆盖，距离4.842304276777094e-07，该检测器半径为1e-06
# 第8632个异常样本，被第4753个自体检测器错误覆盖，距离0.0013848632428808073，该检测器半径为0.0014014039860514324
# 第8636个异常样本，被第8379个自体检测器错误覆盖，距离0.005297700152045025，该检测器半径为0.005324385405448718
# 第8641个异常样本，被第19852个自体检测器错误覆盖，距离0.08923229268327582，该检测器半径为0.1380808329807565
# 第8642个异常样本，被第7525个自体检测器错误覆盖，距离3.987278988709978e-07，该检测器半径为1e-06
# 第8645个异常样本，被第9027个自体检测器错误覆盖，距离8.460920790778631e-07，该检测器半径为1e-06
# 第8648个异常样本，被第1526个自体检测器错误覆盖，距离6.848052357390545e-07，该检测器半径为1e-06
# 第8653个异常样本，被第447个自体检测器错误覆盖，距离4.98688242126294e-07，该检测器半径为1e-06
# 第8658个异常样本，被第25897个自体检测器错误覆盖，距离9.23871996352821e-07，该检测器半径为1e-06
# 第8660个异常样本，被第1503个自体检测器错误覆盖，距离4.053554155780814e-07，该检测器半径为1e-06
# 第8661个异常样本，被第1526个自体检测器错误覆盖，距离9.70293321720854e-07，该检测器半径为1e-06
# 第8663个异常样本，被第288个自体检测器错误覆盖，距离8.002353684334969e-07，该检测器半径为1e-06
# 第8667个异常样本，被第9341个自体检测器错误覆盖，距离3.874379854442701e-05，该检测器半径为5.392326604942038e-05
# 第8668个异常样本，被第958个自体检测器错误覆盖，距离9.60171453881845e-07，该检测器半径为1e-06
# 第8671个异常样本，被第1742个自体检测器错误覆盖，距离0.000401808900627853，该检测器半径为0.0005994047323361268
# 第8674个异常样本，被第26221个自体检测器错误覆盖，距离0.0007727137281773733，该检测器半径为0.0009204256310899486
# 第8679个异常样本，被第839个自体检测器错误覆盖，距离6.31499893696992e-07，该检测器半径为1e-06
# 第8683个异常样本，被第7525个自体检测器错误覆盖，距离8.253683121587554e-07，该检测器半径为1e-06
# 第8684个异常样本，被第839个自体检测器错误覆盖，距离4.6361533824447027e-07，该检测器半径为1e-06
# 第8685个异常样本，被第1215个自体检测器错误覆盖，距离0.09738521664068207，该检测器半径为0.1465719566393219
# 第8689个异常样本，被第839个自体检测器错误覆盖，距离4.749708653085325e-07，该检测器半径为1e-06
# 第8696个异常样本，被第7525个自体检测器错误覆盖，距离2.6320698458933376e-07，该检测器半径为1e-06
# 第8706个异常样本，被第7172个自体检测器错误覆盖，距离5.881335662308195e-06，该检测器半径为9.579024613144072e-06
# 第8714个异常样本，被第4627个自体检测器错误覆盖，距离8.046627176444759e-07，该检测器半径为1.669994083180654e-06
# 第8720个异常样本，被第8110个自体检测器错误覆盖，距离1.0481778050722945e-06，该检测器半径为1.3873293176063754e-06
# 第8724个异常样本，被第4820个自体检测器错误覆盖，距离1.2689631570804204e-06，该检测器半径为2.2974382045384634e-06
# 第8732个异常样本，被第447个自体检测器错误覆盖，距离7.318275701100168e-07，该检测器半径为1e-06
# 第8734个异常样本，被第1906个自体检测器错误覆盖，距离0.008525686424159068，该检测器半径为0.00856144241753612
# 第8738个异常样本，被第6066个自体检测器错误覆盖，距离0.0016083362650203526，该检测器半径为0.002081469934707093
# 第8740个异常样本，被第1526个自体检测器错误覆盖，距离9.978216342502283e-07，该检测器半径为1e-06
# 第8744个异常样本，被第447个自体检测器错误覆盖，距离9.41489290452392e-07，该检测器半径为1e-06
# 第8759个异常样本，被第1526个自体检测器错误覆盖，距离7.071382115903302e-07，该检测器半径为1e-06
# 第8762个异常样本，被第52558个自体检测器错误覆盖，距离1.4322271837633315e-05，该检测器半径为2.5431353909244336e-05
# 第8763个异常样本，被第1173个自体检测器错误覆盖，距离5.893027807474736e-07，该检测器半径为1e-06
# 第8767个异常样本，被第447个自体检测器错误覆盖，距离4.6932744795569884e-07，该检测器半径为1e-06
# 第8768个异常样本，被第38095个自体检测器错误覆盖，距离0.0001481585318439715，该检测器半径为0.00015878142442985762
# 第8772个异常样本，被第20823个自体检测器错误覆盖，距离4.241042249053337e-05，该检测器半径为4.24476178901101e-05
# 第8774个异常样本，被第1464个自体检测器错误覆盖，距离6.623897346256689e-07，该检测器半径为1e-06
# 第8784个异常样本，被第1624个自体检测器错误覆盖，距离0.00017668953182366456，该检测器半径为0.00020468098869833222
# 第8785个异常样本，被第7293个自体检测器错误覆盖，距离9.17117750755035e-07，该检测器半径为1e-06
# 第8790个异常样本，被第694个自体检测器错误覆盖，距离4.977969298915587e-07，该检测器半径为1e-06
# 第8791个异常样本，被第2379个自体检测器错误覆盖，距离7.214378511559235e-07，该检测器半径为1e-06
# 第8801个异常样本，被第447个自体检测器错误覆盖，距离8.210526328112899e-07，该检测器半径为1e-06
# 第8807个异常样本，被第23756个自体检测器错误覆盖，距离1.2378802790237335e-05，该检测器半径为0.00010678640595738491
# 第8827个异常样本，被第17365个自体检测器错误覆盖，距离7.354594903291812e-07，该检测器半径为4.745425160098836e-05
# 第8831个异常样本，被第16个自体检测器错误覆盖，距离1.5139491779696649e-05，该检测器半径为2.8075954759585307e-05
# 第8833个异常样本，被第1418个自体检测器错误覆盖，距离5.923094425902304e-07，该检测器半径为1e-06
# 第8834个异常样本，被第66个自体检测器错误覆盖，距离4.042583759414008e-07，该检测器半径为1e-06
# 第8837个异常样本，被第1205个自体检测器错误覆盖，距离0.0010370989559693121，该检测器半径为0.0012176248530503398
# 第8840个异常样本，被第2379个自体检测器错误覆盖，距离2.5636928121708575e-07，该检测器半径为1e-06
# 第8843个异常样本，被第66个自体检测器错误覆盖，距离5.662441300408342e-07，该检测器半径为1e-06
# 第8849个异常样本，被第364个自体检测器错误覆盖，距离8.719407929438272e-07，该检测器半径为1e-06
# 第8853个异常样本，被第2033个自体检测器错误覆盖，距离7.913063792954095e-07，该检测器半径为1e-06
# 第8858个异常样本，被第31326个自体检测器错误覆盖，距离0.00012240333486425694，该检测器半径为0.0003068544487888518
# 第8860个异常样本，被第51376个自体检测器错误覆盖，距离0.002451993663125001，该检测器半径为0.0033074220040382276
# 第8865个异常样本，被第2591个自体检测器错误覆盖，距离0.0008300163809399357，该检测器半径为0.0009382770567780719
# 第8866个异常样本，被第1464个自体检测器错误覆盖，距离3.1398695818528565e-07，该检测器半径为1e-06
# 第8867个异常样本，被第958个自体检测器错误覆盖，距离7.058810797653868e-07，该检测器半径为1e-06
# 第8868个异常样本，被第2614个自体检测器错误覆盖，距离0.00015201428484627595，该检测器半径为0.00039019243606744206
# 第8871个异常样本，被第8087个自体检测器错误覆盖，距离1.6049041835281591e-07，该检测器半径为1e-06
# 第8875个异常样本，被第1679个自体检测器错误覆盖，距离0.0025978339389107785，该检测器半径为0.002679870914341179
# 第8878个异常样本，被第793个自体检测器错误覆盖，距离5.32286501963411e-07，该检测器半径为1e-06
# 第8880个异常样本，被第19785个自体检测器错误覆盖，距离1.9542689693874122e-07，该检测器半径为1e-06
# 第8885个异常样本，被第66个自体检测器错误覆盖，距离2.0647655905589363e-07，该检测器半径为1e-06
# 第8888个异常样本，被第2379个自体检测器错误覆盖，距离3.358551244150844e-07，该检测器半径为1e-06
# 第8889个异常样本，被第154个自体检测器错误覆盖，距离4.833124544942301e-07，该检测器半径为1e-06
# 第8895个异常样本，被第867个自体检测器错误覆盖，距离2.9824740229617088e-05，该检测器半径为0.00031646119952832537
# 第8901个异常样本，被第9027个自体检测器错误覆盖，距离8.940696740429346e-07，该检测器半径为1e-06
# 第8903个异常样本，被第87个自体检测器错误覆盖，距离9.019819574589715e-07，该检测器半径为1e-06
# 第8912个异常样本，被第2379个自体检测器错误覆盖，距离3.551356580201681e-07，该检测器半径为1e-06
# 第8919个异常样本，被第839个自体检测器错误覆盖，距离4.150983177776372e-07，该检测器半径为1e-06
# 第8925个异常样本，被第15330个自体检测器错误覆盖，距离6.233287411455576e-05，该检测器半径为0.00013386039137120906
# 第8926个异常样本，被第154个自体检测器错误覆盖，距离7.545345401978061e-07，该检测器半径为1e-06
# 第8932个异常样本，被第23个自体检测器错误覆盖，距离0.0008816507642185941，该检测器半径为0.0011911620180572458
# 第8938个异常样本，被第4163个自体检测器错误覆盖，距离0.0007954326862225988，该检测器半径为0.0014099838130384333
# 第8939个异常样本，被第8402个自体检测器错误覆盖，距离3.2920439429149247e-06，该检测器半径为5.0036404131109365e-06
# 第8941个异常样本，被第288个自体检测器错误覆盖，距离4.86061168619993e-07，该检测器半径为1e-06
# 第8945个异常样本，被第1173个自体检测器错误覆盖，距离6.049210809770209e-07，该检测器半径为1e-06
# 第8949个异常样本，被第1759个自体检测器错误覆盖，距离8.487123798412391e-07，该检测器半径为1e-06
# 第8950个异常样本，被第364个自体检测器错误覆盖，距离8.167141441133452e-07，该检测器半径为1e-06
# 第8953个异常样本，被第447个自体检测器错误覆盖，距离5.583463357170886e-07，该检测器半径为1e-06
# 第8956个异常样本，被第288个自体检测器错误覆盖，距离7.621474212892397e-07，该检测器半径为1e-06
# 第8960个异常样本，被第7525个自体检测器错误覆盖，距离4.36987826429164e-07，该检测器半径为1e-06
# 第8961个异常样本，被第449个自体检测器错误覆盖，距离4.6457223472898846e-07，该检测器半径为1.094804447097891e-06
# 第8962个异常样本，被第2379个自体检测器错误覆盖，距离1.3328003749250113e-07，该检测器半径为1e-06
# 第8963个异常样本，被第7525个自体检测器错误覆盖，距离3.139869497076493e-07，该检测器半径为1e-06
# 第8972个异常样本，被第270个自体检测器错误覆盖，距离0.0020070445266585366，该检测器半径为0.0020599226358781805
# 第8974个异常样本，被第958个自体检测器错误覆盖，距离9.929139273209864e-07，该检测器半径为1e-06
# 第8975个异常样本，被第43389个自体检测器错误覆盖，距离0.0029416706685501167，该检测器半径为0.00294169746021163
# 第8976个异常样本，被第39546个自体检测器错误覆盖，距离0.0006668993049521855，该检测器半径为0.0007076257393589919
# 第8988个异常样本，被第7482个自体检测器错误覆盖，距离2.6151431761360534e-07，该检测器半径为1e-06
# 第8989个异常样本，被第9198个自体检测器错误覆盖，距离0.00019991202016243252，该检测器半径为0.00020722217480765226
# 第8990个异常样本，被第5211个自体检测器错误覆盖，距离0.0011118917068081316，该检测器半径为0.0011233837635926378
# 第8991个异常样本，被第839个自体检测器错误覆盖，距离5.930587310624082e-07，该检测器半径为1e-06
# 第8997个异常样本，被第7686个自体检测器错误覆盖，距离0.0029736817166351277，该检测器半径为0.002973681716770653
# 第8999个异常样本，被第1526个自体检测器错误覆盖，距离6.474721765392047e-07，该检测器半径为1e-06
# 第9000个异常样本，被第284个自体检测器错误覆盖，距离7.189713912711123e-07，该检测器半径为1e-06
# 第9001个异常样本，被第284个自体检测器错误覆盖，距离1.2990531157078367e-07，该检测器半径为1e-06
# 第9002个异常样本，被第7293个自体检测器错误覆盖，距离9.76225101926902e-07，该检测器半径为1e-06
# 第9005个异常样本，被第19639个自体检测器错误覆盖，距离2.0214302720470195e-05，该检测器半径为2.1155209562541955e-05
# 第9007个异常样本，被第1921个自体检测器错误覆盖，距离6.782893347358656e-07，该检测器半径为1e-06
# 第9008个异常样本，被第1464个自体检测器错误覆盖，距离6.391886085891721e-07，该检测器半径为1e-06
# 第9021个异常样本，被第8087个自体检测器错误覆盖，距离8.970449548679877e-07，该检测器半径为1e-06
# 第9023个异常样本，被第447个自体检测器错误覆盖，距离4.6932744795569884e-07，该检测器半径为1e-06
# 第9027个异常样本，被第7525个自体检测器错误覆盖，距离1.999200562387517e-07，该检测器半径为1e-06
# 第9032个异常样本，被第7525个自体检测器错误覆盖，距离4.246177332741576e-07，该检测器半径为1e-06
# 第9033个异常样本，被第1503个自体检测器错误覆盖，距离4.3698783224419745e-07，该检测器半径为1e-06
# 第9035个异常样本，被第1464个自体检测器错误覆盖，距离3.47551816394645e-07，该检测器半径为1e-06
# 第9041个异常样本，被第154个自体检测器错误覆盖，距离5.794233873065776e-07，该检测器半径为1e-06
# 第9045个异常样本，被第1464个自体检测器错误覆盖，距离9.171177582879962e-07，该检测器半径为1e-06
# 第9047个异常样本，被第694个自体检测器错误覆盖，距离5.066394858400936e-07，该检测器半径为1e-06
# 第9055个异常样本，被第8143个自体检测器错误覆盖，距离0.00024248717883018913，该检测器半径为0.0002610183445291036
# 第9059个异常样本，被第288个自体检测器错误覆盖，距离5.52750740995251e-07，该检测器半径为1e-06
# 第9060个异常样本，被第18422个自体检测器错误覆盖，距离6.695524687720336e-05，该检测器半径为6.893050474269884e-05
# 第9063个异常样本，被第1464个自体检测器错误覆盖，距离5.732591207971754e-07，该检测器半径为1e-06
# 第9066个异常样本，被第7293个自体检测器错误覆盖，距离7.121445623423616e-07，该检测器半径为1e-06
# 第9067个异常样本，被第7525个自体检测器错误覆盖，距离7.985687873630465e-07，该检测器半径为1e-06
# 第9078个异常样本，被第23618个自体检测器错误覆盖，距离0.0007549008086941689，该检测器半径为0.0012320065594618689
# 第9087个异常样本，被第8087个自体检测器错误覆盖，距离8.471411722444728e-07，该检测器半径为1e-06
# 第9089个异常样本，被第14553个自体检测器错误覆盖，距离1.0553557401791016e-06，该检测器半径为1.6047658171585388e-06
# 第9098个异常样本，被第2636个自体检测器错误覆盖，距离0.0002640555199985248，该检测器半径为0.0011764659434677896
# 第9106个异常样本，被第8087个自体检测器错误覆盖，距离4.4103409633052825e-07，该检测器半径为1e-06
# 第9115个异常样本，被第447个自体检测器错误覆盖，距离4.78696185071085e-07，该检测器半径为1e-06
# 第9122个异常样本，被第315个自体检测器错误覆盖，距离2.7637537590627946e-07，该检测器半径为1e-06
# 第9125个异常样本，被第2694个自体检测器错误覆盖，距离6.158345436981864e-07，该检测器半径为1e-06
# 第9130个异常样本，被第839个自体检测器错误覆盖，距离7.462492033262783e-07，该检测器半径为1e-06
# 第9131个异常样本，被第7273个自体检测器错误覆盖，距离0.00011227362757378931，该检测器半径为0.00011273725043511689
# 第9133个异常样本，被第1606个自体检测器错误覆盖，距离0.003402840916183328，该检测器半径为0.0037766033121469414
# 第9141个异常样本，被第40554个自体检测器错误覆盖，距离0.02359113897102227，该检测器半径为0.023707418948388403
# 第9142个异常样本，被第87个自体检测器错误覆盖，距离5.638864066207155e-07，该检测器半径为1e-06
# 第9143个异常样本，被第4785个自体检测器错误覆盖，距离9.541398640778022e-07，该检测器半径为1e-06
# 第9145个异常样本，被第4785个自体检测器错误覆盖，距离9.79404254282119e-07，该检测器半径为1e-06
# 第9146个异常样本，被第39444个自体检测器错误覆盖，距离6.879977724308889e-05，该检测器半径为0.00010636184777751573
# 第9147个异常样本，被第2434个自体检测器错误覆盖，距离6.989264168380295e-07，该检测器半径为1e-06
# 第9158个异常样本，被第20101个自体检测器错误覆盖，距离1.313332590726142e-06，该检测器半径为3.070000863297579e-06
# 第9160个异常样本，被第1503个自体检测器错误覆盖，距离5.430241572621057e-07，该检测器半径为1e-06
# 第9161个异常样本，被第8036个自体检测器错误覆盖，距离0.028942013690665982，该检测器半径为0.029084811927940483
# 第9163个异常样本，被第315个自体检测器错误覆盖，距离2.5111884061502714e-07，该检测器半径为1e-06
# 第9166个异常样本，被第66个自体检测器错误覆盖，距离7.492187708169324e-07，该检测器半径为1e-06
# 第9168个异常样本，被第315个自体检测器错误覆盖，距离3.976125736274223e-07，该检测器半径为1e-06
# 第9173个异常样本，被第284个自体检测器错误覆盖，距离8.439899962679335e-07，该检测器半径为1e-06
# 第9175个异常样本，被第6374个自体检测器错误覆盖，距离7.656355373892094e-07，该检测器半径为1e-06
# 第9177个异常样本，被第154个自体检测器错误覆盖，距离1.6858739404357614e-07，该检测器半径为1e-06
# 第9180个异常样本，被第1526个自体检测器错误覆盖，距离6.336060692562948e-07，该检测器半径为1e-06
# 第9181个异常样本，被第44201个自体检测器错误覆盖，距离0.001557443312864593，该检测器半径为0.0023460188977676272
# 第9188个异常样本，被第1464个自体检测器错误覆盖，距离2.8429603618888426e-07，该检测器半径为1e-06
# 第9191个异常样本，被第284个自体检测器错误覆盖，距离5.048833645238413e-07，该检测器半径为1e-06
# 第9198个异常样本，被第839个自体检测器错误覆盖，距离3.976125736274223e-07，该检测器半径为1e-06
# 第9200个异常样本，被第7525个自体检测器错误覆盖，距离9.410174744641151e-07，该检测器半径为1e-06
# 第9205个异常样本，被第2525个自体检测器错误覆盖，距离6.802506572532979e-07，该检测器半径为1e-06
# 第9206个异常样本，被第7014个自体检测器错误覆盖，距离9.578560997153944e-07，该检测器半径为1e-06
# 第9207个异常样本，被第2694个自体检测器错误覆盖，距离9.839280882092413e-07，该检测器半径为1e-06
# 第9209个异常样本，被第7525个自体检测器错误覆盖，距离8.024520902137319e-07，该检测器半径为1e-06
# 第9212个异常样本，被第28884个自体检测器错误覆盖，距离8.930757202312333e-07，该检测器半径为1e-06
# 第9213个异常样本，被第1526个自体检测器错误覆盖，距离8.323335673671329e-07，该检测器半径为1e-06
# 第9215个异常样本，被第288个自体检测器错误覆盖，距离4.749708607944616e-07，该检测器半径为1e-06
# 第9220个异常样本，被第1335个自体检测器错误覆盖，距离0.0008112795343880665，该检测器半径为0.000811778209263412
# 第9227个异常样本，被第7525个自体检测器错误覆盖，距离5.364418061858265e-07，该检测器半径为1e-06
# 第9234个异常样本，被第12011个自体检测器错误覆盖，距离0.0013849378920389721，该检测器半径为0.0013849378921131836
# 第9236个异常样本，被第3983个自体检测器错误覆盖，距离9.287142097070953e-06，该检测器半径为1.4934465324613092e-05
# 第9240个异常样本，被第39726个自体检测器错误覆盖，距离3.3820226634439736e-05，该检测器半径为4.336676982971068e-05
# 第9242个异常样本，被第8471个自体检测器错误覆盖，距离0.004111496433084722，该检测器半径为0.004200021845661131
# 第9246个异常样本，被第1912个自体检测器错误覆盖，距离0.002113008024631996，该检测器半径为0.0029245703276958605
# 第9247个异常样本，被第2377个自体检测器错误覆盖，距离0.000602294666142266，该检测器半径为0.0010074582649694022
# 第9252个异常样本，被第694个自体检测器错误覆盖，距离7.913063826246723e-07，该检测器半径为1e-06
# 第9253个异常样本，被第87个自体检测器错误覆盖，距离5.599348064490386e-07，该检测器半径为1e-06
# 第9254个异常样本，被第793个自体检测器错误覆盖，距离8.074174751459574e-07，该检测器半径为1e-06
# 第9257个异常样本，被第2033个自体检测器错误覆盖，距离8.323335673821643e-07，该检测器半径为1e-06
# 第9261个异常样本，被第10246个自体检测器错误覆盖，距离0.0025190785057527345，该检测器半径为0.00255116289510452
# 第9263个异常样本，被第7014个自体检测器错误覆盖，距离7.238958975079707e-07，该检测器半径为1e-06
# 第9266个异常样本，被第1503个自体检测器错误覆盖，距离6.005001604630374e-07，该检测器半径为1e-06
# 第9272个异常样本，被第288个自体检测器错误覆盖，距离5.280985022455031e-07，该检测器半径为1e-06
# 第9273个异常样本，被第694个自体检测器错误覆盖，距离6.912597153832949e-07，该检测器半径为1e-06
# 第9280个异常样本，被第694个自体检测器错误覆盖，距离4.47034841764606e-07，该检测器半径为1e-06
# 第9289个异常样本，被第34002个自体检测器错误覆盖，距离2.1624147003899954e-05，该检测器半径为2.8869345256094514e-05
# 第9292个异常样本，被第288个自体检测器错误覆盖，距离6.841564385986015e-07，该检测器半径为1e-06
# 第9293个异常样本，被第839个自体检测器错误覆盖，距离6.736907129795306e-07，该检测器半径为1e-06
# 第9297个异常样本，被第3532个自体检测器错误覆盖，距离0.00023335250215202502，该检测器半径为0.00045881456930517374
# 第9302个异常样本，被第525个自体检测器错误覆盖，距离0.0005283081612851103，该检测器半径为0.0007079328446909497
# 第9303个异常样本，被第958个自体检测器错误覆盖，距离8.970449533040768e-07，该检测器半径为1e-06
# 第9306个异常样本，被第837个自体检测器错误覆盖，距离0.00020153622805697322，该检测器半径为0.0006578473223918919
# 第9309个异常样本，被第17177个自体检测器错误覆盖，距离0.0011479901934330495，该检测器半径为0.001561054786830361
# 第9313个异常样本，被第905个自体检测器错误覆盖，距离9.85731814586574e-07，该检测器半径为1e-06
# 第9315个异常样本，被第7525个自体检测器错误覆盖，距离8.775253231023052e-07，该检测器半径为1e-06
# 第9319个异常样本，被第4615个自体检测器错误覆盖，距离5.990192664337689e-07，该检测器半径为1e-06
# 第9320个异常样本，被第1235个自体检测器错误覆盖，距离0.002508357607450079，该检测器半径为0.0025283664470377924
# 第9324个异常样本，被第7525个自体检测器错误覆盖，距离4.5295608524722037e-07，该检测器半径为1e-06
# 第9325个异常样本，被第1813个自体检测器错误覆盖，距离9.33911787743619e-07，该检测器半径为1e-06
# 第9328个异常样本，被第16431个自体检测器错误覆盖，距离0.0002331248413988491，该检测器半径为0.00026974066311564896
# 第9338个异常样本，被第1418个自体检测器错误覆盖，距离5.778884717722332e-07，该检测器半径为1e-06
# 第9343个异常样本，被第154个自体检测器错误覆盖，距离6.265579516704032e-07，该检测器半径为1e-06
# 第9346个异常样本，被第1804个自体检测器错误覆盖，距离9.424321830774485e-08，该检测器半径为1e-06
# 第9352个异常样本，被第5396个自体检测器错误覆盖，距离0.0008093583468892473，该检测器半径为0.001034911611549988
# 第9355个异常样本，被第7525个自体检测器错误覆盖，距离9.518098500688917e-07，该检测器半径为1e-06
# 第9358个异常样本，被第18147个自体检测器错误覆盖，距离0.0008535161617249532，该检测器半径为0.0011427745400745227
# 第9366个异常样本，被第12786个自体检测器错误覆盖，距离8.513246124535917e-07，该检测器半径为1e-06
# 第9376个异常样本，被第715个自体检测器错误覆盖，距离0.00010138122838449684，该检测器半径为0.00011747679323884004
# 第9379个异常样本，被第7525个自体检测器错误覆盖，距离7.456538696515407e-07，该检测器半径为1e-06
# 第9383个异常样本，被第388个自体检测器错误覆盖，距离0.0018180490085501287，该检测器半径为0.0019709407969894623
# 第9385个异常样本，被第661个自体检测器错误覆盖，距离0.0005971666895554825，该检测器半径为0.0007131585079085972
# 第9388个异常样本，被第2525个自体检测器错误覆盖，距离7.64474604770169e-07，该检测器半径为1e-06
# true_self:9559, false_self:152, true_nonself:6825, false_nonself:2570
# 自体准确率：0.9843476469982494， 非自体识别准确率：0.7264502394890899
